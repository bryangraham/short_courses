# %% [markdown]
# # Notebook 6: Exogenous Network Formation and Tetrad Logit
# #### Econometric Methods for Social Spillovers and Networks
# #### University of St. Gallen, October 1st to 9th, 2018
# ##### _Bryan S. Graham, UC - Berkeley, bgraham@econ.berkeley.edu_
# This is the sixth of a series of iPython Jupyter notebooks designed to accompany a series of instructional lectures given at the St. Gallen University from Oct 1st to Oct 9th, 2018. The scripts below were written for Python 3.6. The Anaconda distribution of Python, available at https://www.continuum.io/downloads, comes bundled with most the scientific computing packages used in these notebooks.
# <br>
# <br>
# For more information about the course please visit my webpage at http://bryangraham.github.io/econometrics/.
# <br>
# <br>
# In this notebook I illustrate how to fix dyadic network formation models using the two estimation procedureds studied in Graham (2017, _Econometrica_). This paper extends dyadic regression analysis to accommodate unobserved agent-specific effects.
# <br>
# <br>
# #### References
# <br>
# Graham, Bryan S. (2017). "An econometric model of network formation with degree heterogeneity,” _Econometrica_ 85 (4): 1033 - 1063.

# %% [markdown]
# I begin by importing several key packages. The _numpy_ and _scipy_ libraries include a core set of scientific computing tools. The _pandas_ package is useful for data organization and analysis, while _matplotlib_ is Python's basic plotting add-on. Finally the _networkx_ package includes functionality for the analysis, and also visualizing, network data.

# %%
# Direct Python to plot all figures inline (i.e., not in a separate window)
# %matplotlib inline

# Main scientific computing modules
import numpy as np
import scipy as sp
import pandas as pd

# Import matplotlib
import matplotlib.pyplot as plt

# networkx module for the analysis of network data
import networkx as nx

# %% [markdown]
# Load **netrics** package. The Python 2.7 version of this package is registered on [PyPi](https://pypi.python.org/pypi/netrics/), with a GitHub repository at https://github.com/bryangraham/netrics_py27. For an informal introduction to the package see [this](http://bryangraham.github.io/econometrics/networks/2016/09/15/netrics-module.html) blog post. The blog post also includes links to additional resources. The Python 3.6 version of the package is still under development, but currently available code can be found on GitHub at https://github.com/bryangraham/netrics. Once a basic level of functionality and reliability is in place I will register it on PyPi.

# %%
# Append location of ipt module base directory to system path
# NOTE: only required if permanent install not made (see comments above)
import sys
sys.path.append('/Users/bgraham/Dropbox/Sites/software/ipt/')
sys.path.append('/Users/bgraham/Dropbox/Sites/software/netrics/')

# Load ipt and netrics modules
import ipt as ipt
import netrics as netrics

# %% [markdown]
# The following code snippet should be edited to point to wherever you have saved the instructional datasets for the course

# %%
# Directory where datasets of located
data =  '/Users/bgraham/Dropbox/Teaching/Short_Courses/St_Gallen/2018/Data/'

# %% [markdown]
# A basic dyadic dataset for Nyakatoke was constructed in the Notebook 1. I begin by loading this dataset into a pandas dataframe.

# %%
# Read in estimation sample created in the notebook for Lecture 1
es = pd.read_csv(data+"Created/Nyakatoke_Estimation_Sample.csv")
es = es.set_index(['hh1', 'hh2'], drop = False)           # Set dataframe multi-index
del es['Unnamed: 0']                                      # Delete first column which is an unneeded single index

# Print out the first few rows of the dyadic data
es.head()
# Out:
#          hh1  hh2            links               kinship    distance  clan1  \
# hh1 hh2
# 1   2      1    2          no link  other blood relation   91.199997   21.0
#     3      1    3          no link     no blood relation   69.599998   21.0
#     4      1    4  unilateral link     no blood relation  199.199997   21.0
#     5      1    5          no link     no blood relation  252.000000   21.0
#     6      1    6          no link     no blood relation  213.600006   21.0
#
#          clan2    wealth1   wealth2 religion1 religion2  primary1  primary2  \
# hh1 hh2
# 1   2      6.0  17.657388  6.639588  Catholic  Catholic         0         1
#     3     21.0  17.657388  1.538235  Catholic  Catholic         0         1
#     4     23.0  17.657388  2.743059  Catholic  Catholic         0         1
#     5     23.0  17.657388  1.976098  Catholic  Catholic         0         1
#     6     23.0  17.657388  1.394941  Catholic  Catholic         0         1
#
#          head_age1  head_age2  head_sex1  head_sex2
# hh1 hh2
# 1   2         75.0       30.0        1.0        1.0
#     3         75.0       48.0        1.0        0.0
#     4         75.0       80.0        1.0        1.0
#     5         75.0       35.0        1.0        1.0
#     6         75.0       28.0        1.0        1.0

# %% [markdown]
# Below we fit a dyadic link formation model using the two estimators introduced by Graham (2017, _Econometrica_). The link formation model studied in that paper is
#
#
# <div> $$\Pr\left(\left.D_{ij}=1\right|\mathbf{X},\mathbf{A}\right) = \frac{\exp\left(\sum_{k=1}^{K}W_{k,ij}\beta_{k}+A_{i}+A_{j}\right)}   {1+\exp\left(\sum_{k=1}^{K}W_{k,ij}\beta_{k}+A_{i}+A_{j}\right)}$$ </div>
#
# Here $\mathbf{X}$ denotes all the household-specific observed covariates in the network, $W_{k,ij} = W_{k,ji}$ are dyad-specific covariates constructed from $\mathbf{X}$, and the $A_i$ for $i=1,...,N$ are _degree heterogeneity_ parameters which are household specific. These are treated as co-called "fixed effects".
# <br>
# <br>
# Graham (2017) introduces a "tetrad logit" procedure which forms a criterion function, based on conditioning arguments, which is invariant to the fixed effects and also a "joint fixed effects" procedure which estimates the individual effects along with the common parameters.
# <br>
# <br>
# In the _netrics_ package these two procedures are operationalized by the *tetrad\_logit()* and *dyad\_jfe\_logit()* functions. These two functions require the user to input data in a very particular way. The outcome is $D$, the $N \times N$ adjacency matrix. The regressors are included in a length $K$ list where each element is an $N \times N $ numpy 2d array $W_{k}$ with $(i,j)$ element equal to the dyadic covariate $W_{k,ij}$. It takes a bit of work to get our Nyakatoke dataset into this form. This is what the next few snippets of code do.

# %%
hh_set = set(es['hh1'].unique()) | set(es['hh2'].unique()) # Set of all households
N = len(hh_set)                                            # Number of households
n = N * (N - 1) //2                                        # Number of dyads

# %%
# Get multi-indices for lower triangle of N x N matrix
ij_LowTri = np.tril_indices(N, -1)

# %%
# Form adjacency matrix as a dense 2d numpy array
D = np.zeros((N,N), dtype = np.bool)
D[ij_LowTri] = (es['links'] != 'no link')
D = (D + D.T)*1

# %%
# Form four categorical bins for wealth (same as used in plot of Network from Lecture 1)
wealth_bkts = [1000000, 6, 3, 1.5, 0]
wealth_bin_labels = ['+600K','(600K,300K]','(300K,150K]','(150K, 0K]']
es['wealth_cat1'] = np.digitize(es.wealth1, wealth_bkts)
es['wealth_cat2'] = np.digitize(es.wealth2, wealth_bkts)

# %% [markdown]
# Construct $K$ list of $N \times N$ dyad-specific covariate matrices.

# %%
cov_names = ['Distance','Other blood relation', 'Cousin, etc.', 'Sibling, child, etc.', 'Age difference', \
             'Same religion', 'Same clan', 'Same education level', 'Adjacent wealth class', \
             'Non-adjacent wealth class']

# Initialize K-list of dyadic covariate matrices
W = [np.zeros((N,N), dtype = np.float)]*len(cov_names)

# Distance between households
W[0][ij_LowTri] = es['distance']
W[0] = W[0] + W[0].T

# Whether two households are other blood related
W[1][ij_LowTri] = (es['kinship']=='other blood relation')*1
W[1] = W[1] + W[1].T

# Whether two households have a nephew etc. level blood relation
W[2][ij_LowTri] = (es['kinship']=='Nephew/niece/uncle/aunt,cousin,grandparent/grandchild')*1
W[2] = W[2] + W[2].T    

# Whether two households have a child etc. level blood relation
W[3][ij_LowTri] = (es['kinship']=='sibling, child, parent')*1
W[3] = W[3] + W[3].T  

# Absolute difference in age between two household heads
W[4][ij_LowTri] = np.abs(es['head_age1']-es['head_age2'])
W[4] = W[4] + W[4].T

# Whether two households are of the same religion
W[5][ij_LowTri] = (es['religion1'] == es['religion2'])*1
W[5] = W[5] + W[5].T

# Whether two households belong to the same clan
W[6][ij_LowTri] = (es['clan1'] == es['clan2'])*1
W[6] = W[6] + W[6].T

# Whether two households are of the same education level
W[7][ij_LowTri] = (es['primary1'] == es['primary2'])*1
W[7] = W[7] + W[7].T

# Whether two households are of in adjacent wealth class
W[8][ij_LowTri] = (np.abs(es['wealth_cat1'] - es['wealth_cat2']) == 1)*1
W[8] = W[8] + W[8].T

# Whether two households are of in distance wealth classes
W[9][ij_LowTri] = (np.abs(es['wealth_cat1'] - es['wealth_cat2']) > 1)*1
W[9] = W[9] + W[9].T

# %% [markdown]
# Save the adjacency matrix and the covariate matrices to an uncompressed file (this serves as a test dataset for the *tetrad\_logit()* and *dyad\_jfe\_logit()* functions). This file can be download from GitHub at https://github.com/bryangraham/netrics/blob/master/Notebooks/Nyakatoke_Example.npz.

# %%
np.savez(data+"Created/Nyakatoke_Example", D = D, Distance = W[0], OtherBlood = W[1], Cousin = W[2], \
                                           Sibling = W[3], AgeDiff = W[4], SameReligion = W[5], \
                                           SameClan = W[6], SameEdLvl = W[7], AdjacentWealthClass = W[8], \
                                           NonAdjacentWealthClass = W[9])

# %% [markdown]
# ## Tetrad Logit
# With $W$ appropriately constructed we can now fit a link formation model using *tetrad\_logit()*. We can get a sense of how the function works by viewing its help header.

# %%
help(netrics.tetrad_logit)
# Out:
# Help on function tetrad_logit in module netrics.tetrad_logit:
#
# tetrad_logit(D, W, dtcon=None, silent=False, W_names=None)
#     AUTHOR: Bryan S. Graham, bgraham@econ.berkeley.edu, June 2016
#             Revised/updated for Python 3.6 October, 2018
#
#     This function computes the Tetrad Logit estimator introduced in Graham (2017, Econometrica)
#     -- "An Econometric Model of Link Formation with Degree Heterogeneity". The implementation
#     is as described in the paper. Notation attempts to follow that used in the paper.
#
#     INPUTS
#     ------
#     D                 : N x N undirected adjacency matrix
#     W                 : List with elements consisting of N x N 2d numpy arrays of dyad-specific
#                         covariates such that W[k][i,j] gives the k-th covariate for dyad ij
#     dtcon             : Dyad and tetrad concordance (dtcon) List with elements [tetrad_to_dyads_indices,
#                         dyad_to_tetrads_dict]. If dtcon=None, then construct it using generate_tetrad_indices()
#                         function. See header to generate_tetrad_indices() for more information.
#     silent            : If True then suppress all optimization and estimation output, show output otherwise.
#     W_names           : List of K strings giving names of the columns of W_tilde. If silent=False then use
#                         these in presentation of estimation output.
#
#     OUTPUTS
#     -------
#     beta_TL          :  K x 1 vector of tetrad logit point estimates of beta
#     vcov_beta_TL     :  K x K asymptotic-variance matrix for beta_TL
#                         NOTE: vcov_beta_TL is already "divided by n" (just take square root
#                         of diagonal for std. errs.)
#     tetrad_frac_TL   :  Fraction of tetrads that contribute to Tetrad Logit criterion function
#     success          :  corresponds to success component of OptimizeResult associated with
#                         Scipy's minimize function; success = True if the tetrad logit
#                         optimizer exited successfully
#
#
#     CALLS:           : ...logit()...
#                        ...organize_data_tetrad_logit()...
#     ------

# %% [markdown]
# Finally we call *tetrad\_logit()*. Depending on the speed and memory of your computer, this next bit of code may take a few minutes to complete.

# %%
[beta_TL, vcov_beta_TL, tetrad_frac_TL, success] = \
    netrics.tetrad_logit(D, W, dtcon=None, silent=False, W_names=cov_names)
# Out:
# Fisher-Scoring Derivative check (2-norm): 83.97631085
# Value of -logL = 69158.185590,  2-norm of score = 5050100.984835
# Value of -logL = 67593.616978,  2-norm of score = 798126.599415
# Value of -logL = 67538.081661,  2-norm of score = 227764.212117
# Value of -logL = 67033.641994,  2-norm of score = 180510.667836
# Value of -logL = 66303.083489,  2-norm of score = 98018.171015
# Value of -logL = 66110.547991,  2-norm of score = 45862.871411
# Value of -logL = 59498.545868,  2-norm of score = 383793.476872
# Value of -logL = 59486.204176,  2-norm of score = 14890.282721
# Value of -logL = 57556.925804,  2-norm of score = 48275.704045
# Value of -logL = 57556.712392,  2-norm of score = 11335.703885
# Value of -logL = 55482.842064,  2-norm of score = 56718.192937
# Value of -logL = 55482.549827,  2-norm of score = 8825.011465
# Value of -logL = 52713.310524,  2-norm of score = 88084.371820
# Value of -logL = 52712.601173,  2-norm of score = 6841.110078
# Value of -logL = 51002.462297,  2-norm of score = 43308.201452
# Value of -logL = 51002.283274,  2-norm of score = 5468.188118
# Value of -logL = 49370.718481,  2-norm of score = 53195.308805
# Value of -logL = 49370.438713,  2-norm of score = 4019.631453
# Value of -logL = 48674.508893,  2-norm of score = 11205.270833
# Value of -logL = 48674.495021,  2-norm of score = 3471.523355
# Value of -logL = 48127.171972,  2-norm of score = 8336.921432
# Value of -logL = 47774.731831,  2-norm of score = 48051.763465
# Value of -logL = 47774.482722,  2-norm of score = 2599.119904
# Value of -logL = 47612.821217,  2-norm of score = 2551.759073
# Value of -logL = 47451.510108,  2-norm of score = 28434.420331
# Value of -logL = 47451.422896,  2-norm of score = 1490.321539
# Value of -logL = 47242.939258,  2-norm of score = 3780.251535
# Value of -logL = 47242.937544,  2-norm of score = 1164.204468
# Value of -logL = 47172.737840,  2-norm of score = 995.160935
# Value of -logL = 47055.596242,  2-norm of score = 2683.697405
# Value of -logL = 47055.595387,  2-norm of score = 654.806468
# Value of -logL = 47021.648977,  2-norm of score = 552.022882
# Value of -logL = 46971.824283,  2-norm of score = 1671.091538
# Value of -logL = 46971.823957,  2-norm of score = 240.672076
# Value of -logL = 46968.455189,  2-norm of score = 207.979798
# Value of -logL = 46962.730163,  2-norm of score = 157.882552
# Value of -logL = 46957.594389,  2-norm of score = 356.654720
# Value of -logL = 46957.594374,  2-norm of score = 4.797653
# Value of -logL = 46957.593794,  2-norm of score = 4.100497
# Value of -logL = 46957.592823,  2-norm of score = 2.799690
# Value of -logL = 46957.591861,  2-norm of score = 1.515802
# Value of -logL = 46957.591669,  2-norm of score = 0.405898
# Value of -logL = 46957.591607,  2-norm of score = 0.051048
# Value of -logL = 46957.591607,  2-norm of score = 0.008289
# Value of -logL = 46957.591607,  2-norm of score = 0.000540
# Value of -logL = 46957.591607,  2-norm of score = 0.000014
# Value of -logL = 46957.591607,  2-norm of score = 0.000000
# Value of -logL = 46957.591607,  2-norm of score = 0.000000
# Optimization terminated successfully.
#          Current function value: 46957.591607
#          Iterations: 48
#          Function evaluations: 121
#          Gradient evaluations: 168
#          Hessian evaluations: 48
#
# -------------------------------------------------------------------------------------------
# - TETRAD LOGIT ESTIMATION RESULTS                                                         -
# -------------------------------------------------------------------------------------------
#
# Number of agents,           N :             115
# Number of dyads,            n :           6,555
# Number of tetrads             :       6,913,340
# Number identifying tetrads    :         102,151
# Fraction identifying tetrads  :        0.014776
#
# -------------------------------------------------------------------------------------------
#
# Independent variable       Coef.    ( Std. Err.)     (0.95 Confid. Interval )
# -------------------------------------------------------------------------------------------
# Distance                  -0.002098 (  0.000321)     ( -0.002728 , -0.001468)
# Other blood relation       1.263222 (  0.295226)     (  0.684589 ,  1.841855)
# Cousin, etc.               2.045045 (  0.373156)     (  1.313671 ,  2.776418)
# Sibling, child, etc.       2.674647 (  0.415617)     (  1.860053 ,  3.489241)
# Age difference            -0.014230 (  0.005989)     ( -0.025968 , -0.002491)
# Same religion              0.234212 (  0.141803)     ( -0.043717 ,  0.512140)
# Same clan                  0.272891 (  0.215871)     ( -0.150207 ,  0.695990)
# Same education level       0.216351 (  0.148914)     ( -0.075515 ,  0.508217)
# Adjacent wealth class     -0.220430 (  0.160917)     ( -0.535821 ,  0.094961)
# Non-adjacent wealth class -0.228703 (  0.175977)     ( -0.573612 ,  0.116207)
#
# -------------------------------------------------------------------------------------------

# %% [markdown]
# The program spits out some useful information. In a network with $N = 115$ agents there are a total of $6,913,340$ different tetrads! Of these only $102,151$, or about 1.5 percent, actually contribute to the *tetrad\_logit()* criterion function. The effectiveness of the procedure in the context of sparse networks is one of its theoretical and practical attractions.
# <br>
# <br>
# The results suggest that ties are more frequent between households which are physically close, related by blood and where the household heads are close in age. There is little evidence for sorting by religion, clan or education. There is some evidence for heterophily in terms of wealth (perhaps consistent with some models of "mutual support"), but it is rather weak.
# <br>
# <br>
# The *tetrad\_logit()* estimation procedure is computationally intense. On a modern desktop machine it would be difficult to use the procedure on a network larger than a few hundred agents (fortunately there are many possible ways to apply the method at scale via various approximations and parallelizations; but these extensions are not yet part of the _netrics_ package).
# <br>
# <br>
# Part of the computational intensity is up front. Specifically, the function computes a detailed dictionary which maps dyads-to-tetrads and vice-versa. This bookkeeping overhead makes later calculations much quicker. A user who anticipates fitting several different models to the same adjacency matrix can save considerable time by computing this concordance first (once and for all) and then passing it to *tetrad\_logit()* via the _dtcon_ parameter. This can be done by calling the *generate\_tetrad\_indices()* function.
# <br>
# <br>
# To illustrate I create the concordance and then fit a model with only the distance and kinship variables included.

# %%
N = np.shape(D)[0]
concordance = netrics.generate_tetrad_indices(N, full_set=True)
[beta_TL, vcov_beta_TL, tetrad_frac_TL, success] = \
    netrics.tetrad_logit(D, W[0:4], dtcon=concordance, silent=False, W_names=cov_names[0:4])
# Out:
# Fisher-Scoring Derivative check (2-norm): 83.97620528
# Value of -logL = 69163.219831,  2-norm of score = 5045814.866050
# Value of -logL = 67604.839126,  2-norm of score = 772959.869305
# Value of -logL = 67557.021302,  2-norm of score = 30472.352890
# Value of -logL = 60570.400551,  2-norm of score = 312602.514428
# Value of -logL = 60562.290006,  2-norm of score = 9904.763394
# Value of -logL = 55914.238906,  2-norm of score = 204713.498453
# Value of -logL = 55910.626898,  2-norm of score = 6252.561744
# Value of -logL = 53745.637844,  2-norm of score = 62366.284086
# Value of -logL = 53745.287551,  2-norm of score = 4450.443068
# Value of -logL = 52853.901035,  2-norm of score = 13360.292600
# Value of -logL = 52853.883283,  2-norm of score = 3931.551890
# Value of -logL = 52132.409477,  2-norm of score = 9742.220453
# Value of -logL = 52132.399570,  2-norm of score = 3371.585317
# Value of -logL = 51720.042467,  2-norm of score = 4052.606996
# Value of -logL = 50991.862741,  2-norm of score = 17599.150097
# Value of -logL = 50991.832261,  2-norm of score = 2149.214171
# Value of -logL = 50682.138858,  2-norm of score = 3850.792431
# Value of -logL = 50172.544422,  2-norm of score = 16513.986538
# Value of -logL = 50172.516508,  2-norm of score = 1156.703179
# Value of -logL = 49922.576802,  2-norm of score = 6230.674370
# Value of -logL = 49922.572684,  2-norm of score = 735.041278
# Value of -logL = 49879.987171,  2-norm of score = 670.043604
# Value of -logL = 49806.691122,  2-norm of score = 1369.968371
# Value of -logL = 49806.690897,  2-norm of score = 479.235506
# Value of -logL = 49772.123803,  2-norm of score = 453.236927
# Value of -logL = 49728.917865,  2-norm of score = 2019.386814
# Value of -logL = 49728.917418,  2-norm of score = 84.932007
# Value of -logL = 49727.805713,  2-norm of score = 68.143850
# Value of -logL = 49726.185904,  2-norm of score = 49.589055
# Value of -logL = 49725.779131,  2-norm of score = 24.414327
# Value of -logL = 49725.779131,  2-norm of score = 1.468944
# Value of -logL = 49725.778969,  2-norm of score = 1.141327
# Value of -logL = 49725.778750,  2-norm of score = 0.402138
# Value of -logL = 49725.778715,  2-norm of score = 0.108394
# Value of -logL = 49725.778711,  2-norm of score = 0.003927
# Value of -logL = 49725.778711,  2-norm of score = 0.000140
# Value of -logL = 49725.778711,  2-norm of score = 0.000000
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 49725.778711
#          Iterations: 37
#          Function evaluations: 165
#          Gradient evaluations: 191
#          Hessian evaluations: 38
#
# -------------------------------------------------------------------------------------------
# - TETRAD LOGIT ESTIMATION RESULTS                                                         -
# -------------------------------------------------------------------------------------------
#
# Number of agents,           N :             115
# Number of dyads,            n :           6,555
# Number of tetrads             :       6,913,340
# Number identifying tetrads    :         102,151
# Fraction identifying tetrads  :        0.014776
#
# -------------------------------------------------------------------------------------------
#
# Independent variable       Coef.    ( Std. Err.)     (0.95 Confid. Interval )
# -------------------------------------------------------------------------------------------
# Distance                  -0.002067 (  0.000328)     ( -0.002710 , -0.001424)
# Other blood relation       1.307596 (  0.293372)     (  0.732597 ,  1.882595)
# Cousin, etc.               2.209613 (  0.393581)     (  1.438208 ,  2.981019)
# Sibling, child, etc.       2.895174 (  0.393442)     (  2.124043 ,  3.666305)
#
# -------------------------------------------------------------------------------------------

# %% [markdown]
# ## Joint Fixed Effects Logit
# Graham (2017) also introduces a joint fixed effects estimator for link formation. This procedure estimates the coefficients on $W_{k,ij}$ for $k=1,...,K$ as well as individual specific degree heterogeneity parameters $A_{i}$ for $i=1,...,N$. The *dyad\_jfe\_logit()* function implements this estimator. By default it reports the iterated bias-corrected estimates described in the paper (but the uncorrected estimates are also returned by the function).

# %%
[beta_JFE, beta_JFE_BC, vcov_beta_JFE, A_JFE, success] = \
    netrics.dyad_jfe_logit(D, W, T=None, silent=False, W_names=cov_names, beta_sv=None)
# Out:
# -------------------------------------------------------------------------------------------
# - COMPUTE JOINT FIXED EFFECT MLEs                                                         -
# -------------------------------------------------------------------------------------------
# Value of c_logl = 1573.908738,  2-norm of c_score = 62611.044085
# Value of c_logl = 1547.376177,  2-norm of c_score = 48351.975248
# Value of c_logl = 1529.569133,  2-norm of c_score = 37055.111284
# Value of c_logl = 1517.970298,  2-norm of c_score = 28245.611814
# Value of c_logl = 1510.616125,  2-norm of c_score = 21451.154531
# Value of c_logl = 1506.059542,  2-norm of c_score = 16250.785285
# Value of c_logl = 1503.289015,  2-norm of c_score = 12291.724880
# Value of c_logl = 1501.628916,  2-norm of c_score = 9289.087256
# Value of c_logl = 1500.644547,  2-norm of c_score = 7018.123944
# Value of c_logl = 1500.064461,  2-norm of c_score = 5304.215799
# Value of c_logl = 1499.723062,  2-norm of c_score = 4013.098332
# Value of c_logl = 1499.521113,  2-norm of c_score = 3042.322471
# Value of c_logl = 1499.399888,  2-norm of c_score = 2314.241471
# Value of c_logl = 1499.324854,  2-norm of c_score = 1770.525245
# Value of c_logl = 1498.606942,  2-norm of c_score = 2257.517129
# Value of c_logl = 1498.536577,  2-norm of c_score = 1724.198891
# Value of c_logl = 1497.866883,  2-norm of c_score = 2222.491166
# Value of c_logl = 1497.799814,  2-norm of c_score = 1694.206388
# Value of c_logl = 1497.757260,  2-norm of c_score = 1301.461433
# Value of c_logl = 1496.258750,  2-norm of c_score = 2731.275756
# Value of c_logl = 1496.164290,  2-norm of c_score = 2066.538181
# Value of c_logl = 1496.108257,  2-norm of c_score = 1568.431123
# Value of c_logl = 1496.074096,  2-norm of c_score = 1196.493365
# Value of c_logl = 1495.748416,  2-norm of c_score = 1536.654751
# Value of c_logl = 1495.716105,  2-norm of c_score = 1170.305719
# Value of c_logl = 1495.695683,  2-norm of c_score = 898.185040
# Value of c_logl = 1494.970062,  2-norm of c_score = 1855.434239
# Value of c_logl = 1494.925901,  2-norm of c_score = 1403.211465
# Value of c_logl = 1494.899748,  2-norm of c_score = 1064.698517
# Value of c_logl = 1494.883786,  2-norm of c_score = 812.235476
# Value of c_logl = 1494.730646,  2-norm of c_score = 1029.768412
# Value of c_logl = 1494.715871,  2-norm of c_score = 784.638668
# Value of c_logl = 1494.574600,  2-norm of c_score = 1002.110333
# Value of c_logl = 1494.560774,  2-norm of c_score = 762.525146
# Value of c_logl = 1494.429199,  2-norm of c_score = 983.152653
# Value of c_logl = 1494.416067,  2-norm of c_score = 746.957450
# Value of c_logl = 1494.407920,  2-norm of c_score = 571.273766
# Value of c_logl = 1494.119094,  2-norm of c_score = 1179.938316
# Value of c_logl = 1494.101160,  2-norm of c_score = 891.030701
# Value of c_logl = 1494.090632,  2-norm of c_score = 674.794693
# Value of c_logl = 1494.084286,  2-norm of c_score = 513.439584
# Value of c_logl = 1493.868376,  2-norm of c_score = 1112.276585
# Value of c_logl = 1493.852622,  2-norm of c_score = 837.952174
# Value of c_logl = 1493.843520,  2-norm of c_score = 632.383275
# Value of c_logl = 1493.838184,  2-norm of c_score = 478.581783
# Value of c_logl = 1493.834969,  2-norm of c_score = 363.867359
# Value of c_logl = 1493.718279,  2-norm of c_score = 726.240347
# Value of c_logl = 1493.711459,  2-norm of c_score = 547.336638
# Value of c_logl = 1493.707488,  2-norm of c_score = 413.430793
# Value of c_logl = 1493.705122,  2-norm of c_score = 313.455090
# Value of c_logl = 1470.159592,  2-norm of c_score = 2603.848307
# Value of c_logl = 1470.070910,  2-norm of c_score = 1947.657740
# Value of c_logl = 1470.021679,  2-norm of c_score = 1457.471126
# Value of c_logl = 1469.994243,  2-norm of c_score = 1091.224398
# Value of c_logl = 1469.978889,  2-norm of c_score = 817.568888
# Value of c_logl = 1469.970250,  2-norm of c_score = 613.127445
# Value of c_logl = 1469.965350,  2-norm of c_score = 460.464644
# Value of c_logl = 1469.962534,  2-norm of c_score = 346.583327
# Value of c_logl = 1469.960879,  2-norm of c_score = 261.816882
# Value of c_logl = 1453.285473,  2-norm of c_score = 2459.154015
# Value of c_logl = 1453.206819,  2-norm of c_score = 1837.870211
# Value of c_logl = 1453.163125,  2-norm of c_score = 1374.773144
# Value of c_logl = 1453.138693,  2-norm of c_score = 1029.607303
# Value of c_logl = 1453.124908,  2-norm of c_score = 772.441114
# Value of c_logl = 1453.117021,  2-norm of c_score = 581.025503
# Value of c_logl = 1453.112401,  2-norm of c_score = 438.855083
# Value of c_logl = 1453.068439,  2-norm of c_score = 570.511056
# Value of c_logl = 1453.064036,  2-norm of c_score = 430.357658
# Value of c_logl = 1453.061381,  2-norm of c_score = 326.593696
# Value of c_logl = 1452.966599,  2-norm of c_score = 676.772524
# Value of c_logl = 1452.960643,  2-norm of c_score = 507.905655
# Value of c_logl = 1452.957216,  2-norm of c_score = 382.242295
# Value of c_logl = 1452.955191,  2-norm of c_score = 288.977782
# Value of c_logl = 1452.883663,  2-norm of c_score = 610.250185
# Value of c_logl = 1452.878857,  2-norm of c_score = 457.286368
# Value of c_logl = 1452.876117,  2-norm of c_score = 343.354259
# Value of c_logl = 1452.874525,  2-norm of c_score = 258.643774
# Value of c_logl = 1437.110886,  2-norm of c_score = 2507.058617
# Value of c_logl = 1437.029503,  2-norm of c_score = 1870.410916
# Value of c_logl = 1436.984471,  2-norm of c_score = 1396.641716
# Value of c_logl = 1436.959396,  2-norm of c_score = 1044.099618
# Value of c_logl = 1436.945312,  2-norm of c_score = 781.860493
# Value of c_logl = 1436.937296,  2-norm of c_score = 586.970203
# Value of c_logl = 1436.932632,  2-norm of c_score = 442.420620
# Value of c_logl = 1436.929809,  2-norm of c_score = 335.687771
# Value of c_logl = 1436.829430,  2-norm of c_score = 699.462918
# Value of c_logl = 1436.823091,  2-norm of c_score = 524.284045
# Value of c_logl = 1436.819450,  2-norm of c_score = 394.172754
# Value of c_logl = 1436.817297,  2-norm of c_score = 297.813508
# Value of c_logl = 1436.743491,  2-norm of c_score = 650.434036
# Value of c_logl = 1436.738071,  2-norm of c_score = 486.599080
# Value of c_logl = 1436.735000,  2-norm of c_score = 364.752864
# Value of c_logl = 1436.733229,  2-norm of c_score = 274.273565
# Value of c_logl = 1436.732175,  2-norm of c_score = 207.309467
# Value of c_logl = 1436.693475,  2-norm of c_score = 415.816563
# Value of c_logl = 1436.691239,  2-norm of c_score = 311.413777
# Value of c_logl = 1436.689954,  2-norm of c_score = 233.855657
# Value of c_logl = 1436.689196,  2-norm of c_score = 176.408024
# Value of c_logl = 1428.816079,  2-norm of c_score = 1274.252279
# Value of c_logl = 1428.795395,  2-norm of c_score = 950.769423
# Value of c_logl = 1428.783876,  2-norm of c_score = 710.153483
# Value of c_logl = 1428.777412,  2-norm of c_score = 531.245044
# Value of c_logl = 1428.773742,  2-norm of c_score = 398.335050
# Value of c_logl = 1428.771614,  2-norm of c_score = 299.780600
# Value of c_logl = 1428.770336,  2-norm of c_score = 227.000334
# Value of c_logl = 1428.724247,  2-norm of c_score = 466.414775
# Value of c_logl = 1428.721440,  2-norm of c_score = 349.275629
# Value of c_logl = 1428.719827,  2-norm of c_score = 262.331861
# Value of c_logl = 1428.718874,  2-norm of c_score = 197.994567
# Value of c_logl = 1428.684414,  2-norm of c_score = 406.758917
# Value of c_logl = 1428.682289,  2-norm of c_score = 304.245715
# Value of c_logl = 1428.681076,  2-norm of c_score = 228.110094
# Value of c_logl = 1428.680368,  2-norm of c_score = 171.699313
# Value of c_logl = 1421.341079,  2-norm of c_score = 1175.291640
# Value of c_logl = 1421.323547,  2-norm of c_score = 876.399547
# Value of c_logl = 1421.313793,  2-norm of c_score = 654.191539
# Value of c_logl = 1421.308327,  2-norm of c_score = 489.057007
# Value of c_logl = 1421.305229,  2-norm of c_score = 366.442127
# Value of c_logl = 1421.303437,  2-norm of c_score = 275.563487
# Value of c_logl = 1421.302363,  2-norm of c_score = 208.473635
# Value of c_logl = 1421.263854,  2-norm of c_score = 431.609461
# Value of c_logl = 1421.261461,  2-norm of c_score = 322.957734
# Value of c_logl = 1421.260090,  2-norm of c_score = 242.346593
# Value of c_logl = 1421.259284,  2-norm of c_score = 182.708541
# Value of c_logl = 1421.230371,  2-norm of c_score = 380.301041
# Value of c_logl = 1421.228523,  2-norm of c_score = 284.197271
# Value of c_logl = 1421.227472,  2-norm of c_score = 212.845560
# Value of c_logl = 1421.226862,  2-norm of c_score = 159.982609
# Value of c_logl = 1414.878246,  2-norm of c_score = 976.199096
# Value of c_logl = 1414.866199,  2-norm of c_score = 727.720038
# Value of c_logl = 1414.859493,  2-norm of c_score = 543.062176
# Value of c_logl = 1414.855733,  2-norm of c_score = 405.894857
# Value of c_logl = 1414.853598,  2-norm of c_score = 304.102361
# Value of c_logl = 1414.852360,  2-norm of c_score = 228.713576
# Value of c_logl = 1414.851614,  2-norm of c_score = 173.127256
# Value of c_logl = 1414.824414,  2-norm of c_score = 350.182182
# Value of c_logl = 1414.822834,  2-norm of c_score = 262.090414
# Value of c_logl = 1414.821925,  2-norm of c_score = 196.800510
# Value of c_logl = 1414.821383,  2-norm of c_score = 148.584039
# Value of c_logl = 1414.801413,  2-norm of c_score = 296.181350
# Value of c_logl = 1414.800285,  2-norm of c_score = 221.502174
# Value of c_logl = 1414.799637,  2-norm of c_score = 166.136356
# Value of c_logl = 1414.799254,  2-norm of c_score = 125.224060
# Value of c_logl = 1400.449162,  2-norm of c_score = 1946.696566
# Value of c_logl = 1400.400954,  2-norm of c_score = 1448.992578
# Value of c_logl = 1400.374368,  2-norm of c_score = 1079.333255
# Value of c_logl = 1400.359629,  2-norm of c_score = 804.809354
# Value of c_logl = 1400.351398,  2-norm of c_score = 601.011314
# Value of c_logl = 1400.346749,  2-norm of c_score = 449.840703
# Value of c_logl = 1400.344073,  2-norm of c_score = 337.898572
# Value of c_logl = 1400.342479,  2-norm of c_score = 255.312478
# Value of c_logl = 1400.287633,  2-norm of c_score = 555.407002
# Value of c_logl = 1400.283718,  2-norm of c_score = 414.889476
# Value of c_logl = 1400.281499,  2-norm of c_score = 310.668824
# Value of c_logl = 1400.280215,  2-norm of c_score = 233.520198
# Value of c_logl = 1400.279444,  2-norm of c_score = 176.655824
# Value of c_logl = 1400.252019,  2-norm of c_score = 369.484101
# Value of c_logl = 1400.250278,  2-norm of c_score = 276.250472
# Value of c_logl = 1400.249282,  2-norm of c_score = 207.148684
# Value of c_logl = 1400.248697,  2-norm of c_score = 156.078041
# Value of c_logl = 1400.228507,  2-norm of c_score = 339.538839
# Value of c_logl = 1400.227051,  2-norm of c_score = 253.408630
# Value of c_logl = 1400.226228,  2-norm of c_score = 189.497561
# Value of c_logl = 1400.225756,  2-norm of c_score = 142.150876
# Value of c_logl = 1400.225475,  2-norm of c_score = 107.197374
# Value of c_logl = 1400.215034,  2-norm of c_score = 210.264640
# Value of c_logl = 1400.214467,  2-norm of c_score = 157.149253
# Value of c_logl = 1400.214142,  2-norm of c_score = 117.799153
# Value of c_logl = 1400.213949,  2-norm of c_score = 88.748721
# Value of c_logl = 1392.355942,  2-norm of c_score = 389.579145
# Value of c_logl = 1392.354039,  2-norm of c_score = 290.431011
# Value of c_logl = 1392.352973,  2-norm of c_score = 216.831588
# Value of c_logl = 1392.352369,  2-norm of c_score = 162.251053
# Value of c_logl = 1392.352020,  2-norm of c_score = 121.855920
# Value of c_logl = 1392.340075,  2-norm of c_score = 268.825937
# Value of c_logl = 1392.339168,  2-norm of c_score = 200.357967
# Value of c_logl = 1392.338659,  2-norm of c_score = 149.539014
# Value of c_logl = 1392.338369,  2-norm of c_score = 111.863455
# Value of c_logl = 1392.338201,  2-norm of c_score = 83.998888
# Value of c_logl = 1385.459964,  2-norm of c_score = 259.758425
# Value of c_logl = 1385.459118,  2-norm of c_score = 193.680822
# Value of c_logl = 1385.458642,  2-norm of c_score = 144.658330
# Value of c_logl = 1385.458370,  2-norm of c_score = 108.338166
# Value of c_logl = 1385.458211,  2-norm of c_score = 81.505136
# Value of c_logl = 1385.452325,  2-norm of c_score = 162.415707
# Value of c_logl = 1385.451990,  2-norm of c_score = 121.217446
# Value of c_logl = 1385.451800,  2-norm of c_score = 90.689706
# Value of c_logl = 1385.451688,  2-norm of c_score = 68.129774
# Value of c_logl = 1380.830770,  2-norm of c_score = 178.660150
# Value of c_logl = 1380.830368,  2-norm of c_score = 133.290059
# Value of c_logl = 1380.830140,  2-norm of c_score = 99.661559
# Value of c_logl = 1380.830008,  2-norm of c_score = 74.788858
# Value of c_logl = 1380.825175,  2-norm of c_score = 151.467612
# Value of c_logl = 1380.824886,  2-norm of c_score = 112.900548
# Value of c_logl = 1380.824722,  2-norm of c_score = 84.308892
# Value of c_logl = 1380.824628,  2-norm of c_score = 63.153613
# Value of c_logl = 1376.934439,  2-norm of c_score = 193.483334
# Value of c_logl = 1376.933972,  2-norm of c_score = 144.132482
# Value of c_logl = 1376.933710,  2-norm of c_score = 107.527549
# Value of c_logl = 1376.933561,  2-norm of c_score = 80.408305
# Value of c_logl = 1376.933474,  2-norm of c_score = 60.364846
# Value of c_logl = 1373.401241,  2-norm of c_score = 167.368896
# Value of c_logl = 1373.400890,  2-norm of c_score = 124.776706
# Value of c_logl = 1373.400692,  2-norm of c_score = 93.208706
# Value of c_logl = 1373.400579,  2-norm of c_score = 69.851013
# Value of c_logl = 1373.400511,  2-norm of c_score = 52.630539
# Value of c_logl = 1373.398003,  2-norm of c_score = 103.413011
# Value of c_logl = 1373.397867,  2-norm of c_score = 77.211579
# Value of c_logl = 1373.397789,  2-norm of c_score = 57.824622
# Value of c_logl = 1373.397743,  2-norm of c_score = 43.531825
# Value of c_logl = 1371.468738,  2-norm of c_score = 152.866776
# Value of c_logl = 1371.468446,  2-norm of c_score = 113.937189
# Value of c_logl = 1371.468281,  2-norm of c_score = 85.085908
# Value of c_logl = 1371.468187,  2-norm of c_score = 63.738344
# Value of c_logl = 1371.468131,  2-norm of c_score = 47.997029
# Value of c_logl = 1371.466064,  2-norm of c_score = 95.158174
# Value of c_logl = 1371.465949,  2-norm of c_score = 71.018380
# Value of c_logl = 1371.465883,  2-norm of c_score = 53.154888
# Value of c_logl = 1371.465844,  2-norm of c_score = 39.979675
# Value of c_logl = 1369.853638,  2-norm of c_score = 142.066542
# Value of c_logl = 1369.853386,  2-norm of c_score = 105.852495
# Value of c_logl = 1369.853244,  2-norm of c_score = 79.013647
# Value of c_logl = 1369.853163,  2-norm of c_score = 59.152193
# Value of c_logl = 1369.853116,  2-norm of c_score = 44.499592
# Value of c_logl = 1369.851371,  2-norm of c_score = 89.875340
# Value of c_logl = 1369.851269,  2-norm of c_score = 67.030675
# Value of c_logl = 1369.851210,  2-norm of c_score = 50.119775
# Value of c_logl = 1369.851177,  2-norm of c_score = 37.635813
# Value of c_logl = 1368.448656,  2-norm of c_score = 141.008453
# Value of c_logl = 1368.448409,  2-norm of c_score = 105.003486
# Value of c_logl = 1368.448270,  2-norm of c_score = 78.314795
# Value of c_logl = 1368.448191,  2-norm of c_score = 58.554674
# Value of c_logl = 1368.448146,  2-norm of c_score = 43.959076
# Value of c_logl = 1368.446530,  2-norm of c_score = 93.528861
# Value of c_logl = 1368.446420,  2-norm of c_score = 69.661229
# Value of c_logl = 1368.446358,  2-norm of c_score = 51.977946
# Value of c_logl = 1368.446323,  2-norm of c_score = 38.898446
# Value of c_logl = 1368.446302,  2-norm of c_score = 29.258560
# Value of c_logl = 1367.571192,  2-norm of c_score = 105.692726
# Value of c_logl = 1367.571053,  2-norm of c_score = 78.731968
# Value of c_logl = 1367.570974,  2-norm of c_score = 58.756416
# Value of c_logl = 1367.570930,  2-norm of c_score = 43.978864
# Value of c_logl = 1367.570903,  2-norm of c_score = 33.081823
# Value of c_logl = 1367.569922,  2-norm of c_score = 65.407026
# Value of c_logl = 1367.569868,  2-norm of c_score = 48.784585
# Value of c_logl = 1367.569837,  2-norm of c_score = 36.487232
# Value of c_logl = 1367.569819,  2-norm of c_score = 27.418670
# Value of c_logl = 1366.809883,  2-norm of c_score = 98.329139
# Value of c_logl = 1366.809762,  2-norm of c_score = 73.229544
# Value of c_logl = 1366.809694,  2-norm of c_score = 54.632664
# Value of c_logl = 1366.809656,  2-norm of c_score = 40.873306
# Value of c_logl = 1366.809633,  2-norm of c_score = 30.723213
# Value of c_logl = 1366.808799,  2-norm of c_score = 61.727115
# Value of c_logl = 1366.808751,  2-norm of c_score = 46.016041
# Value of c_logl = 1366.808724,  2-norm of c_score = 34.389432
# Value of c_logl = 1366.808708,  2-norm of c_score = 25.808989
# Value of c_logl = 1366.145500,  2-norm of c_score = 93.981554
# Value of c_logl = 1366.145390,  2-norm of c_score = 69.965650
# Value of c_logl = 1366.145328,  2-norm of c_score = 52.169712
# Value of c_logl = 1366.145293,  2-norm of c_score = 38.998803
# Value of c_logl = 1366.145273,  2-norm of c_score = 29.275226
# Value of c_logl = 1366.144539,  2-norm of c_score = 60.772633
# Value of c_logl = 1366.144493,  2-norm of c_score = 45.264460
# Value of c_logl = 1366.144467,  2-norm of c_score = 33.781389
# Value of c_logl = 1366.144452,  2-norm of c_score = 25.295701
# Value of c_logl = 1365.525984,  2-norm of c_score = 96.566843
# Value of c_logl = 1365.525869,  2-norm of c_score = 71.844266
# Value of c_logl = 1365.525804,  2-norm of c_score = 53.519853
# Value of c_logl = 1365.525768,  2-norm of c_score = 39.949485
# Value of c_logl = 1365.525747,  2-norm of c_score = 29.917098
# Value of c_logl = 1365.525734,  2-norm of c_score = 22.527576
# Value of c_logl = 1365.525274,  2-norm of c_score = 44.288324
# Value of c_logl = 1365.525249,  2-norm of c_score = 33.043511
# Value of c_logl = 1365.525234,  2-norm of c_score = 24.730574
# Value of c_logl = 1365.525226,  2-norm of c_score = 18.607968
# Value of c_logl = 1365.171331,  2-norm of c_score = 61.156518
# Value of c_logl = 1365.171284,  2-norm of c_score = 45.562795
# Value of c_logl = 1365.171257,  2-norm of c_score = 34.017112
# Value of c_logl = 1365.171242,  2-norm of c_score = 25.484678
# Value of c_logl = 1365.171233,  2-norm of c_score = 19.204643
# Value of c_logl = 1365.170892,  2-norm of c_score = 37.045344
# Value of c_logl = 1365.170874,  2-norm of c_score = 27.653657
# Value of c_logl = 1365.170864,  2-norm of c_score = 20.715391
# Value of c_logl = 1364.759797,  2-norm of c_score = 77.005835
# Value of c_logl = 1364.759723,  2-norm of c_score = 57.291771
# Value of c_logl = 1364.759682,  2-norm of c_score = 42.682645
# Value of c_logl = 1364.759659,  2-norm of c_score = 31.866406
# Value of c_logl = 1364.759646,  2-norm of c_score = 23.872960
# Value of c_logl = 1364.759638,  2-norm of c_score = 17.988819
# Value of c_logl = 1364.759345,  2-norm of c_score = 35.747600
# Value of c_logl = 1364.759328,  2-norm of c_score = 26.672758
# Value of c_logl = 1364.759319,  2-norm of c_score = 19.965082
# Value of c_logl = 1364.759314,  2-norm of c_score = 15.025580
# Value of c_logl = 1364.530548,  2-norm of c_score = 50.601951
# Value of c_logl = 1364.530516,  2-norm of c_score = 37.693250
# Value of c_logl = 1364.530498,  2-norm of c_score = 28.135981
# Value of c_logl = 1364.530487,  2-norm of c_score = 21.072551
# Value of c_logl = 1364.530481,  2-norm of c_score = 15.872008
# Value of c_logl = 1364.530254,  2-norm of c_score = 31.643542
# Value of c_logl = 1364.530241,  2-norm of c_score = 23.604992
# Value of c_logl = 1364.530234,  2-norm of c_score = 17.662786
# Value of c_logl = 1364.530229,  2-norm of c_score = 13.285841
# Value of c_logl = 1364.351984,  2-norm of c_score = 46.210525
# Value of c_logl = 1364.351957,  2-norm of c_score = 34.412903
# Value of c_logl = 1364.351942,  2-norm of c_score = 25.677335
# Value of c_logl = 1364.351934,  2-norm of c_score = 19.219481
# Value of c_logl = 1364.351929,  2-norm of c_score = 14.461711
# Value of c_logl = 1364.351743,  2-norm of c_score = 29.309461
# Value of c_logl = 1364.351732,  2-norm of c_score = 21.850565
# Value of c_logl = 1364.351726,  2-norm of c_score = 16.334409
# Value of c_logl = 1364.351722,  2-norm of c_score = 12.267100
# Value of c_logl = 1364.202428,  2-norm of c_score = 43.458759
# Value of c_logl = 1364.202404,  2-norm of c_score = 32.349791
# Value of c_logl = 1364.202391,  2-norm of c_score = 24.122356
# Value of c_logl = 1364.202384,  2-norm of c_score = 18.037186
# Value of c_logl = 1364.202379,  2-norm of c_score = 13.548985
# Value of c_logl = 1364.202222,  2-norm of c_score = 28.425392
# Value of c_logl = 1364.202212,  2-norm of c_score = 21.169797
# Value of c_logl = 1364.202206,  2-norm of c_score = 15.799974
# Value of c_logl = 1364.202203,  2-norm of c_score = 11.834050
# Value of c_logl = 1364.202081,  2-norm of c_score = 23.746846
# Value of c_logl = 1364.202074,  2-norm of c_score = 17.672125
# Value of c_logl = 1364.202070,  2-norm of c_score = 13.176046
# Value of c_logl = 1364.202067,  2-norm of c_score = 9.855131
# Value of c_logl = 1364.106171,  2-norm of c_score = 38.190353
# Value of c_logl = 1364.106153,  2-norm of c_score = 28.396128
# Value of c_logl = 1364.106143,  2-norm of c_score = 21.138912
# Value of c_logl = 1364.106137,  2-norm of c_score = 15.766068
# Value of c_logl = 1364.106134,  2-norm of c_score = 11.794978
# Value of c_logl = 1364.106132,  2-norm of c_score = 8.870405
# Value of c_logl = 1364.026383,  2-norm of c_score = 24.501135
# Value of c_logl = 1364.026375,  2-norm of c_score = 18.260636
# Value of c_logl = 1364.026371,  2-norm of c_score = 13.644183
# Value of c_logl = 1364.026368,  2-norm of c_score = 10.237640
# Value of c_logl = 1364.026279,  2-norm of c_score = 21.394651
# Value of c_logl = 1364.026273,  2-norm of c_score = 15.926823
# Value of c_logl = 1364.026270,  2-norm of c_score = 11.879888
# Value of c_logl = 1364.026268,  2-norm of c_score = 8.890421
# Value of c_logl = 1363.950059,  2-norm of c_score = 32.310612
# Value of c_logl = 1363.950046,  2-norm of c_score = 24.029719
# Value of c_logl = 1363.950039,  2-norm of c_score = 17.894676
# Value of c_logl = 1363.950035,  2-norm of c_score = 13.353518
# Value of c_logl = 1363.950032,  2-norm of c_score = 9.998212
# Value of c_logl = 1363.950031,  2-norm of c_score = 7.528681
# Value of c_logl = 1363.949979,  2-norm of c_score = 14.679771
# Value of c_logl = 1363.949976,  2-norm of c_score = 10.951056
# Value of c_logl = 1363.949975,  2-norm of c_score = 8.196506
# Value of c_logl = 1363.949917,  2-norm of c_score = 16.652227
# Value of c_logl = 1363.949913,  2-norm of c_score = 12.386805
# Value of c_logl = 1363.949911,  2-norm of c_score = 9.229404
# Value of c_logl = 1363.949910,  2-norm of c_score = 6.896329
# Value of c_logl = 1363.949910,  2-norm of c_score = 5.178928
# Value of c_logl = 1363.849483,  2-norm of c_score = 47.890441
# Value of c_logl = 1363.849455,  2-norm of c_score = 35.571528
# Value of c_logl = 1363.849439,  2-norm of c_score = 26.439359
# Value of c_logl = 1363.849431,  2-norm of c_score = 19.671548
# Value of c_logl = 1363.849426,  2-norm of c_score = 14.658732
# Value of c_logl = 1363.849423,  2-norm of c_score = 10.949802
# Value of c_logl = 1363.849422,  2-norm of c_score = 8.211580
# Value of c_logl = 1363.849421,  2-norm of c_score = 6.199693
# Value of c_logl = 1363.849385,  2-norm of c_score = 12.253701
# Value of c_logl = 1363.849383,  2-norm of c_score = 9.148690
# Value of c_logl = 1363.849382,  2-norm of c_score = 6.855927
# Value of c_logl = 1363.849343,  2-norm of c_score = 14.876690
# Value of c_logl = 1363.849341,  2-norm of c_score = 11.065401
# Value of c_logl = 1363.849339,  2-norm of c_score = 8.243269
# Value of c_logl = 1363.849338,  2-norm of c_score = 6.156443
# Value of c_logl = 1363.849338,  2-norm of c_score = 4.617751
# Value of c_logl = 1363.827852,  2-norm of c_score = 8.574799
# Value of c_logl = 1363.827851,  2-norm of c_score = 6.399415
# Value of c_logl = 1363.827851,  2-norm of c_score = 4.793570
# Value of c_logl = 1363.805479,  2-norm of c_score = 12.356477
# Value of c_logl = 1363.805477,  2-norm of c_score = 9.199758
# Value of c_logl = 1363.805476,  2-norm of c_score = 6.863406
# Value of c_logl = 1363.805476,  2-norm of c_score = 5.137355
# Value of c_logl = 1363.805475,  2-norm of c_score = 3.867143
# Value of c_logl = 1363.805461,  2-norm of c_score = 7.365052
# Value of c_logl = 1363.805461,  2-norm of c_score = 5.494869
# Value of c_logl = 1363.805460,  2-norm of c_score = 4.114040
# Value of c_logl = 1363.789013,  2-norm of c_score = 12.960983
# Value of c_logl = 1363.789011,  2-norm of c_score = 9.642427
# Value of c_logl = 1363.789009,  2-norm of c_score = 7.184906
# Value of c_logl = 1363.789009,  2-norm of c_score = 5.367228
# Value of c_logl = 1363.789008,  2-norm of c_score = 4.026161
# Value of c_logl = 1363.788994,  2-norm of c_score = 8.321602
# Value of c_logl = 1363.788994,  2-norm of c_score = 6.194251
# Value of c_logl = 1363.788993,  2-norm of c_score = 4.620153
# Value of c_logl = 1363.788993,  2-norm of c_score = 3.457830
# Value of c_logl = 1363.777339,  2-norm of c_score = 10.973337
# Value of c_logl = 1363.777337,  2-norm of c_score = 8.162666
# Value of c_logl = 1363.777336,  2-norm of c_score = 6.081204
# Value of c_logl = 1363.777336,  2-norm of c_score = 4.541580
# Value of c_logl = 1363.777336,  2-norm of c_score = 3.405495
# Value of c_logl = 1363.777326,  2-norm of c_score = 6.980975
# Value of c_logl = 1363.777325,  2-norm of c_score = 5.195889
# Value of c_logl = 1363.777325,  2-norm of c_score = 3.875098
# Value of c_logl = 1363.777324,  2-norm of c_score = 2.899887
# Value of c_logl = 1363.769078,  2-norm of c_score = 9.013450
# Value of c_logl = 1363.769077,  2-norm of c_score = 6.704833
# Value of c_logl = 1363.769077,  2-norm of c_score = 4.995298
# Value of c_logl = 1363.769076,  2-norm of c_score = 3.730956
# Value of c_logl = 1363.769076,  2-norm of c_score = 2.798259
# Value of c_logl = 1363.769069,  2-norm of c_score = 5.581329
# Value of c_logl = 1363.769069,  2-norm of c_score = 4.155508
# Value of c_logl = 1363.769069,  2-norm of c_score = 3.100959
# Value of c_logl = 1363.769068,  2-norm of c_score = 2.322976
# Value of c_logl = 1363.763664,  2-norm of c_score = 6.806025
# Value of c_logl = 1363.763663,  2-norm of c_score = 5.064971
# Value of c_logl = 1363.763663,  2-norm of c_score = 3.776247
# Value of c_logl = 1363.763663,  2-norm of c_score = 2.823912
# Value of c_logl = 1363.763663,  2-norm of c_score = 2.122625
# Value of c_logl = 1363.759084,  2-norm of c_score = 5.402242
# Value of c_logl = 1363.759084,  2-norm of c_score = 4.026753
# Value of c_logl = 1363.759083,  2-norm of c_score = 3.009798
# Value of c_logl = 1363.759083,  2-norm of c_score = 2.260110
# Value of c_logl = 1363.759079,  2-norm of c_score = 4.532027
# Value of c_logl = 1363.759078,  2-norm of c_score = 3.375713
# Value of c_logl = 1363.759078,  2-norm of c_score = 2.520685
# Value of c_logl = 1363.759078,  2-norm of c_score = 1.890183
# Value of c_logl = 1363.755498,  2-norm of c_score = 5.791269
# Value of c_logl = 1363.755497,  2-norm of c_score = 4.310366
# Value of c_logl = 1363.755497,  2-norm of c_score = 3.214215
# Value of c_logl = 1363.755497,  2-norm of c_score = 2.404185
# Value of c_logl = 1363.755497,  2-norm of c_score = 1.807675
# Value of c_logl = 1363.755494,  2-norm of c_score = 3.470633
# Value of c_logl = 1363.755494,  2-norm of c_score = 2.587730
# Value of c_logl = 1363.755493,  2-norm of c_score = 1.935576
# Value of c_logl = 1363.751883,  2-norm of c_score = 6.080409
# Value of c_logl = 1363.751882,  2-norm of c_score = 4.522236
# Value of c_logl = 1363.751882,  2-norm of c_score = 3.368262
# Value of c_logl = 1363.751882,  2-norm of c_score = 2.514563
# Value of c_logl = 1363.751882,  2-norm of c_score = 1.884398
# Value of c_logl = 1363.751879,  2-norm of c_score = 3.946696
# Value of c_logl = 1363.751878,  2-norm of c_score = 2.936197
# Value of c_logl = 1363.751878,  2-norm of c_score = 2.188310
# Value of c_logl = 1363.751878,  2-norm of c_score = 1.635748
# Value of c_logl = 1363.751878,  2-norm of c_score = 1.229021
# Value of c_logl = 1363.746420,  2-norm of c_score = 10.485998
# Value of c_logl = 1363.746418,  2-norm of c_score = 7.788131
# Value of c_logl = 1363.746418,  2-norm of c_score = 5.788436
# Value of c_logl = 1363.746417,  2-norm of c_score = 4.306685
# Value of c_logl = 1363.746417,  2-norm of c_score = 3.209350
# Value of c_logl = 1363.746417,  2-norm of c_score = 2.397601
# Value of c_logl = 1363.746417,  2-norm of c_score = 1.798463
# Value of c_logl = 1363.746417,  2-norm of c_score = 1.358443
# Value of c_logl = 1363.746415,  2-norm of c_score = 2.709248
# Value of c_logl = 1363.746415,  2-norm of c_score = 2.022676
# Value of c_logl = 1363.746415,  2-norm of c_score = 1.515738
# Value of c_logl = 1363.746415,  2-norm of c_score = 1.143113
# Value of c_logl = 1363.746414,  2-norm of c_score = 2.236354
# Value of c_logl = 1363.746413,  2-norm of c_score = 1.669071
# Value of c_logl = 1363.746413,  2-norm of c_score = 1.250243
# Value of c_logl = 1363.746412,  2-norm of c_score = 2.618732
# Value of c_logl = 1363.746412,  2-norm of c_score = 1.947887
# Value of c_logl = 1363.746412,  2-norm of c_score = 1.451355
# Value of c_logl = 1363.746412,  2-norm of c_score = 1.084454
# Value of c_logl = 1363.746412,  2-norm of c_score = 0.814302
# Value of c_logl = 1363.744017,  2-norm of c_score = 4.869298
# Value of c_logl = 1363.744017,  2-norm of c_score = 3.617080
# Value of c_logl = 1363.744017,  2-norm of c_score = 2.689035
# Value of c_logl = 1363.744017,  2-norm of c_score = 2.001519
# Value of c_logl = 1363.744017,  2-norm of c_score = 1.492582
# Value of c_logl = 1363.744017,  2-norm of c_score = 1.116411
# Value of c_logl = 1363.744017,  2-norm of c_score = 0.839255
# Value of c_logl = 1363.744016,  2-norm of c_score = 1.723088
# Value of c_logl = 1363.744016,  2-norm of c_score = 1.283666
# Value of c_logl = 1363.744016,  2-norm of c_score = 0.958716
# Value of c_logl = 1363.744016,  2-norm of c_score = 0.719051
# Value of c_logl = 1363.744016,  2-norm of c_score = 1.407854
# Value of c_logl = 1363.744016,  2-norm of c_score = 1.048354
# Value of c_logl = 1363.744016,  2-norm of c_score = 0.782554
# Value of c_logl = 1363.744016,  2-norm of c_score = 0.586591
# Value of c_logl = 1363.742830,  2-norm of c_score = 6.945058
# Value of c_logl = 1363.742830,  2-norm of c_score = 5.156927
# Value of c_logl = 1363.742829,  2-norm of c_score = 3.831428
# Value of c_logl = 1363.742829,  2-norm of c_score = 2.849077
# Value of c_logl = 1363.742829,  2-norm of c_score = 2.121329
# Value of c_logl = 1363.742829,  2-norm of c_score = 1.582607
# Value of c_logl = 1363.742829,  2-norm of c_score = 1.184409
# Value of c_logl = 1363.742829,  2-norm of c_score = 0.891004
# Value of c_logl = 1363.742828,  2-norm of c_score = 1.967363
# Value of c_logl = 1363.742828,  2-norm of c_score = 1.464952
# Value of c_logl = 1363.742828,  2-norm of c_score = 1.093103
# Value of c_logl = 1363.742828,  2-norm of c_score = 0.818347
# Value of c_logl = 1363.742828,  2-norm of c_score = 0.616056
# Value of c_logl = 1363.742828,  2-norm of c_score = 1.287591
# Value of c_logl = 1363.742828,  2-norm of c_score = 0.959538
# Value of c_logl = 1363.742828,  2-norm of c_score = 0.716940
# Value of c_logl = 1363.742828,  2-norm of c_score = 0.538003
# Value of c_logl = 1363.742827,  2-norm of c_score = 1.127169
# Value of c_logl = 1363.742827,  2-norm of c_score = 0.838980
# Value of c_logl = 1363.742827,  2-norm of c_score = 0.625741
# Value of c_logl = 1363.742827,  2-norm of c_score = 0.468273
# Value of c_logl = 1363.742619,  2-norm of c_score = 1.132940
# Value of c_logl = 1363.742619,  2-norm of c_score = 0.840251
# Value of c_logl = 1363.742619,  2-norm of c_score = 0.623403
# Value of c_logl = 1363.742619,  2-norm of c_score = 0.462855
# Value of c_logl = 1363.742619,  2-norm of c_score = 0.344149
# Value of c_logl = 1363.742504,  2-norm of c_score = 1.842581
# Value of c_logl = 1363.742504,  2-norm of c_score = 1.368623
# Value of c_logl = 1363.742504,  2-norm of c_score = 1.017380
# Value of c_logl = 1363.742504,  2-norm of c_score = 0.757192
# Value of c_logl = 1363.742504,  2-norm of c_score = 0.564615
# Value of c_logl = 1363.742504,  2-norm of c_score = 0.422317
# Value of c_logl = 1363.742504,  2-norm of c_score = 0.317540
# Value of c_logl = 1363.742504,  2-norm of c_score = 0.607322
# Value of c_logl = 1363.742504,  2-norm of c_score = 0.452834
# Value of c_logl = 1363.742504,  2-norm of c_score = 0.338737
# Value of c_logl = 1363.742393,  2-norm of c_score = 0.263778
# Value of c_logl = 1363.742210,  2-norm of c_score = 2.451335
# Value of c_logl = 1363.742210,  2-norm of c_score = 1.820300
# Value of c_logl = 1363.742210,  2-norm of c_score = 1.352546
# Value of c_logl = 1363.742210,  2-norm of c_score = 1.005905
# Value of c_logl = 1363.742210,  2-norm of c_score = 0.749132
# Value of c_logl = 1363.742210,  2-norm of c_score = 0.559090
# Value of c_logl = 1363.742210,  2-norm of c_score = 0.418675
# Value of c_logl = 1363.742210,  2-norm of c_score = 0.315299
# Value of c_logl = 1363.742210,  2-norm of c_score = 0.674501
# Value of c_logl = 1363.742210,  2-norm of c_score = 0.502593
# Value of c_logl = 1363.742210,  2-norm of c_score = 0.375429
# Value of c_logl = 1363.742210,  2-norm of c_score = 0.281578
# Value of c_logl = 1363.742210,  2-norm of c_score = 0.631347
# Value of c_logl = 1363.742210,  2-norm of c_score = 0.469575
# Value of c_logl = 1363.742210,  2-norm of c_score = 0.349787
# Value of c_logl = 1363.742210,  2-norm of c_score = 0.261194
# Value of c_logl = 1363.742210,  2-norm of c_score = 0.195833
# Value of c_logl = 1363.742210,  2-norm of c_score = 0.392458
# Value of c_logl = 1363.742210,  2-norm of c_score = 0.292131
# Value of c_logl = 1363.742210,  2-norm of c_score = 0.217925
# Value of c_logl = 1363.742210,  2-norm of c_score = 0.163171
# Value of c_logl = 1363.742184,  2-norm of c_score = 0.154800
# Value of c_logl = 1363.742138,  2-norm of c_score = 1.219260
# Value of c_logl = 1363.742138,  2-norm of c_score = 0.905464
# Value of c_logl = 1363.742138,  2-norm of c_score = 0.672874
# Value of c_logl = 1363.742138,  2-norm of c_score = 0.500523
# Value of c_logl = 1363.742138,  2-norm of c_score = 0.372876
# Value of c_logl = 1363.742138,  2-norm of c_score = 0.278434
# Value of c_logl = 1363.742138,  2-norm of c_score = 0.208700
# Value of c_logl = 1363.742138,  2-norm of c_score = 0.157437
# Value of c_logl = 1363.742138,  2-norm of c_score = 0.318868
# Value of c_logl = 1363.742138,  2-norm of c_score = 0.237893
# Value of c_logl = 1363.742138,  2-norm of c_score = 0.178070
# Value of c_logl = 1363.742138,  2-norm of c_score = 0.134036
# Value of c_logl = 1363.742138,  2-norm of c_score = 0.268083
# Value of c_logl = 1363.742138,  2-norm of c_score = 0.199869
# Value of c_logl = 1363.742138,  2-norm of c_score = 0.149461
# Value of c_logl = 1363.742138,  2-norm of c_score = 0.112339
# Value of c_logl = 1363.742125,  2-norm of c_score = 0.330654
# Value of c_logl = 1363.742125,  2-norm of c_score = 0.245129
# Value of c_logl = 1363.742125,  2-norm of c_score = 0.181764
# Value of c_logl = 1363.742125,  2-norm of c_score = 0.134849
# Value of c_logl = 1363.742125,  2-norm of c_score = 0.100160
# Value of c_logl = 1363.742115,  2-norm of c_score = 0.373236
# Value of c_logl = 1363.742115,  2-norm of c_score = 0.277422
# Value of c_logl = 1363.742115,  2-norm of c_score = 0.206445
# Value of c_logl = 1363.742115,  2-norm of c_score = 0.153908
# Value of c_logl = 1363.742115,  2-norm of c_score = 0.115083
# Value of c_logl = 1363.742115,  2-norm of c_score = 0.249428
# Value of c_logl = 1363.742115,  2-norm of c_score = 0.185358
# Value of c_logl = 1363.742115,  2-norm of c_score = 0.137912
# Value of c_logl = 1363.742115,  2-norm of c_score = 0.102815
# Value of c_logl = 1363.742106,  2-norm of c_score = 0.110315
# Value of c_logl = 1363.742106,  2-norm of c_score = 0.082246
# Value of c_logl = 1363.742099,  2-norm of c_score = 0.353739
# Value of c_logl = 1363.742099,  2-norm of c_score = 0.262763
# Value of c_logl = 1363.742099,  2-norm of c_score = 0.195345
# Value of c_logl = 1363.742099,  2-norm of c_score = 0.145407
# Value of c_logl = 1363.742099,  2-norm of c_score = 0.108448
# Value of c_logl = 1363.742099,  2-norm of c_score = 0.081143
# Value of c_logl = 1363.742093,  2-norm of c_score = 0.062168
# Value of c_logl = 1363.742085,  2-norm of c_score = 1.283794
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.953074
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.707906
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.526187
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.391535
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.291814
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.218039
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.163575
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.123554
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.261771
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.195272
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.146110
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.109872
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.141674
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.106422
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.138622
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.103996
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.137318
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.102863
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.138432
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.103519
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.143238
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.106903
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.080056
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.107308
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.080230
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.110043
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.082127
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.116285
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.086620
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.064673
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.088713
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.066130
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.092440
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.068802
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.143588
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.106527
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.079054
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.058690
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.043602
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.125840
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.093448
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.069440
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.051651
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.150085
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.111506
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.082915
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.061735
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.046058
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.066884
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.049794
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.076698
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.056983
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.042374
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.044809
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.033224
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.053120
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.039401
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.029230
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.021691
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.021155
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.009621
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.010578
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.007860
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.005846
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.006833
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.005081
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.005656
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.006369
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.004731
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.005196
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.003859
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.004017
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.002982
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.003749
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.002784
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1363.742084
#          Iterations: 646
#          Function evaluations: 1173
#          Gradient evaluations: 1818
#          Hessian evaluations: 647
#
# -------------------------------------------------------------------------------------------
# - BIAS CORRECTED JOINT FIXED EFFECTS LOGIT ESTIMATION RESULTS                             -
# -------------------------------------------------------------------------------------------
#
# Number of agents,           N :             115
# Number of dyads,            n :           6,555
#
# -------------------------------------------------------------------------------------------
#
# Independent variable       Coef.    ( Std. Err.)     (0.95 Confid. Interval )
# -------------------------------------------------------------------------------------------
# Distance                  -0.002001 (  0.000184)     ( -0.002361 , -0.001640)
# Other blood relation       1.362709 (  0.189174)     (  0.991935 ,  1.733484)
# Cousin, etc.               1.856891 (  0.244763)     (  1.377165 ,  2.336617)
# Sibling, child, etc.       2.875524 (  0.273332)     (  2.339804 ,  3.411244)
# Age difference            -0.004631 (  0.003642)     ( -0.011770 ,  0.002508)
# Same religion              0.466867 (  0.083760)     (  0.302700 ,  0.631034)
# Same clan                  0.294969 (  0.138685)     (  0.023152 ,  0.566786)
# Same education level       0.417187 (  0.117280)     (  0.187322 ,  0.647052)
# Adjacent wealth class      0.038704 (  0.100513)     ( -0.158297 ,  0.235706)
# Non-adjacent wealth class -0.030166 (  0.113675)     ( -0.252964 ,  0.192632)
#
# -------------------------------------------------------------------------------------------

# %% [markdown]
# It takes some time for *dyad\_jfe\_logit()* to converge. This reflects the sparsity of the Nyakatoke network and the consequent difficulty of estimating the household degree heterogeneity effects.
# <br>
# <br>
# Relative to the *tetrad\_logit()* results, the joint estimator suggests sorting by religion and clan. In Monte Carlo experiments I have found that the joint estimator -- particularly the bias correction step -- can work very poorly in networks like the Nyakatoke one (i.e., in networks that are sparse such that many agents have only a few links). In such settings the $A_{i}$ for $i=1,...,N$ may be _very_ imprecisely estimated and this can effect the quality of the common parameter estimates as well.
# <br>
# <br>
# For reference we can look at the joint coefficient estimates prior to bias correction using the *print\_coef()* utility included in the **netrics** package. These point estimates are closer to the *tetrad\_logit()* ones than their bias-corrected counterparts. This suggests, that in this particular example, bias-correction may be doing more harm that good.
# <br>
# <br>
# Monte Carlo evidence suggests that in denser networks, the size distortion causes by bias in the limit distribution of the joint fixed effects estimator is very real and, furthermore, that bias correction can be effective in such contexts. So not too much should be made of this example.

# %%
netrics.print_coef(beta_JFE, vcov_beta_JFE, var_names=cov_names)
# Out:
# Independent variable       Coef.    ( Std. Err.)     (0.95 Confid. Interval )
# -------------------------------------------------------------------------------------------
# Distance                  -0.002531 (  0.000184)     ( -0.002891 , -0.002170)
# Other blood relation       1.305247 (  0.189174)     (  0.934473 ,  1.676021)
# Cousin, etc.               1.924257 (  0.244763)     (  1.444531 ,  2.403984)
# Sibling, child, etc.       2.880068 (  0.273332)     (  2.344348 ,  3.415788)
# Age difference            -0.013243 (  0.003642)     ( -0.020382 , -0.006103)
# Same religion              0.375953 (  0.083760)     (  0.211786 ,  0.540120)
# Same clan                  0.259153 (  0.138685)     ( -0.012663 ,  0.530970)
# Same education level       0.073595 (  0.117280)     ( -0.156270 ,  0.303459)
# Adjacent wealth class     -0.175216 (  0.100513)     ( -0.372218 ,  0.021785)
# Non-adjacent wealth class -0.282326 (  0.113675)     ( -0.505124 , -0.059528)
#
# -------------------------------------------------------------------------------------------

# %%
# This imports an attractive notebook style from Github
from IPython.display import HTML
from urllib.request import urlopen
html = urlopen('http://bit.ly/1Bf5Hft')
HTML(html.read().decode('utf-8'))
# Out:
# <style>
#
# html {
#   font-size: 62.5% !important; }
# body {
#   font-size: 1.5em !important; /* currently ems cause chrome bug misinterpreting rems on body element */
#   line-height: 1.6 !important;
#   font-weight: 400 !important;
#   font-family: "Raleway", "HelveticaNeue", "Helvetica Neue", Helvetica, Arial, sans-serif !important;
#   color: #222 !important; }
#
# div{ border-radius: 0px !important;  }
# div.CodeMirror-sizer{ background: rgb(244, 244, 248) !important; }
# div.input_area{ background: rgb(244, 244, 248) !important; }
#
# div.out_prompt_overlay:hover{ background: rgb(244, 244, 248) !important; }
# div.input_prompt:hover{ background: rgb(244, 244, 248) !important; }
#
# h1, h2, h3, h4, h5, h6 {
#   color: #333 !important;
#   margin-top: 0 !important;
#   margin-bottom: 2rem !important;
#   font-weight: 300 !important; }
# h1 { font-size: 4.0rem !important; line-height: 1.2 !important;  letter-spacing: -.1rem !important;}
# h2 { font-size: 3.6rem !important; line-height: 1.25 !important; letter-spacing: -.1rem !important; }
# h3 { font-size: 3.0rem !important; line-height: 1.3 !important;  letter-spacing: -.1rem !important; }
# h4 { font-size: 2.4rem !important; line-height: 1.35 !important; letter-spacing: -.08rem !important; }
# h5 { font-size: 1.8rem !important; line-height: 1.5 !important;  letter-spacing: -.05rem !important; }
# h6 { font-size: 1.5rem !important; line-height: 1.6 !important;  letter-spacing: 0 !important; }
#
# @media (min-width: 550px) {
#   h1 { font-size: 5.0rem !important; }
#   h2 { font-size: 4.2rem !important; }
#   h3 { font-size: 3.6rem !important; }
#   h4 { font-size: 3.0rem !important; }
#   h5 { font-size: 2.4rem !important; }
#   h6 { font-size: 1.5rem !important; }
# }
#
# p {
#   margin-top: 0 !important; }
#
# a {
#   color: #1EAEDB !important; }
# a:hover {
#   color: #0FA0CE !important; }
#
# code {
#   padding: .2rem .5rem !important;
#   margin: 0 .2rem !important;
#   font-size: 90% !important;
#   white-space: nowrap !important;
#   background: #F1F1F1 !important;
#   border: 1px solid #E1E1E1 !important;
#   border-radius: 4px !important; }
# pre > code {
#   display: block !important;
#   padding: 1rem 1.5rem !important;
#   white-space: pre !important; }
#
# button{ border-radius: 0px !important; }
# .navbar-inner{ background-image: none !important;  }
# select, textarea{ border-radius: 0px !important; }
#
# </style>
