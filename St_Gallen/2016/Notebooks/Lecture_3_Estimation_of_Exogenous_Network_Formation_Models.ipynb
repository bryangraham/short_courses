# %% [markdown]
# # Lecture 3: Estimating models of exogenous network formation
# #### Econometric Methods for Social Spillovers and Networks
# #### _University of St. Gallen, September 26th to October 3rd, 2016_
# ##### _Bryan S. Graham, UC - Berkeley, bgraham@econ.berkeley.edu_
# <br>
# <br>
# This is the third of a series of iPython Jupyter notebooks designed to accompany a series of instructional lectures given at the University of St. Gallen from September 26th to October 3rd, 2016. The scripts below were written for Python 2.7.12. The Anaconda distribution of Python, available at https://www.continuum.io/downloads, comes bundled with most the scientific computing packages used in the notebooks.
# <br>
# <br>
# For more information about the course please visit my webpage at http://bryangraham.github.io/econometrics/. This notebook also provides a basic illustration of the recently introduced _netrics_ Python package for the econometric analysis of network data.
# <br>
# <br>
# I begin by importing several key packages. The _numpy_ and _scipy_ libraries include a core set of scientific computing tools. The _pandas_ package is useful for data organization and analysis, while _matplotlib_ is Python's basic plotting add-on. Finally the _networkx_ package includes functionality for the analysis, and also visualizing, network data.

# %%
# Direct Python to plot all figures inline (i.e., not in a separate window)
# %matplotlib inline

# Main scientific computing modules
import numpy as np
import scipy as sp
import pandas as pd

# Import matplotlib
import matplotlib.pyplot as plt

# networkx module for the analysis of network data
import networkx as nx

# Division of two integers in Python 2.7 does not return a floating point result. The default is to round down 
# to the nearest integer. The following piece of code changes the default.
from __future__ import division

# %% [markdown]
# Load **netrics** package. This package is registered on [PyPi](https://pypi.python.org/pypi/netrics/), with a GitHub repository at https://github.com/bryangraham/netrics. For an informal introduction to the package see [this](http://bryangraham.github.io/econometrics/networks/2016/09/15/netrics-module.html) blog post. The blog post also includes links to additional resources.

# %%
# Append location of netrics module base directory to system path
# NOTE: only required if permanent install not made (see discussion in blog post referenced above)
import sys
sys.path.append('/Users/bgraham/Dropbox/Sites/software/netrics/')

# Load netrics module
import netrics as netrics

# %% [markdown]
# The following code snippet should be edited to point to wherever you have saved the instructional datasets for the course

# %%
# Directory where datasets of located
data =  '/Users/bgraham/Dropbox/Teaching/Short_Courses/St_Gallen/Data/'

# %% [markdown]
# A basic dyadic dataset for Nyakatoke was constructed in the Lecture 1 notebook. I begin by loading this dataset into a pandas dataframe.

# %%
# Read in estimation sample created in the notebook for Lecture 1
es = pd.read_csv(data+"Created/Nyakatoke_Estimation_Sample.csv")
es = es.set_index(['hh1', 'hh2'], drop = False)           # Set dataframe multi-index
del es['Unnamed: 0']                                      # Delete first column which is an unneeded single index

# Print out the first few rows of the dyadic data
es.head()
# Out:
#          hh1  hh2            links               kinship    distance  clan1  \
# hh1 hh2
# 1   2      1    2          no link  other blood relation   91.199997   21.0
#     3      1    3          no link     no blood relation   69.599998   21.0
#     4      1    4  unilateral link     no blood relation  199.199997   21.0
#     5      1    5          no link     no blood relation  252.000000   21.0
#     6      1    6          no link     no blood relation  213.600006   21.0
#
#          clan2    wealth1   wealth2 religion1 religion2       education1  \
# hh1 hh2
# 1   2      6.0  17.657388  6.639588  Catholic  Catholic  started primary
#     3     21.0  17.657388  1.538235  Catholic  Catholic  started primary
#     4     23.0  17.657388  2.743059  Catholic  Catholic  started primary
#     5     23.0  17.657388  1.976098  Catholic  Catholic  started primary
#     6     23.0  17.657388  1.394941  Catholic  Catholic  started primary
#
#                education2  head_age1  head_age2 head_sex1 head_sex2
# hh1 hh2
# 1   2    finished primary       75.0       30.0      male      male
#     3           secondary       75.0       48.0      male    female
#     4    finished primary       75.0       80.0      male      male
#     5    finished primary       75.0       35.0      male      male
#     6    finished primary       75.0       28.0      male      male

# %% [markdown]
# Below we fit a dyadic link formation model using the two estimators introduced by Graham (2014, _NBER_). The link formation model studied in that paper is
#
#
# <div> $$\Pr\left(\left.D_{ij}=1\right|\mathbf{X},\mathbf{A}\right) = \frac{\exp\left(\sum_{k=1}^{K}W_{k,ij}\beta_{k}+A_{i}+A_{j}\right)}   {1+\exp\left(\sum_{k=1}^{K}W_{k,ij}\beta_{k}+A_{i}+A_{j}\right)}$$ </div>
#
# Here $\mathbf{X}$ denotes all the household-specific observed covariates in the network, $W_{k,ij} = W_{k,ji}$ are dyad-specific covariates constructed from $\mathbf{X}$, and the $A_i$ for $i=1,...,N$ are _degree heterogeneity_ parameters which are household specific. These are treated as co-called "fixed effects".
# <br>
# <br>
# Graham (2014) introduces a "tetrad logit" procedure which forms a criterion function, based on conditioning arguments, which is invariant to the fixed effects and also a "joint fixed effects" procedure which estimates the individual effects along with the common parameters.
# <br>
# <br>
# In the _netrics_ package these two procedures are operationalized by the *tetrad\_logit()* and *dyad\_jfe\_logit()* functions. These two functions require the user to input data in a very particular way. The outcome is $D$, the $N \times N$ adjacency matrix. The regressors are included in a length $K$ list where each element is an $N \times N $ numpy 2d array $W_{k}$ with $(i,j)$ element equal to the dyadic covariate $W_{k,ij}$. It takes a bit of work to get our Nyakatoke dataset into this form. This is what the next few snippets of code do.

# %%
hh_set = set(es['hh1'].unique()) | set(es['hh2'].unique()) # Set of all households
N = len(hh_set)                                            # Number of households
n = N * (N - 1) //2                                        # Number of dyads

# %%
# Get multi-indices for lower triangle of N x N matrix
ij_LowTri = np.tril_indices(N, -1)

# %%
# Form adjacency matrix as a dense 2d numpy array
D = np.zeros((N,N), dtype = np.bool)
D[ij_LowTri] = (es['links'] != 'no link')
D = (D + D.T)*1

# %%
# Form four categorical bins for wealth (same as used in plot of Network from Lecture 1)
wealth_bkts = [1000000, 6, 3, 1.5, 0]
wealth_bin_labels = ['+600K','(600K,300K]','(300K,150K]','(150K, 0K]']
es['wealth_cat1'] = np.digitize(es.wealth1, wealth_bkts)
es['wealth_cat2'] = np.digitize(es.wealth2, wealth_bkts)

# %% [markdown]
# Construct $K$ list of $N \times N$ dyad-specific covariate matrices.

# %%
cov_names = ['Distance','Other blood relation', 'Cousin, etc.', 'Sibling, child, etc.', 'Age difference', \
             'Same religion', 'Same clan', 'Same education level', 'Adjacent wealth class', \
             'Non-adjacent wealth class']

# Initialize K-list of dyadic covariate matrices
W = [np.zeros((N,N), dtype = np.float)]*len(cov_names)

# Distance between households
W[0][ij_LowTri] = es['distance']
W[0] = W[0] + W[0].T

# Whether two households are other blood related
W[1][ij_LowTri] = (es['kinship']=='other blood relation')*1
W[1] = W[1] + W[1].T

# Whether two households have a nephew etc. level blood relation
W[2][ij_LowTri] = (es['kinship']=='Nephew/niece/uncle/aunt,cousin,grandparent/grandchild')*1
W[2] = W[2] + W[2].T    

# Whether two households have a child etc. level blood relation
W[3][ij_LowTri] = (es['kinship']=='sibling, child, parent')*1
W[3] = W[3] + W[3].T  

# Absolute difference in age between two household heads
W[4][ij_LowTri] = np.abs(es['head_age1']-es['head_age2'])
W[4] = W[4] + W[4].T

# Whether two households are of the same religion
W[5][ij_LowTri] = (es['religion1'] == es['religion2'])*1
W[5] = W[5] + W[5].T

# Whether two households belong to the same clan
W[6][ij_LowTri] = (es['clan1'] == es['clan2'])*1
W[6] = W[6] + W[6].T

# Whether two households are of the same education level
W[7][ij_LowTri] = (es['education1'] == es['education2'])*1
W[7] = W[7] + W[7].T

# Whether two households are of in adjacent wealth class
W[8][ij_LowTri] = (np.abs(es['wealth_cat1'] - es['wealth_cat2']) == 1)*1
W[8] = W[8] + W[8].T

# Whether two households are of in distance wealth classes
W[9][ij_LowTri] = (np.abs(es['wealth_cat1'] - es['wealth_cat2']) > 1)*1
W[9] = W[9] + W[9].T

# %% [markdown]
# Save the adjacency matrix and the covariate matrices to an uncompressed file (this serves as a test dataset for the *tetrad\_logit()* and *dyad\_jfe\_logit()* functions). This file can be download from GitHub at https://github.com/bryangraham/netrics/blob/master/Notebooks/Nyakatoke_Example.npz.

# %%
np.savez(data+"Created/Nyakatoke_Example", D = D, Distance = W[0], OtherBlood = W[1], Cousin = W[2], \
                                           Sibling = W[3], AgeDiff = W[4], SameReligion = W[5], \
                                           SameClan = W[6], SameEdLvl = W[7], AdjacentWealthClass = W[8], \
                                           NonAdjacentWealthClass = W[9])

# %% [markdown]
# ## Tetrad Logit
# With $W$ appropriately constructed we can now fit a link formation model using *tetrad\_logit()*. We can get a sense of how the function works by viewing its help header.

# %%
help(netrics.tetrad_logit)
# Out:
# Help on function tetrad_logit in module netrics.tetrad_logit:
#
# tetrad_logit(D, W, dtcon=None, silent=False, W_names=None)
#     AUTHOR: Bryan S. Graham, bgraham@econ.berkeley.edu, June 2016
#
#     This function computes the Tetrad Logit estimator introduced in Graham (2014, NBER No. 20341) -- "An Econometric
#     Model of Link Formation with Degree Heterogeneity". The implementation is as described in the paper. Notation
#     attempts to follow that used in the paper.
#
#     INPUTS
#     ------
#     D                 : N x N undirected adjacency matrix
#     W                 : List with elements consisting of N x N 2d numpy arrays of dyad-specific
#                         covariates such that W[k][i,j] gives the k-th covariate for dyad ij
#     dtcon             : Dyad and tetrad concordance (dtcon) List with elements [tetrad_to_dyads_indices,
#                         dyad_to_tetrads_dict]. If dtcon=None, then construct it using generate_tetrad_indices()
#                         function. See header to generate_tetrad_indices() for more information.
#     silent            : If True then suppress all optimization and estimation output, show output otherwise.
#     W_names           : List of K strings giving names of the columns of W_tilde. If silent=False then use
#                         these in presentation of estimation output.
#
#     OUTPUTS
#     -------
#     beta_TL          :  K x 1 vector of tetrad logit point estimates of beta
#     vcov_beta_TL     :  K x K asymptotic-variance matrix for beta_TL
#                         NOTE: vcov_beta_TL is already "divided by n" (just take square root of diagonal for std. errs.)
#     tetrad_frac_TL   :  Fraction of tetrads that contribute to Tetrad Logit criterion function
#     success          :  corresponds to success component of OptimizeResult associated with Scipy's minimize function;
#                         success = True if the tetrad logit optimizer exited successfully
#
#
#     CALLS:           : ...logit()...
#                        ...organize_data_tetrad_logit()...
#     ------

# %% [markdown]
# Finally we call *tetrad\_logit()*. Depending on the speed and memory of your computer, this next bit of code may take a few minutes to complete.

# %%
[beta_TL, vcov_beta_TL, tetrad_frac_TL, success] = \
    netrics.tetrad_logit(D, W, dtcon=None, silent=False, W_names=cov_names)
# Out:
# Fisher-Scoring Derivative check (2-norm): 4.71127475
# Value of -logL = 138316.376938,  2-norm of score = 10100196.293330
# Value of -logL = 135187.248221,  2-norm of score = 1596218.251378
# Value of -logL = 135076.189036,  2-norm of score = 455357.680707
# Value of -logL = 134067.546456,  2-norm of score = 360772.909168
# Value of -logL = 132607.914482,  2-norm of score = 195723.087456
# Value of -logL = 132227.469603,  2-norm of score = 90172.252165
# Value of -logL = 119215.459180,  2-norm of score = 774170.802897
# Value of -logL = 119190.326354,  2-norm of score = 29152.067630
# Value of -logL = 115270.688308,  2-norm of score = 100160.420149
# Value of -logL = 115270.231613,  2-norm of score = 21801.989563
# Value of -logL = 110870.099478,  2-norm of score = 129096.777810
# Value of -logL = 110869.345560,  2-norm of score = 16812.212772
# Value of -logL = 108924.013044,  2-norm of score = 28476.500213
# Value of -logL = 105502.849076,  2-norm of score = 110760.674365
# Value of -logL = 105502.272354,  2-norm of score = 11564.394672
# Value of -logL = 104010.911028,  2-norm of score = 19122.138687
# Value of -logL = 101374.123387,  2-norm of score = 72971.419331
# Value of -logL = 101373.860981,  2-norm of score = 8180.644040
# Value of -logL = 98881.159924,  2-norm of score = 60032.088265
# Value of -logL = 98880.976535,  2-norm of score = 6422.993555
# Value of -logL = 97133.055625,  2-norm of score = 39620.494198
# Value of -logL = 97132.973193,  2-norm of score = 5055.677683
# Value of -logL = 96314.607900,  2-norm of score = 12852.462866
# Value of -logL = 96314.598222,  2-norm of score = 4368.523624
# Value of -logL = 95916.424705,  2-norm of score = 4434.391784
# Value of -logL = 95239.523395,  2-norm of score = 17659.616163
# Value of -logL = 95239.506123,  2-norm of score = 2648.175208
# Value of -logL = 95063.118346,  2-norm of score = 2610.689247
# Value of -logL = 94768.372641,  2-norm of score = 7540.270290
# Value of -logL = 94768.369347,  2-norm of score = 1559.410509
# Value of -logL = 94644.861006,  2-norm of score = 2132.430082
# Value of -logL = 94515.876665,  2-norm of score = 10025.774438
# Value of -logL = 94515.870869,  2-norm of score = 136.256262
# Value of -logL = 94515.816241,  2-norm of score = 118.356357
# Value of -logL = 94515.396131,  2-norm of score = 65.464311
# Value of -logL = 94515.145794,  2-norm of score = 17.970309
# Value of -logL = 94515.145794,  2-norm of score = 6.525878
# Value of -logL = 94515.144930,  2-norm of score = 5.565890
# Value of -logL = 94515.143509,  2-norm of score = 3.545812
# Value of -logL = 94515.142470,  2-norm of score = 0.835581
# Value of -logL = 94515.142405,  2-norm of score = 0.041349
# Value of -logL = 94515.142405,  2-norm of score = 0.011061
# Value of -logL = 94515.142405,  2-norm of score = 0.000756
# Value of -logL = 94515.142405,  2-norm of score = 0.000029
# Value of -logL = 94515.142405,  2-norm of score = 0.000010
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 94515.142405
#          Iterations: 45
#          Function evaluations: 118
#          Gradient evaluations: 162
#          Hessian evaluations: 46
#
# -------------------------------------------------------------------------------------------
# - TETRAD LOGIT ESTIMATION RESULTS                                                         -
# -------------------------------------------------------------------------------------------
#
# Number of agents,           N :             115
# Number of dyads,            n :           6,555
# Number of tetrads             :       6,913,340
# Number identifying tetrads    :         102,151
# Fraction identifying tetrads  :        0.014776
#
# -------------------------------------------------------------------------------------------
#
# Independent variable       Coef.    ( Std. Err.)
# -------------------------------------------------------------------------------------------
# Distance                  -0.002083 (  0.000319)
# Other blood relation       1.252720 (  0.293468)
# Cousin, etc.               2.038704 (  0.378834)
# Sibling, child, etc.       2.714449 (  0.417002)
# Age difference            -0.014838 (  0.006137)
# Same religion              0.236759 (  0.141679)
# Same clan                  0.277682 (  0.217226)
# Same education level      -0.012042 (  0.151148)
# Adjacent wealth class     -0.226542 (  0.160744)
# Non-adjacent wealth class -0.262694 (  0.175229)
#
# -------------------------------------------------------------------------------------------

# %% [markdown]
# The program spits out some useful information. In a network with $N = 115$ agents there are a total of $6,913,340$ different tetrads! Of these only $102,151$, or about 1.5 percent, actually contribute to the *tetrad\_logit()* criterion function. The effectiveness of the procedure in the context of sparse networks is one of its theoretical and practical attractions.
# <br>
# <br>
# The results suggest that ties are more frequent between households which are physically close, related by blood and where the household heads are close in age. There is little evidence for sorting by religion, clan or education. There is some evidence for heterophily in terms of wealth (perhaps consistent with some models of "mutual support"), but it is rather weak.
# <br>
# <br>
# The *tetrad\_logit()* estimation procedure is computationally intense. On a modern desktop machine it would be difficult to use the procedure on a network larger than a few hundred agents (fortunately there are many possible ways to apply the method at scale via various approximations and parallelizations; but these extensions are not yet part of the _netrics_ package).
# <br>
# <br>
# Part of the computational intensity is up front. Specifically, the function computes a detailed dictionary which maps dyads-to-tetrads and vice-versa. This bookkeeping overhead makes later calculations much quicker. A user who anticipates fitting several different models to the same adjacency matrix can save considerable time by computing this concordance first (once and for all) and then passing it to *tetrad\_logit()* via the _dtcon_ parameter. This can be done by calling the *generate\_tetrad\_indices()* function.
# <br>
# <br>
# To illustrate I create the concordance and then fit a model with only the distance and kinship variables included.

# %%
N = np.shape(D)[0]
concordance = netrics.generate_tetrad_indices(N, full_set=True)
[beta_TL, vcov_beta_TL, tetrad_frac_TL, success] = \
    netrics.tetrad_logit(D, W[0:4], dtcon=concordance, silent=False, W_names=cov_names[0:4])
# Out:
# Fisher-Scoring Derivative check (2-norm): 3.60591159
# Value of -logL = 138326.439661,  2-norm of score = 10091629.732103
# Value of -logL = 135209.678252,  2-norm of score = 1545919.738610
# Value of -logL = 135114.042604,  2-norm of score = 60944.705780
# Value of -logL = 121140.801102,  2-norm of score = 625205.028856
# Value of -logL = 121124.580012,  2-norm of score = 19809.526787
# Value of -logL = 111828.477811,  2-norm of score = 409426.996907
# Value of -logL = 111821.253795,  2-norm of score = 12505.123489
# Value of -logL = 107491.275688,  2-norm of score = 124732.568172
# Value of -logL = 107490.575103,  2-norm of score = 8900.886136
# Value of -logL = 105707.802070,  2-norm of score = 26720.585201
# Value of -logL = 105707.766567,  2-norm of score = 7863.103780
# Value of -logL = 104264.818956,  2-norm of score = 19484.440876
# Value of -logL = 104264.799142,  2-norm of score = 6743.170635
# Value of -logL = 103440.084936,  2-norm of score = 8105.213966
# Value of -logL = 101983.725487,  2-norm of score = 35198.300037
# Value of -logL = 101983.664528,  2-norm of score = 4298.428347
# Value of -logL = 101364.277726,  2-norm of score = 7701.584741
# Value of -logL = 100345.088860,  2-norm of score = 33027.972484
# Value of -logL = 100345.033032,  2-norm of score = 2313.406382
# Value of -logL = 99845.153632,  2-norm of score = 12461.347743
# Value of -logL = 99845.145397,  2-norm of score = 1470.082616
# Value of -logL = 99759.974382,  2-norm of score = 1340.087226
# Value of -logL = 99613.382298,  2-norm of score = 2739.935861
# Value of -logL = 99613.381849,  2-norm of score = 958.471242
# Value of -logL = 99544.247690,  2-norm of score = 906.473174
# Value of -logL = 99457.835783,  2-norm of score = 4038.768097
# Value of -logL = 99457.834887,  2-norm of score = 169.864729
# Value of -logL = 99455.611482,  2-norm of score = 136.288623
# Value of -logL = 99452.371850,  2-norm of score = 99.178088
# Value of -logL = 99451.558261,  2-norm of score = 48.831039
# Value of -logL = 99451.558261,  2-norm of score = 2.937739
# Value of -logL = 99451.557938,  2-norm of score = 2.282115
# Value of -logL = 99451.557499,  2-norm of score = 0.802791
# Value of -logL = 99451.557431,  2-norm of score = 0.216692
# Value of -logL = 99451.557423,  2-norm of score = 0.093413
# Value of -logL = 99451.557422,  2-norm of score = 0.026804
# Value of -logL = 99451.557422,  2-norm of score = 0.000316
# Value of -logL = 99451.557422,  2-norm of score = 0.000004
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 99451.557422
#          Iterations: 38
#          Function evaluations: 106
#          Gradient evaluations: 143
#          Hessian evaluations: 39
#
# -------------------------------------------------------------------------------------------
# - TETRAD LOGIT ESTIMATION RESULTS                                                         -
# -------------------------------------------------------------------------------------------
#
# Number of agents,           N :             115
# Number of dyads,            n :           6,555
# Number of tetrads             :       6,913,340
# Number identifying tetrads    :         102,151
# Fraction identifying tetrads  :        0.014776
#
# -------------------------------------------------------------------------------------------
#
# Independent variable       Coef.    ( Std. Err.)
# -------------------------------------------------------------------------------------------
# Distance                  -0.002067 (  0.000328)
# Other blood relation       1.307596 (  0.293372)
# Cousin, etc.               2.209613 (  0.393581)
# Sibling, child, etc.       2.895174 (  0.393442)
#
# -------------------------------------------------------------------------------------------

# %% [markdown]
# ## Joint Fixed Effects Logit
# Graham (2014) also introduces a joint fixed effects estimator for link formation. This procedure estimates the coefficients on $W_{k,ij}$ for $k=1,...,K$ as well as individual specific degree heterogeneity parameters $A_{i}$ for $i=1,...,N$. The *dyad\_jfe\_logit()* function implements this estimator. By default it reports the iterated bias-corrected estimates described in the paper (but the uncorrected estimates are also returned by the function).

# %%
[beta_JFE, beta_JFE_BC, vcov_beta_JFE, A_JFE, success] = \
    netrics.dyad_jfe_logit(D, W, T=None, silent=False, W_names=cov_names, beta_sv=None)
# Out:
# -------------------------------------------------------------------------------------------
# - COMPUTE JOINT FIXED EFFECT MLEs                                                         -
# -------------------------------------------------------------------------------------------
# Value of c_logl = 1573.908746,  2-norm of c_score = 62611.046459
# Value of c_logl = 1547.376191,  2-norm of c_score = 48351.980722
# Value of c_logl = 1529.569153,  2-norm of c_score = 37055.119814
# Value of c_logl = 1517.970321,  2-norm of c_score = 28245.623208
# Value of c_logl = 1510.616150,  2-norm of c_score = 21451.168506
# Value of c_logl = 1506.059569,  2-norm of c_score = 16250.801500
# Value of c_logl = 1503.289044,  2-norm of c_score = 12291.742962
# Value of c_logl = 1501.628945,  2-norm of c_score = 9289.106809
# Value of c_logl = 1500.644577,  2-norm of c_score = 7018.144552
# Value of c_logl = 1500.064492,  2-norm of c_score = 5304.237016
# Value of c_logl = 1499.723095,  2-norm of c_score = 4013.119659
# Value of c_logl = 1499.521148,  2-norm of c_score = 3042.343307
# Value of c_logl = 1499.399925,  2-norm of c_score = 2314.261004
# Value of c_logl = 1499.324894,  2-norm of c_score = 1770.542197
# Value of c_logl = 1498.607050,  2-norm of c_score = 2258.018679
# Value of c_logl = 1498.536662,  2-norm of c_score = 1724.573882
# Value of c_logl = 1497.866818,  2-norm of c_score = 2223.637539
# Value of c_logl = 1497.799693,  2-norm of c_score = 1695.060497
# Value of c_logl = 1497.757111,  2-norm of c_score = 1302.087806
# Value of c_logl = 1496.258277,  2-norm of c_score = 2734.965482
# Value of c_logl = 1496.163581,  2-norm of c_score = 2069.298596
# Value of c_logl = 1496.107418,  2-norm of c_score = 1570.486054
# Value of c_logl = 1496.073187,  2-norm of c_score = 1198.007724
# Value of c_logl = 1495.746945,  2-norm of c_score = 1539.794850
# Value of c_logl = 1495.714527,  2-norm of c_score = 1172.624209
# Value of c_logl = 1495.694052,  2-norm of c_score = 899.864079
# Value of c_logl = 1494.967496,  2-norm of c_score = 1862.966115
# Value of c_logl = 1494.923005,  2-norm of c_score = 1408.821272
# Value of c_logl = 1494.896671,  2-norm of c_score = 1068.848810
# Value of c_logl = 1494.880615,  2-norm of c_score = 815.264686
# Value of c_logl = 1494.726696,  2-norm of c_score = 1035.546577
# Value of c_logl = 1494.711790,  2-norm of c_score = 788.870116
# Value of c_logl = 1494.569435,  2-norm of c_score = 1010.064609
# Value of c_logl = 1494.555431,  2-norm of c_score = 768.366748
# Value of c_logl = 1494.422380,  2-norm of c_score = 994.116728
# Value of c_logl = 1494.409002,  2-norm of c_score = 755.030661
# Value of c_logl = 1494.400732,  2-norm of c_score = 577.112229
# Value of c_logl = 1494.109504,  2-norm of c_score = 1203.381540
# Value of c_logl = 1494.090899,  2-norm of c_score = 908.455124
# Value of c_logl = 1494.080006,  2-norm of c_score = 687.657953
# Value of c_logl = 1494.073470,  2-norm of c_score = 522.812072
# Value of c_logl = 1494.010779,  2-norm of c_score = 664.485318
# Value of c_logl = 1494.004725,  2-norm of c_score = 504.673114
# Value of c_logl = 1493.946751,  2-norm of c_score = 643.876412
# Value of c_logl = 1493.941113,  2-norm of c_score = 488.497667
# Value of c_logl = 1493.887199,  2-norm of c_score = 625.425013
# Value of c_logl = 1493.881922,  2-norm of c_score = 473.983541
# Value of c_logl = 1493.831503,  2-norm of c_score = 608.372676
# Value of c_logl = 1493.826547,  2-norm of c_score = 460.566634
# Value of c_logl = 1493.823549,  2-norm of c_score = 350.371861
# Value of c_logl = 1493.713926,  2-norm of c_score = 692.195543
# Value of c_logl = 1493.707710,  2-norm of c_score = 521.856849
# Value of c_logl = 1493.704081,  2-norm of c_score = 394.400210
# Value of c_logl = 1493.701908,  2-norm of c_score = 299.297883
# Value of c_logl = 1471.781195,  2-norm of c_score = 1960.485959
# Value of c_logl = 1471.731271,  2-norm of c_score = 1466.815609
# Value of c_logl = 1471.703468,  2-norm of c_score = 1097.836187
# Value of c_logl = 1471.687932,  2-norm of c_score = 822.026406
# Value of c_logl = 1471.679215,  2-norm of c_score = 615.870988
# Value of c_logl = 1471.674295,  2-norm of c_score = 461.821212
# Value of c_logl = 1471.671493,  2-norm of c_score = 346.782507
# Value of c_logl = 1471.669872,  2-norm of c_score = 260.994723
# Value of c_logl = 1455.220765,  2-norm of c_score = 2060.780256
# Value of c_logl = 1455.165796,  2-norm of c_score = 1540.454555
# Value of c_logl = 1455.135222,  2-norm of c_score = 1152.371645
# Value of c_logl = 1455.118123,  2-norm of c_score = 862.932814
# Value of c_logl = 1455.108489,  2-norm of c_score = 647.131211
# Value of c_logl = 1455.102998,  2-norm of c_score = 486.357166
# Value of c_logl = 1455.099807,  2-norm of c_score = 366.780768
# Value of c_logl = 1455.097889,  2-norm of c_score = 278.174182
# Value of c_logl = 1455.028264,  2-norm of c_score = 564.106216
# Value of c_logl = 1455.024118,  2-norm of c_score = 423.470415
# Value of c_logl = 1455.021726,  2-norm of c_score = 318.791393
# Value of c_logl = 1455.020307,  2-norm of c_score = 241.101035
# Value of c_logl = 1440.695773,  2-norm of c_score = 1908.841340
# Value of c_logl = 1440.648835,  2-norm of c_score = 1425.708419
# Value of c_logl = 1440.622712,  2-norm of c_score = 1065.961516
# Value of c_logl = 1440.608065,  2-norm of c_score = 798.157039
# Value of c_logl = 1440.599759,  2-norm of c_score = 598.934960
# Value of c_logl = 1440.594962,  2-norm of c_score = 450.959974
# Value of c_logl = 1440.592101,  2-norm of c_score = 341.421313
# Value of c_logl = 1440.493115,  2-norm of c_score = 735.841307
# Value of c_logl = 1440.486145,  2-norm of c_score = 551.126921
# Value of c_logl = 1440.482176,  2-norm of c_score = 413.728445
# Value of c_logl = 1440.479870,  2-norm of c_score = 311.714581
# Value of c_logl = 1440.457873,  2-norm of c_score = 404.740209
# Value of c_logl = 1440.455685,  2-norm of c_score = 304.603267
# Value of c_logl = 1440.454381,  2-norm of c_score = 230.465951
# Value of c_logl = 1440.407004,  2-norm of c_score = 468.851568
# Value of c_logl = 1440.404160,  2-norm of c_score = 351.321293
# Value of c_logl = 1440.402528,  2-norm of c_score = 263.951103
# Value of c_logl = 1440.401565,  2-norm of c_score = 199.177876
# Value of c_logl = 1430.515615,  2-norm of c_score = 1347.917575
# Value of c_logl = 1430.492429,  2-norm of c_score = 1006.162084
# Value of c_logl = 1430.479506,  2-norm of c_score = 751.873275
# Value of c_logl = 1430.472247,  2-norm of c_score = 562.740131
# Value of c_logl = 1430.468118,  2-norm of c_score = 422.195222
# Value of c_logl = 1430.465720,  2-norm of c_score = 317.957972
# Value of c_logl = 1430.464274,  2-norm of c_score = 240.979195
# Value of c_logl = 1430.412181,  2-norm of c_score = 494.717254
# Value of c_logl = 1430.409018,  2-norm of c_score = 370.674373
# Value of c_logl = 1430.407198,  2-norm of c_score = 278.581057
# Value of c_logl = 1430.406120,  2-norm of c_score = 210.420424
# Value of c_logl = 1430.367405,  2-norm of c_score = 435.587759
# Value of c_logl = 1430.364967,  2-norm of c_score = 325.947974
# Value of c_logl = 1430.363576,  2-norm of c_score = 244.485289
# Value of c_logl = 1430.362763,  2-norm of c_score = 184.097863
# Value of c_logl = 1421.985250,  2-norm of c_score = 1123.483744
# Value of c_logl = 1421.969224,  2-norm of c_score = 838.173560
# Value of c_logl = 1421.960293,  2-norm of c_score = 626.005220
# Value of c_logl = 1421.955276,  2-norm of c_score = 468.299098
# Value of c_logl = 1421.952422,  2-norm of c_score = 351.190268
# Value of c_logl = 1421.950762,  2-norm of c_score = 264.408433
# Value of c_logl = 1421.934941,  2-norm of c_score = 343.713160
# Value of c_logl = 1421.933367,  2-norm of c_score = 258.472745
# Value of c_logl = 1421.932425,  2-norm of c_score = 195.507286
# Value of c_logl = 1421.898450,  2-norm of c_score = 401.591924
# Value of c_logl = 1421.896376,  2-norm of c_score = 300.566535
# Value of c_logl = 1421.895188,  2-norm of c_score = 225.590394
# Value of c_logl = 1421.894487,  2-norm of c_score = 170.106317
# Value of c_logl = 1421.868928,  2-norm of c_score = 344.925143
# Value of c_logl = 1421.867403,  2-norm of c_score = 257.896214
# Value of c_logl = 1421.866533,  2-norm of c_score = 193.280192
# Value of c_logl = 1421.866024,  2-norm of c_score = 145.422605
# Value of c_logl = 1403.498576,  2-norm of c_score = 2271.102559
# Value of c_logl = 1403.432615,  2-norm of c_score = 1690.991402
# Value of c_logl = 1403.396265,  2-norm of c_score = 1259.945353
# Value of c_logl = 1403.376129,  2-norm of c_score = 939.682589
# Value of c_logl = 1403.364898,  2-norm of c_score = 701.799605
# Value of c_logl = 1403.358570,  2-norm of c_score = 525.226513
# Value of c_logl = 1403.354942,  2-norm of c_score = 394.351067
# Value of c_logl = 1403.352799,  2-norm of c_score = 297.647848
# Value of c_logl = 1403.332252,  2-norm of c_score = 381.059580
# Value of c_logl = 1403.330270,  2-norm of c_score = 287.329008
# Value of c_logl = 1403.311341,  2-norm of c_score = 370.918445
# Value of c_logl = 1403.309484,  2-norm of c_score = 279.351945
# Value of c_logl = 1403.308351,  2-norm of c_score = 211.958727
# Value of c_logl = 1403.267490,  2-norm of c_score = 433.557725
# Value of c_logl = 1403.265070,  2-norm of c_score = 324.677141
# Value of c_logl = 1403.263674,  2-norm of c_score = 244.012055
# Value of c_logl = 1403.262839,  2-norm of c_score = 184.480097
# Value of c_logl = 1403.233462,  2-norm of c_score = 390.826839
# Value of c_logl = 1403.231517,  2-norm of c_score = 292.192401
# Value of c_logl = 1403.230408,  2-norm of c_score = 219.023367
# Value of c_logl = 1403.229761,  2-norm of c_score = 164.874675
# Value of c_logl = 1403.207853,  2-norm of c_score = 365.916221
# Value of c_logl = 1403.206164,  2-norm of c_score = 273.047222
# Value of c_logl = 1403.205213,  2-norm of c_score = 204.076733
# Value of c_logl = 1403.204671,  2-norm of c_score = 152.918761
# Value of c_logl = 1403.204353,  2-norm of c_score = 115.071699
# Value of c_logl = 1403.192595,  2-norm of c_score = 228.174583
# Value of c_logl = 1403.191931,  2-norm of c_score = 170.414329
# Value of c_logl = 1403.191553,  2-norm of c_score = 127.567241
# Value of c_logl = 1403.191331,  2-norm of c_score = 95.863536
# Value of c_logl = 1394.251918,  2-norm of c_score = 258.675311
# Value of c_logl = 1394.251073,  2-norm of c_score = 193.060000
# Value of c_logl = 1394.250596,  2-norm of c_score = 144.362561
# Value of c_logl = 1394.250321,  2-norm of c_score = 108.282339
# Value of c_logl = 1394.250158,  2-norm of c_score = 81.647486
# Value of c_logl = 1387.539375,  2-norm of c_score = 202.960400
# Value of c_logl = 1387.538852,  2-norm of c_score = 151.686081
# Value of c_logl = 1387.538552,  2-norm of c_score = 113.684671
# Value of c_logl = 1387.538376,  2-norm of c_score = 85.603750
# Value of c_logl = 1387.531862,  2-norm of c_score = 170.404588
# Value of c_logl = 1387.531493,  2-norm of c_score = 127.261281
# Value of c_logl = 1387.531282,  2-norm of c_score = 95.280814
# Value of c_logl = 1387.531159,  2-norm of c_score = 71.641470
# Value of c_logl = 1382.417920,  2-norm of c_score = 215.601872
# Value of c_logl = 1382.417336,  2-norm of c_score = 160.852812
# Value of c_logl = 1382.417006,  2-norm of c_score = 120.237043
# Value of c_logl = 1382.416816,  2-norm of c_score = 90.156136
# Value of c_logl = 1382.416704,  2-norm of c_score = 67.956266
# Value of c_logl = 1377.803706,  2-norm of c_score = 203.215324
# Value of c_logl = 1377.803186,  2-norm of c_score = 151.682644
# Value of c_logl = 1377.802892,  2-norm of c_score = 113.476035
# Value of c_logl = 1377.802721,  2-norm of c_score = 85.206739
# Value of c_logl = 1377.796921,  2-norm of c_score = 188.920012
# Value of c_logl = 1377.796475,  2-norm of c_score = 140.767902
# Value of c_logl = 1377.796224,  2-norm of c_score = 105.036030
# Value of c_logl = 1377.796082,  2-norm of c_score = 78.551080
# Value of c_logl = 1377.796000,  2-norm of c_score = 58.966136
# Value of c_logl = 1374.398016,  2-norm of c_score = 234.381565
# Value of c_logl = 1374.397332,  2-norm of c_score = 174.615063
# Value of c_logl = 1374.396950,  2-norm of c_score = 130.264448
# Value of c_logl = 1374.396733,  2-norm of c_score = 97.383258
# Value of c_logl = 1374.396609,  2-norm of c_score = 73.049891
# Value of c_logl = 1374.396534,  2-norm of c_score = 55.112958
# Value of c_logl = 1374.393760,  2-norm of c_score = 107.676699
# Value of c_logl = 1374.393612,  2-norm of c_score = 80.463294
# Value of c_logl = 1374.393526,  2-norm of c_score = 60.325184
# Value of c_logl = 1374.390423,  2-norm of c_score = 123.453175
# Value of c_logl = 1374.390232,  2-norm of c_score = 91.976773
# Value of c_logl = 1374.390124,  2-norm of c_score = 68.635484
# Value of c_logl = 1374.390062,  2-norm of c_score = 51.355272
# Value of c_logl = 1374.390026,  2-norm of c_score = 38.607169
# Value of c_logl = 1368.956778,  2-norm of c_score = 397.205241
# Value of c_logl = 1368.954823,  2-norm of c_score = 295.413220
# Value of c_logl = 1368.953741,  2-norm of c_score = 219.858221
# Value of c_logl = 1368.953139,  2-norm of c_score = 163.792242
# Value of c_logl = 1368.952803,  2-norm of c_score = 122.209391
# Value of c_logl = 1368.952612,  2-norm of c_score = 91.399082
# Value of c_logl = 1368.952502,  2-norm of c_score = 68.616621
# Value of c_logl = 1368.952436,  2-norm of c_score = 51.844282
# Value of c_logl = 1368.950036,  2-norm of c_score = 105.926353
# Value of c_logl = 1368.949894,  2-norm of c_score = 79.135007
# Value of c_logl = 1368.949812,  2-norm of c_score = 59.308562
# Value of c_logl = 1368.949764,  2-norm of c_score = 44.686720
# Value of c_logl = 1368.948012,  2-norm of c_score = 91.543003
# Value of c_logl = 1368.947906,  2-norm of c_score = 68.317543
# Value of c_logl = 1368.947846,  2-norm of c_score = 51.119888
# Value of c_logl = 1368.947811,  2-norm of c_score = 38.420846
# Value of c_logl = 1368.946500,  2-norm of c_score = 76.061748
# Value of c_logl = 1368.946427,  2-norm of c_score = 56.728820
# Value of c_logl = 1368.946385,  2-norm of c_score = 42.413135
# Value of c_logl = 1368.946361,  2-norm of c_score = 31.841891
# Value of c_logl = 1367.929327,  2-norm of c_score = 93.837061
# Value of c_logl = 1367.929217,  2-norm of c_score = 69.938064
# Value of c_logl = 1367.929155,  2-norm of c_score = 52.227322
# Value of c_logl = 1367.929119,  2-norm of c_score = 39.125560
# Value of c_logl = 1367.929098,  2-norm of c_score = 29.469849
# Value of c_logl = 1367.046115,  2-norm of c_score = 98.884141
# Value of c_logl = 1367.045993,  2-norm of c_score = 73.718874
# Value of c_logl = 1367.045924,  2-norm of c_score = 55.072563
# Value of c_logl = 1367.045884,  2-norm of c_score = 41.281281
# Value of c_logl = 1367.045860,  2-norm of c_score = 31.120138
# Value of c_logl = 1367.044981,  2-norm of c_score = 61.302142
# Value of c_logl = 1367.044933,  2-norm of c_score = 45.773305
# Value of c_logl = 1367.044905,  2-norm of c_score = 34.287186
# Value of c_logl = 1367.044889,  2-norm of c_score = 25.823613
# Value of c_logl = 1366.365136,  2-norm of c_score = 94.770622
# Value of c_logl = 1366.365024,  2-norm of c_score = 70.623773
# Value of c_logl = 1366.364961,  2-norm of c_score = 52.729447
# Value of c_logl = 1366.364925,  2-norm of c_score = 39.489150
# Value of c_logl = 1366.364903,  2-norm of c_score = 29.724385
# Value of c_logl = 1366.364124,  2-norm of c_score = 60.306462
# Value of c_logl = 1366.364078,  2-norm of c_score = 44.985742
# Value of c_logl = 1366.364052,  2-norm of c_score = 33.645198
# Value of c_logl = 1366.364037,  2-norm of c_score = 25.274452
# Value of c_logl = 1365.733111,  2-norm of c_score = 96.872960
# Value of c_logl = 1365.732994,  2-norm of c_score = 72.140398
# Value of c_logl = 1365.732929,  2-norm of c_score = 53.806083
# Value of c_logl = 1365.732892,  2-norm of c_score = 40.230116
# Value of c_logl = 1365.732870,  2-norm of c_score = 30.200652
# Value of c_logl = 1365.732121,  2-norm of c_score = 65.560897
# Value of c_logl = 1365.732067,  2-norm of c_score = 48.822894
# Value of c_logl = 1365.732037,  2-norm of c_score = 36.418891
# Value of c_logl = 1365.732020,  2-norm of c_score = 27.240056
# Value of c_logl = 1365.732010,  2-norm of c_score = 20.468525
# Value of c_logl = 1365.311747,  2-norm of c_score = 75.349645
# Value of c_logl = 1365.311677,  2-norm of c_score = 56.117768
# Value of c_logl = 1365.311637,  2-norm of c_score = 41.864535
# Value of c_logl = 1365.311614,  2-norm of c_score = 31.314779
# Value of c_logl = 1365.311601,  2-norm of c_score = 23.527107
# Value of c_logl = 1365.311125,  2-norm of c_score = 48.717001
# Value of c_logl = 1365.311095,  2-norm of c_score = 36.303331
# Value of c_logl = 1365.311078,  2-norm of c_score = 27.110618
# Value of c_logl = 1365.311068,  2-norm of c_score = 20.317698
# Value of c_logl = 1364.910978,  2-norm of c_score = 76.229387
# Value of c_logl = 1364.910906,  2-norm of c_score = 56.736602
# Value of c_logl = 1364.910865,  2-norm of c_score = 42.285779
# Value of c_logl = 1364.910843,  2-norm of c_score = 31.582752
# Value of c_logl = 1364.910830,  2-norm of c_score = 23.670352
# Value of c_logl = 1364.910822,  2-norm of c_score = 17.844530
# Value of c_logl = 1364.910529,  2-norm of c_score = 34.809033
# Value of c_logl = 1364.910514,  2-norm of c_score = 25.989663
# Value of c_logl = 1364.910505,  2-norm of c_score = 19.470570
# Value of c_logl = 1364.910181,  2-norm of c_score = 39.892702
# Value of c_logl = 1364.910161,  2-norm of c_score = 29.695454
# Value of c_logl = 1364.910149,  2-norm of c_score = 22.141625
# Value of c_logl = 1364.910143,  2-norm of c_score = 16.555575
# Value of c_logl = 1364.910139,  2-norm of c_score = 12.439892
# Value of c_logl = 1364.338402,  2-norm of c_score = 121.218860
# Value of c_logl = 1364.338221,  2-norm of c_score = 90.091215
# Value of c_logl = 1364.338120,  2-norm of c_score = 67.002093
# Value of c_logl = 1364.338064,  2-norm of c_score = 49.880375
# Value of c_logl = 1364.338033,  2-norm of c_score = 37.190514
# Value of c_logl = 1364.338015,  2-norm of c_score = 27.795012
# Value of c_logl = 1364.338005,  2-norm of c_score = 20.853080
# Value of c_logl = 1364.337999,  2-norm of c_score = 15.747234
# Value of c_logl = 1364.337774,  2-norm of c_score = 31.737178
# Value of c_logl = 1364.337761,  2-norm of c_score = 23.699393
# Value of c_logl = 1364.337754,  2-norm of c_score = 17.757414
# Value of c_logl = 1364.337750,  2-norm of c_score = 13.381748
# Value of c_logl = 1364.337587,  2-norm of c_score = 26.581935
# Value of c_logl = 1364.337578,  2-norm of c_score = 19.837757
# Value of c_logl = 1364.337573,  2-norm of c_score = 14.851237
# Value of c_logl = 1364.337570,  2-norm of c_score = 11.177819
# Value of c_logl = 1364.210963,  2-norm of c_score = 20.389141
# Value of c_logl = 1364.210958,  2-norm of c_score = 15.247217
# Value of c_logl = 1364.210955,  2-norm of c_score = 11.453515
# Value of c_logl = 1364.210839,  2-norm of c_score = 22.941353
# Value of c_logl = 1364.210832,  2-norm of c_score = 17.097226
# Value of c_logl = 1364.210828,  2-norm of c_score = 12.772688
# Value of c_logl = 1364.210826,  2-norm of c_score = 9.581157
# Value of c_logl = 1364.119079,  2-norm of c_score = 31.022161
# Value of c_logl = 1364.119067,  2-norm of c_score = 23.098270
# Value of c_logl = 1364.119061,  2-norm of c_score = 17.228305
# Value of c_logl = 1364.119057,  2-norm of c_score = 12.886155
# Value of c_logl = 1364.119055,  2-norm of c_score = 9.683865
# Value of c_logl = 1364.118970,  2-norm of c_score = 18.993868
# Value of c_logl = 1364.118966,  2-norm of c_score = 14.160454
# Value of c_logl = 1364.118963,  2-norm of c_score = 10.585465
# Value of c_logl = 1364.118961,  2-norm of c_score = 7.949620
# Value of c_logl = 1363.901387,  2-norm of c_score = 66.130213
# Value of c_logl = 1363.901332,  2-norm of c_score = 49.140440
# Value of c_logl = 1363.901303,  2-norm of c_score = 36.540405
# Value of c_logl = 1363.901286,  2-norm of c_score = 27.198493
# Value of c_logl = 1363.901277,  2-norm of c_score = 20.275836
# Value of c_logl = 1363.901271,  2-norm of c_score = 15.151106
# Value of c_logl = 1363.901268,  2-norm of c_score = 11.365075
# Value of c_logl = 1363.901266,  2-norm of c_score = 8.580434
# Value of c_logl = 1363.901201,  2-norm of c_score = 17.608211
# Value of c_logl = 1363.901197,  2-norm of c_score = 13.143126
# Value of c_logl = 1363.901194,  2-norm of c_score = 9.841715
# Value of c_logl = 1363.901193,  2-norm of c_score = 7.409056
# Value of c_logl = 1363.901145,  2-norm of c_score = 15.346529
# Value of c_logl = 1363.901142,  2-norm of c_score = 11.441758
# Value of c_logl = 1363.901141,  2-norm of c_score = 8.552655
# Value of c_logl = 1363.901140,  2-norm of c_score = 6.420659
# Value of c_logl = 1363.901104,  2-norm of c_score = 13.051188
# Value of c_logl = 1363.901101,  2-norm of c_score = 9.721872
# Value of c_logl = 1363.901100,  2-norm of c_score = 7.257882
# Value of c_logl = 1363.901099,  2-norm of c_score = 5.438575
# Value of c_logl = 1363.871893,  2-norm of c_score = 15.377069
# Value of c_logl = 1363.871890,  2-norm of c_score = 11.449746
# Value of c_logl = 1363.871889,  2-norm of c_score = 8.541296
# Value of c_logl = 1363.871888,  2-norm of c_score = 6.390882
# Value of c_logl = 1363.871887,  2-norm of c_score = 4.806394
# Value of c_logl = 1363.871866,  2-norm of c_score = 9.128057
# Value of c_logl = 1363.871865,  2-norm of c_score = 6.809418
# Value of c_logl = 1363.871864,  2-norm of c_score = 5.096121
# Value of c_logl = 1363.846671,  2-norm of c_score = 14.757788
# Value of c_logl = 1363.846668,  2-norm of c_score = 10.983543
# Value of c_logl = 1363.846667,  2-norm of c_score = 8.187581
# Value of c_logl = 1363.846666,  2-norm of c_score = 6.118987
# Value of c_logl = 1363.846666,  2-norm of c_score = 4.592587
# Value of c_logl = 1363.846647,  2-norm of c_score = 9.109519
# Value of c_logl = 1363.846646,  2-norm of c_score = 6.786482
# Value of c_logl = 1363.846645,  2-norm of c_score = 5.067792
# Value of c_logl = 1363.846645,  2-norm of c_score = 3.799613
# Value of c_logl = 1363.832125,  2-norm of c_score = 10.738118
# Value of c_logl = 1363.832124,  2-norm of c_score = 7.996593
# Value of c_logl = 1363.832123,  2-norm of c_score = 5.966821
# Value of c_logl = 1363.832122,  2-norm of c_score = 4.466797
# Value of c_logl = 1363.832122,  2-norm of c_score = 3.362679
# Value of c_logl = 1363.820460,  2-norm of c_score = 8.409137
# Value of c_logl = 1363.820459,  2-norm of c_score = 6.273564
# Value of c_logl = 1363.820459,  2-norm of c_score = 4.694652
# Value of c_logl = 1363.820459,  2-norm of c_score = 3.531300
# Value of c_logl = 1363.820447,  2-norm of c_score = 6.857447
# Value of c_logl = 1363.820447,  2-norm of c_score = 5.114446
# Value of c_logl = 1363.820446,  2-norm of c_score = 3.826097
# Value of c_logl = 1363.820446,  2-norm of c_score = 2.877362
# Value of c_logl = 1363.791280,  2-norm of c_score = 23.136949
# Value of c_logl = 1363.791273,  2-norm of c_score = 17.192242
# Value of c_logl = 1363.791269,  2-norm of c_score = 12.784092
# Value of c_logl = 1363.791267,  2-norm of c_score = 9.516342
# Value of c_logl = 1363.791266,  2-norm of c_score = 7.095370
# Value of c_logl = 1363.791266,  2-norm of c_score = 5.303766
# Value of c_logl = 1363.791265,  2-norm of c_score = 3.980947
# Value of c_logl = 1363.791265,  2-norm of c_score = 3.009190
# Value of c_logl = 1363.791257,  2-norm of c_score = 6.026662
# Value of c_logl = 1363.791256,  2-norm of c_score = 4.501561
# Value of c_logl = 1363.791256,  2-norm of c_score = 3.374949
# Value of c_logl = 1363.791256,  2-norm of c_score = 2.546379
# Value of c_logl = 1363.791250,  2-norm of c_score = 5.049611
# Value of c_logl = 1363.791250,  2-norm of c_score = 3.769636
# Value of c_logl = 1363.791249,  2-norm of c_score = 2.823914
# Value of c_logl = 1363.791249,  2-norm of c_score = 2.128072
# Value of c_logl = 1363.791245,  2-norm of c_score = 4.054267
# Value of c_logl = 1363.791245,  2-norm of c_score = 3.026757
# Value of c_logl = 1363.791245,  2-norm of c_score = 2.268015
# Value of c_logl = 1363.786243,  2-norm of c_score = 5.550310
# Value of c_logl = 1363.786243,  2-norm of c_score = 4.134390
# Value of c_logl = 1363.786243,  2-norm of c_score = 3.086244
# Value of c_logl = 1363.786242,  2-norm of c_score = 2.311861
# Value of c_logl = 1363.786242,  2-norm of c_score = 1.742166
# Value of c_logl = 1363.786240,  2-norm of c_score = 3.267219
# Value of c_logl = 1363.786239,  2-norm of c_score = 2.439680
# Value of c_logl = 1363.786239,  2-norm of c_score = 1.828842
# Value of c_logl = 1363.782942,  2-norm of c_score = 5.686095
# Value of c_logl = 1363.782942,  2-norm of c_score = 4.232734
# Value of c_logl = 1363.782941,  2-norm of c_score = 3.156310
# Value of c_logl = 1363.782941,  2-norm of c_score = 2.360183
# Value of c_logl = 1363.782941,  2-norm of c_score = 1.773093
# Value of c_logl = 1363.782938,  2-norm of c_score = 3.547513
# Value of c_logl = 1363.782938,  2-norm of c_score = 2.643513
# Value of c_logl = 1363.782938,  2-norm of c_score = 1.974827
# Value of c_logl = 1363.782938,  2-norm of c_score = 1.481584
# Value of c_logl = 1363.780735,  2-norm of c_score = 4.115244
# Value of c_logl = 1363.780735,  2-norm of c_score = 3.065213
# Value of c_logl = 1363.780735,  2-norm of c_score = 2.287947
# Value of c_logl = 1363.780735,  2-norm of c_score = 1.713729
# Value of c_logl = 1363.780732,  2-norm of c_score = 3.569928
# Value of c_logl = 1363.780732,  2-norm of c_score = 2.656124
# Value of c_logl = 1363.780732,  2-norm of c_score = 1.979465
# Value of c_logl = 1363.780732,  2-norm of c_score = 1.479223
# Value of c_logl = 1363.780732,  2-norm of c_score = 1.110680
# Value of c_logl = 1363.776253,  2-norm of c_score = 8.832741
# Value of c_logl = 1363.776252,  2-norm of c_score = 6.562588
# Value of c_logl = 1363.776252,  2-norm of c_score = 4.879264
# Value of c_logl = 1363.776252,  2-norm of c_score = 3.631455
# Value of c_logl = 1363.776251,  2-norm of c_score = 2.707015
# Value of c_logl = 1363.776251,  2-norm of c_score = 2.022903
# Value of c_logl = 1363.776251,  2-norm of c_score = 1.517786
# Value of c_logl = 1363.776249,  2-norm of c_score = 3.396073
# Value of c_logl = 1363.776249,  2-norm of c_score = 2.526956
# Value of c_logl = 1363.776249,  2-norm of c_score = 1.883134
# Value of c_logl = 1363.776249,  2-norm of c_score = 1.406784
# Value of c_logl = 1363.776249,  2-norm of c_score = 1.055218
# Value of c_logl = 1363.776248,  2-norm of c_score = 2.103067
# Value of c_logl = 1363.776248,  2-norm of c_score = 1.566200
# Value of c_logl = 1363.776248,  2-norm of c_score = 1.168973
# Value of c_logl = 1363.776248,  2-norm of c_score = 0.875787
# Value of c_logl = 1363.775480,  2-norm of c_score = 1.731886
# Value of c_logl = 1363.775480,  2-norm of c_score = 1.291348
# Value of c_logl = 1363.775480,  2-norm of c_score = 0.965710
# Value of c_logl = 1363.775480,  2-norm of c_score = 0.725867
# Value of c_logl = 1363.773626,  2-norm of c_score = 4.803621
# Value of c_logl = 1363.773626,  2-norm of c_score = 3.569455
# Value of c_logl = 1363.773625,  2-norm of c_score = 2.654375
# Value of c_logl = 1363.773625,  2-norm of c_score = 1.976117
# Value of c_logl = 1363.773625,  2-norm of c_score = 1.473724
# Value of c_logl = 1363.773625,  2-norm of c_score = 1.102072
# Value of c_logl = 1363.773625,  2-norm of c_score = 0.827864
# Value of c_logl = 1363.773625,  2-norm of c_score = 1.809585
# Value of c_logl = 1363.773625,  2-norm of c_score = 1.347276
# Value of c_logl = 1363.773625,  2-norm of c_score = 1.004935
# Value of c_logl = 1363.773625,  2-norm of c_score = 0.751831
# Value of c_logl = 1363.773625,  2-norm of c_score = 0.565322
# Value of c_logl = 1363.773624,  2-norm of c_score = 1.103091
# Value of c_logl = 1363.773624,  2-norm of c_score = 0.822502
# Value of c_logl = 1363.773624,  2-norm of c_score = 0.615091
# Value of c_logl = 1363.773624,  2-norm of c_score = 0.462316
# Value of c_logl = 1363.772878,  2-norm of c_score = 4.298181
# Value of c_logl = 1363.772878,  2-norm of c_score = 3.193280
# Value of c_logl = 1363.772878,  2-norm of c_score = 2.373970
# Value of c_logl = 1363.772878,  2-norm of c_score = 1.766593
# Value of c_logl = 1363.772878,  2-norm of c_score = 1.316550
# Value of c_logl = 1363.772878,  2-norm of c_score = 0.983403
# Value of c_logl = 1363.772878,  2-norm of c_score = 0.737259
# Value of c_logl = 1363.772878,  2-norm of c_score = 0.556143
# Value of c_logl = 1363.772878,  2-norm of c_score = 1.160835
# Value of c_logl = 1363.772878,  2-norm of c_score = 0.865939
# Value of c_logl = 1363.772878,  2-norm of c_score = 0.647840
# Value of c_logl = 1363.772878,  2-norm of c_score = 0.487009
# Value of c_logl = 1363.772877,  2-norm of c_score = 1.043517
# Value of c_logl = 1363.772877,  2-norm of c_score = 0.777256
# Value of c_logl = 1363.772877,  2-norm of c_score = 0.580155
# Value of c_logl = 1363.772877,  2-norm of c_score = 0.434527
# Value of c_logl = 1363.772877,  2-norm of c_score = 0.327374
# Value of c_logl = 1363.772877,  2-norm of c_score = 0.620762
# Value of c_logl = 1363.772877,  2-norm of c_score = 0.463403
# Value of c_logl = 1363.772877,  2-norm of c_score = 0.347217
# Value of c_logl = 1363.772760,  2-norm of c_score = 0.581415
# Value of c_logl = 1363.772760,  2-norm of c_score = 0.433958
# Value of c_logl = 1363.772760,  2-norm of c_score = 0.325042
# Value of c_logl = 1363.772759,  2-norm of c_score = 0.655288
# Value of c_logl = 1363.772759,  2-norm of c_score = 0.487664
# Value of c_logl = 1363.772759,  2-norm of c_score = 0.363587
# Value of c_logl = 1363.772759,  2-norm of c_score = 0.271924
# Value of c_logl = 1363.772687,  2-norm of c_score = 0.772603
# Value of c_logl = 1363.772687,  2-norm of c_score = 0.574851
# Value of c_logl = 1363.772687,  2-norm of c_score = 0.428385
# Value of c_logl = 1363.772687,  2-norm of c_score = 0.320052
# Value of c_logl = 1363.772687,  2-norm of c_score = 0.240149
# Value of c_logl = 1363.772629,  2-norm of c_score = 0.641354
# Value of c_logl = 1363.772629,  2-norm of c_score = 0.477792
# Value of c_logl = 1363.772629,  2-norm of c_score = 0.356740
# Value of c_logl = 1363.772629,  2-norm of c_score = 0.267344
# Value of c_logl = 1363.772629,  2-norm of c_score = 0.552375
# Value of c_logl = 1363.772629,  2-norm of c_score = 0.411081
# Value of c_logl = 1363.772629,  2-norm of c_score = 0.306478
# Value of c_logl = 1363.772629,  2-norm of c_score = 0.229179
# Value of c_logl = 1363.772578,  2-norm of c_score = 0.686261
# Value of c_logl = 1363.772578,  2-norm of c_score = 0.510537
# Value of c_logl = 1363.772578,  2-norm of c_score = 0.380359
# Value of c_logl = 1363.772578,  2-norm of c_score = 0.284032
# Value of c_logl = 1363.772578,  2-norm of c_score = 0.212919
# Value of c_logl = 1363.772578,  2-norm of c_score = 0.421874
# Value of c_logl = 1363.772578,  2-norm of c_score = 0.314111
# Value of c_logl = 1363.772578,  2-norm of c_score = 0.234374
# Value of c_logl = 1363.772578,  2-norm of c_score = 0.175515
# Value of c_logl = 1363.772547,  2-norm of c_score = 0.477415
# Value of c_logl = 1363.772547,  2-norm of c_score = 0.355409
# Value of c_logl = 1363.772547,  2-norm of c_score = 0.265083
# Value of c_logl = 1363.772547,  2-norm of c_score = 0.198331
# Value of c_logl = 1363.772547,  2-norm of c_score = 0.149191
# Value of c_logl = 1363.772468,  2-norm of c_score = 1.020713
# Value of c_logl = 1363.772468,  2-norm of c_score = 0.758470
# Value of c_logl = 1363.772468,  2-norm of c_score = 0.564030
# Value of c_logl = 1363.772468,  2-norm of c_score = 0.419912
# Value of c_logl = 1363.772468,  2-norm of c_score = 0.313164
# Value of c_logl = 1363.772468,  2-norm of c_score = 0.234195
# Value of c_logl = 1363.772468,  2-norm of c_score = 0.175932
# Value of c_logl = 1363.772468,  2-norm of c_score = 0.387747
# Value of c_logl = 1363.772468,  2-norm of c_score = 0.288667
# Value of c_logl = 1363.772468,  2-norm of c_score = 0.215294
# Value of c_logl = 1363.772468,  2-norm of c_score = 0.161038
# Value of c_logl = 1363.772468,  2-norm of c_score = 0.121045
# Value of c_logl = 1363.772468,  2-norm of c_score = 0.241434
# Value of c_logl = 1363.772468,  2-norm of c_score = 0.179950
# Value of c_logl = 1363.772468,  2-norm of c_score = 0.134481
# Value of c_logl = 1363.772468,  2-norm of c_score = 0.100956
# Value of c_logl = 1363.772458,  2-norm of c_score = 0.347655
# Value of c_logl = 1363.772458,  2-norm of c_score = 0.258796
# Value of c_logl = 1363.772458,  2-norm of c_score = 0.192987
# Value of c_logl = 1363.772458,  2-norm of c_score = 0.144319
# Value of c_logl = 1363.772458,  2-norm of c_score = 0.108436
# Value of c_logl = 1363.772458,  2-norm of c_score = 0.216954
# Value of c_logl = 1363.772458,  2-norm of c_score = 0.161673
# Value of c_logl = 1363.772458,  2-norm of c_score = 0.120786
# Value of c_logl = 1363.772444,  2-norm of c_score = 0.400273
# Value of c_logl = 1363.772444,  2-norm of c_score = 0.297643
# Value of c_logl = 1363.772444,  2-norm of c_score = 0.221580
# Value of c_logl = 1363.772444,  2-norm of c_score = 0.165247
# Value of c_logl = 1363.772444,  2-norm of c_score = 0.123587
# Value of c_logl = 1363.772444,  2-norm of c_score = 0.092868
# Value of c_logl = 1363.772436,  2-norm of c_score = 0.258900
# Value of c_logl = 1363.772436,  2-norm of c_score = 0.192882
# Value of c_logl = 1363.772436,  2-norm of c_score = 0.144009
# Value of c_logl = 1363.772436,  2-norm of c_score = 0.107894
# Value of c_logl = 1363.772436,  2-norm of c_score = 0.140610
# Value of c_logl = 1363.772436,  2-norm of c_score = 0.105239
# Value of c_logl = 1363.772436,  2-norm of c_score = 0.137877
# Value of c_logl = 1363.772436,  2-norm of c_score = 0.103085
# Value of c_logl = 1363.772436,  2-norm of c_score = 0.135562
# Value of c_logl = 1363.772436,  2-norm of c_score = 0.101250
# Value of c_logl = 1363.772436,  2-norm of c_score = 0.133225
# Value of c_logl = 1363.772436,  2-norm of c_score = 0.099409
# Value of c_logl = 1363.772427,  2-norm of c_score = 0.468345
# Value of c_logl = 1363.772427,  2-norm of c_score = 0.348021
# Value of c_logl = 1363.772427,  2-norm of c_score = 0.258806
# Value of c_logl = 1363.772427,  2-norm of c_score = 0.192681
# Value of c_logl = 1363.772427,  2-norm of c_score = 0.143700
# Value of c_logl = 1363.772427,  2-norm of c_score = 0.107465
# Value of c_logl = 1363.772427,  2-norm of c_score = 0.080727
# Value of c_logl = 1363.772427,  2-norm of c_score = 0.180557
# Value of c_logl = 1363.772427,  2-norm of c_score = 0.134402
# Value of c_logl = 1363.772427,  2-norm of c_score = 0.100217
# Value of c_logl = 1363.772427,  2-norm of c_score = 0.074931
# Value of c_logl = 1363.772427,  2-norm of c_score = 0.098804
# Value of c_logl = 1363.772427,  2-norm of c_score = 0.073795
# Value of c_logl = 1363.772423,  2-norm of c_score = 0.178431
# Value of c_logl = 1363.772423,  2-norm of c_score = 0.132702
# Value of c_logl = 1363.772423,  2-norm of c_score = 0.098811
# Value of c_logl = 1363.772423,  2-norm of c_score = 0.073712
# Value of c_logl = 1363.772423,  2-norm of c_score = 0.104942
# Value of c_logl = 1363.772423,  2-norm of c_score = 0.078147
# Value of c_logl = 1363.772423,  2-norm of c_score = 0.058307
# Value of c_logl = 1363.772422,  2-norm of c_score = 0.177246
# Value of c_logl = 1363.772422,  2-norm of c_score = 0.131837
# Value of c_logl = 1363.772422,  2-norm of c_score = 0.098184
# Value of c_logl = 1363.772422,  2-norm of c_score = 0.073264
# Value of c_logl = 1363.772422,  2-norm of c_score = 0.105173
# Value of c_logl = 1363.772422,  2-norm of c_score = 0.078327
# Value of c_logl = 1363.772422,  2-norm of c_score = 0.058450
# Value of c_logl = 1363.772422,  2-norm of c_score = 0.081479
# Value of c_logl = 1363.772422,  2-norm of c_score = 0.060705
# Value of c_logl = 1363.772422,  2-norm of c_score = 0.086084
# Value of c_logl = 1363.772422,  2-norm of c_score = 0.064040
# Value of c_logl = 1363.772422,  2-norm of c_score = 0.047712
# Value of c_logl = 1363.772420,  2-norm of c_score = 0.271158
# Value of c_logl = 1363.772420,  2-norm of c_score = 0.201427
# Value of c_logl = 1363.772420,  2-norm of c_score = 0.149718
# Value of c_logl = 1363.772420,  2-norm of c_score = 0.111382
# Value of c_logl = 1363.772420,  2-norm of c_score = 0.082972
# Value of c_logl = 1363.772420,  2-norm of c_score = 0.061935
# Value of c_logl = 1363.772420,  2-norm of c_score = 0.090052
# Value of c_logl = 1363.772420,  2-norm of c_score = 0.067075
# Value of c_logl = 1363.772420,  2-norm of c_score = 0.050061
# Value of c_logl = 1363.772420,  2-norm of c_score = 0.071972
# Value of c_logl = 1363.772420,  2-norm of c_score = 0.053609
# Value of c_logl = 1363.772420,  2-norm of c_score = 0.081085
# Value of c_logl = 1363.772420,  2-norm of c_score = 0.060278
# Value of c_logl = 1363.772420,  2-norm of c_score = 0.044856
# Value of c_logl = 1363.772420,  2-norm of c_score = 0.032526
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.235004
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.174535
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.129691
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.096439
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.071790
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.053529
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.040015
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.057142
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.042619
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.064963
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.048335
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.036012
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.056581
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.042057
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.031289
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.035274
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.026248
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.016736
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.011698
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.017836
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.013242
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.009835
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.017311
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.012860
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.009559
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.010955
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.008141
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.010574
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.007860
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.010927
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.008123
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.009220
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.010604
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.007873
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.005847
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.008611
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.006397
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.009639
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.007161
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.007923
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.005885
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.008971
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.006665
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.007658
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.005686
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.008223
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.006108
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.015049
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.011179
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.008309
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.009448
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.007020
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.007787
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.005783
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.004296
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1363.772419
#          Iterations: 632
#          Function evaluations: 1151
#          Gradient evaluations: 1782
#          Hessian evaluations: 633
#
# -------------------------------------------------------------------------------------------
# - BIAS CORRECTED JOINT FIXED EFFECTS LOGIT ESTIMATION RESULTS                             -
# -------------------------------------------------------------------------------------------
#
# Number of agents,           N :             115
# Number of dyads,            n :           6,555
#
# -------------------------------------------------------------------------------------------
#
# Independent variable       Coef.    ( Std. Err.)
# -------------------------------------------------------------------------------------------
# Distance                  -0.001949 (  0.000190)
# Other blood relation       1.361084 (  0.190788)
# Cousin, etc.               1.849783 (  0.245518)
# Sibling, child, etc.       2.898092 (  0.270260)
# Age difference            -0.004347 (  0.003730)
# Same religion              0.475105 (  0.086042)
# Same clan                  0.298620 (  0.141581)
# Same education level       0.143418 (  0.110033)
# Adjacent wealth class      0.052693 (  0.103700)
# Non-adjacent wealth class -0.043660 (  0.116544)
#
# -------------------------------------------------------------------------------------------

# %% [markdown]
# It takes some time for *dyad\_jfe\_logit()* to converge. This reflects the sparsity of the Nyakatoke network and the consequent difficulty of estimating the household degree heterogeneity effects.
# <br>
# <br>
# Relative to the *tetrad\_logit()* results, the joint estimator suggests sorting by religion and clan. In Monte Carlo experiments I have found that the joint estimator -- particularly the bias correction step -- can work very poorly in networks like the Nyakatoke one (i.e., in networks that are sparse such that many agents have only a few links). In such settings the $A_{i}$ for $i=1,...,N$ may be _very_ imprecisely estimated and this can effect the quality of the common parameter estimates as well.
# <br>
# <br>
# For reference we can look at the joint coefficient estimates prior to bias correction using the *print\_coef()* utility included in the **netrics** package. These point estimates are closer to the *tetrad\_logit()* ones than their bias-corrected counterparts. This suggests, that in this particular example, bias-correction may be doing more harm that good.
# <br>
# <br>
# Monte Carlo evidence suggests that in denser networks, the size distortion causes by bias in the limit distribution of the joint fixed effects estimator is very real and, furthermore, that bias correction can be effective in such contexts. So not too much should be made of this example.

# %%
netrics.print_coef(beta_JFE, vcov_beta_JFE, var_names=cov_names)
# Out:
# Independent variable       Coef.    ( Std. Err.)
# -------------------------------------------------------------------------------------------
# Distance                  -0.002531 (  0.000190)
# Other blood relation       1.308499 (  0.190788)
# Cousin, etc.               1.925627 (  0.245518)
# Sibling, child, etc.       2.893071 (  0.270260)
# Age difference            -0.013740 (  0.003730)
# Same religion              0.375629 (  0.086042)
# Same clan                  0.264695 (  0.141581)
# Same education level      -0.062930 (  0.110033)
# Adjacent wealth class     -0.176241 (  0.103700)
# Non-adjacent wealth class -0.298086 (  0.116544)
#
# -------------------------------------------------------------------------------------------

# %%
# This imports an attractive notebook style from Github
from IPython.core.display import HTML
import urllib2
HTML(urllib2.urlopen('http://bit.ly/1Bf5Hft').read())
# Out:
# <style>
#
# html {
#   font-size: 62.5% !important; }
# body {
#   font-size: 1.5em !important; /* currently ems cause chrome bug misinterpreting rems on body element */
#   line-height: 1.6 !important;
#   font-weight: 400 !important;
#   font-family: "Raleway", "HelveticaNeue", "Helvetica Neue", Helvetica, Arial, sans-serif !important;
#   color: #222 !important; }
#
# div{ border-radius: 0px !important;  }
# div.CodeMirror-sizer{ background: rgb(244, 244, 248) !important; }
# div.input_area{ background: rgb(244, 244, 248) !important; }
#
# div.out_prompt_overlay:hover{ background: rgb(244, 244, 248) !important; }
# div.input_prompt:hover{ background: rgb(244, 244, 248) !important; }
#
# h1, h2, h3, h4, h5, h6 {
#   color: #333 !important;
#   margin-top: 0 !important;
#   margin-bottom: 2rem !important;
#   font-weight: 300 !important; }
# h1 { font-size: 4.0rem !important; line-height: 1.2 !important;  letter-spacing: -.1rem !important;}
# h2 { font-size: 3.6rem !important; line-height: 1.25 !important; letter-spacing: -.1rem !important; }
# h3 { font-size: 3.0rem !important; line-height: 1.3 !important;  letter-spacing: -.1rem !important; }
# h4 { font-size: 2.4rem !important; line-height: 1.35 !important; letter-spacing: -.08rem !important; }
# h5 { font-size: 1.8rem !important; line-height: 1.5 !important;  letter-spacing: -.05rem !important; }
# h6 { font-size: 1.5rem !important; line-height: 1.6 !important;  letter-spacing: 0 !important; }
#
# @media (min-width: 550px) {
#   h1 { font-size: 5.0rem !important; }
#   h2 { font-size: 4.2rem !important; }
#   h3 { font-size: 3.6rem !important; }
#   h4 { font-size: 3.0rem !important; }
#   h5 { font-size: 2.4rem !important; }
#   h6 { font-size: 1.5rem !important; }
# }
#
# p {
#   margin-top: 0 !important; }
#
# a {
#   color: #1EAEDB !important; }
# a:hover {
#   color: #0FA0CE !important; }
#
# code {
#   padding: .2rem .5rem !important;
#   margin: 0 .2rem !important;
#   font-size: 90% !important;
#   white-space: nowrap !important;
#   background: #F1F1F1 !important;
#   border: 1px solid #E1E1E1 !important;
#   border-radius: 4px !important; }
# pre > code {
#   display: block !important;
#   padding: 1rem 1.5rem !important;
#   white-space: pre !important; }
#
# button{ border-radius: 0px !important; }
# .navbar-inner{ background-image: none !important;  }
# select, textarea{ border-radius: 0px !important; }
#
# </style>
