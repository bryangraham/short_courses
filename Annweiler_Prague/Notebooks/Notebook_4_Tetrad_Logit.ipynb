# %% [markdown]
# # Notebook 4: Exogenous Network Formation and Tetrad Logit
# #### Econometric Methods for Social Spillovers and Networks
# #### Charles University, August 6th and 7th, 2019
# #### Notebook updated and revised on 5 August 2019
# ##### _Bryan S. Graham, UC - Berkeley, bgraham@econ.berkeley.edu_
# This is the sixth of a series of iPython Jupyter notebooks designed to accompany a series of instructional lectures given at Charles University on August 6th and 7th, 2019. The scripts below were written for Python 3.6. The Anaconda distribution of Python, available at https://www.continuum.io/downloads, comes bundled with most the scientific computing packages used in these notebooks.
# <br>
# <br>
# For more information about the course please visit my webpage at http://bryangraham.github.io/econometrics/.
# <br>
# <br>
# In this notebook I illustrate how to fix dyadic network formation models using the two estimation procedureds studied in Graham (2017, _Econometrica_). This paper extends dyadic regression analysis to accommodate unobserved agent-specific effects.
# <br>
# <br>
# #### References
# <br>
# Graham, Bryan S. (2017). "An econometric model of network formation with degree heterogeneity,” _Econometrica_ 85 (4): 1033 - 1063.

# %% [markdown]
# I begin by importing several key packages. The _numpy_ and _scipy_ libraries include a core set of scientific computing tools. The _pandas_ package is useful for data organization and analysis, while _matplotlib_ is Python's basic plotting add-on. Finally the _networkx_ package includes functionality for the analysis, and also visualizing, network data.

# %%
# Direct Python to plot all figures inline (i.e., not in a separate window)
# %matplotlib inline

# Main scientific computing modules
import numpy as np
import scipy as sp
import pandas as pd

# Import matplotlib
import matplotlib.pyplot as plt

# networkx module for the analysis of network data
import networkx as nx

# %% [markdown]
# Load **netrics** package. The Python 2.7 version of this package is registered on [PyPi](https://pypi.python.org/pypi/netrics/), with a GitHub repository at https://github.com/bryangraham/netrics_py27. For an informal introduction to the package see [this](http://bryangraham.github.io/econometrics/networks/2016/09/15/netrics-module.html) blog post. The blog post also includes links to additional resources. The Python 3.6 version of the package is still under development, but currently available code can be found on GitHub at https://github.com/bryangraham/netrics. Once a basic level of functionality and reliability is in place I will register it on PyPi.

# %%
# Append location of ipt module base directory to system path
# NOTE: only required if permanent install not made (see comments above)
import sys
sys.path.append('/Users/bgraham/Dropbox/Sites/software/ipt/')
sys.path.append('/Users/bgraham/Dropbox/Sites/software/netrics/')

# Load ipt and netrics modules
import ipt as ipt
import netrics as netrics

# %% [markdown]
# The following code snippet should be edited to point to wherever you have saved the instructional datasets for the course

# %%
# Directory where datasets of located
data =  '/Users/bgraham/Dropbox/Teaching/Short_Courses/St_Gallen/2018/Data/'

# %% [markdown]
# A basic dyadic dataset for Nyakatoke was constructed in the Notebook 1. I begin by loading this dataset into a pandas dataframe.

# %%
# Read in estimation sample created in the notebook for Lecture 1
es = pd.read_csv(data+"Created/Nyakatoke_Estimation_Sample.csv")
es = es.set_index(['hh1', 'hh2'], drop = False)           # Set dataframe multi-index
del es['Unnamed: 0']                                      # Delete first column which is an unneeded single index

# Print out the first few rows of the dyadic data
es.head()
# Out:
#          hh1  hh2            links               kinship  distance  clan1  \
# hh1 hh2
# 1   2      1    2          no link  other blood relation      91.2   21.0
#     3      1    3          no link     no blood relation      69.6   21.0
#     4      1    4  unilateral link     no blood relation     199.2   21.0
#     5      1    5          no link     no blood relation     252.0   21.0
#     6      1    6          no link     no blood relation     213.6   21.0
#
#          clan2    wealth1   wealth2 religion1 religion2  primary1  primary2  \
# hh1 hh2
# 1   2      6.0  17.657388  6.639588  Catholic  Catholic         0         1
#     3     21.0  17.657388  1.538235  Catholic  Catholic         0         1
#     4     23.0  17.657388  2.743059  Catholic  Catholic         0         1
#     5     23.0  17.657388  1.976098  Catholic  Catholic         0         1
#     6     23.0  17.657388  1.394941  Catholic  Catholic         0         1
#
#          head_age1  head_age2  head_sex1  head_sex2
# hh1 hh2
# 1   2         75.0       30.0        1.0        1.0
#     3         75.0       48.0        1.0        0.0
#     4         75.0       80.0        1.0        1.0
#     5         75.0       35.0        1.0        1.0
#     6         75.0       28.0        1.0        1.0

# %% [markdown]
# Below we fit a dyadic link formation model using the two estimators introduced by Graham (2017, _Econometrica_). The link formation model studied in that paper is
#
#
# <div> $$\Pr\left(\left.D_{ij}=1\right|\mathbf{X},\mathbf{A}\right) = \frac{\exp\left(\sum_{k=1}^{K}W_{k,ij}\beta_{k}+A_{i}+A_{j}\right)}   {1+\exp\left(\sum_{k=1}^{K}W_{k,ij}\beta_{k}+A_{i}+A_{j}\right)}$$ </div>
#
# Here $\mathbf{X}$ denotes all the household-specific observed covariates in the network, $W_{k,ij} = W_{k,ji}$ are dyad-specific covariates constructed from $\mathbf{X}$, and the $A_i$ for $i=1,...,N$ are _degree heterogeneity_ parameters which are household specific. These are treated as co-called "fixed effects".
# <br>
# <br>
# Graham (2017) introduces a "tetrad logit" procedure which forms a criterion function, based on conditioning arguments, which is invariant to the fixed effects and also a "joint fixed effects" procedure which estimates the individual effects along with the common parameters.
# <br>
# <br>
# In the _netrics_ package these two procedures are operationalized by the *tetrad\_logit()* and *dyad\_jfe\_logit()* functions. These two functions require the user to input data in a very particular way. The outcome is $D$, the $N \times N$ adjacency matrix. The regressors are included in a length $K$ list where each element is an $N \times N $ numpy 2d array $W_{k}$ with $(i,j)$ element equal to the dyadic covariate $W_{k,ij}$. It takes a bit of work to get our Nyakatoke dataset into this form. This is what the next few snippets of code do.

# %%
hh_set = set(es['hh1'].unique()) | set(es['hh2'].unique()) # Set of all households
N = len(hh_set)                                            # Number of households
n = N * (N - 1) //2                                        # Number of dyads

# %%
# Get multi-indices for lower triangle of N x N matrix
ij_LowTri = np.tril_indices(N, -1)

# %%
# Form adjacency matrix as a dense 2d numpy array
D = np.zeros((N,N), dtype = np.bool)
D[ij_LowTri] = (es['links'] != 'no link')
D = (D + D.T)*1

# %%
# Form four categorical bins for wealth (same as used in plot of Network from Lecture 1)
wealth_bkts = [1000000, 6, 3, 1.5, 0]
wealth_bin_labels = ['+600K','(600K,300K]','(300K,150K]','(150K, 0K]']
es['wealth_cat1'] = np.digitize(es.wealth1, wealth_bkts)
es['wealth_cat2'] = np.digitize(es.wealth2, wealth_bkts)

# %% [markdown]
# Construct $K$ list of $N \times N$ dyad-specific covariate matrices.

# %%
cov_names = ['Distance','Other blood relation', 'Cousin, etc.', 'Sibling, child, etc.', 'Age difference', \
             'Same religion', 'Same clan', 'Same education level', 'Adjacent wealth class', \
             'Non-adjacent wealth class']

# Initialize K-list of dyadic covariate matrices
W = [np.zeros((N,N), dtype = np.float)]*len(cov_names)

# Distance between households
W[0][ij_LowTri] = es['distance']
W[0] = W[0] + W[0].T

# Whether two households are other blood related
W[1][ij_LowTri] = (es['kinship']=='other blood relation')*1
W[1] = W[1] + W[1].T

# Whether two households have a nephew etc. level blood relation
W[2][ij_LowTri] = (es['kinship']=='Nephew/niece/uncle/aunt,cousin,grandparent/grandchild')*1
W[2] = W[2] + W[2].T    

# Whether two households have a child etc. level blood relation
W[3][ij_LowTri] = (es['kinship']=='sibling, child, parent')*1
W[3] = W[3] + W[3].T  

# Absolute difference in age between two household heads
W[4][ij_LowTri] = np.abs(es['head_age1']-es['head_age2'])
W[4] = W[4] + W[4].T

# Whether two households are of the same religion
W[5][ij_LowTri] = (es['religion1'] == es['religion2'])*1
W[5] = W[5] + W[5].T

# Whether two households belong to the same clan
W[6][ij_LowTri] = (es['clan1'] == es['clan2'])*1
W[6] = W[6] + W[6].T

# Whether two households are of the same education level
W[7][ij_LowTri] = (es['primary1'] == es['primary2'])*1
W[7] = W[7] + W[7].T

# Whether two households are of in adjacent wealth class
W[8][ij_LowTri] = (np.abs(es['wealth_cat1'] - es['wealth_cat2']) == 1)*1
W[8] = W[8] + W[8].T

# Whether two households are of in distance wealth classes
W[9][ij_LowTri] = (np.abs(es['wealth_cat1'] - es['wealth_cat2']) > 1)*1
W[9] = W[9] + W[9].T

# %% [markdown]
# Save the adjacency matrix and the covariate matrices to an uncompressed file (this serves as a test dataset for the *tetrad\_logit()* and *dyad\_jfe\_logit()* functions). This file can be download from GitHub at https://github.com/bryangraham/netrics/blob/master/Notebooks/Nyakatoke_Example.npz.

# %%
np.savez(data+"Created/Nyakatoke_Example", D = D, Distance = W[0], OtherBlood = W[1], Cousin = W[2], \
                                           Sibling = W[3], AgeDiff = W[4], SameReligion = W[5], \
                                           SameClan = W[6], SameEdLvl = W[7], AdjacentWealthClass = W[8], \
                                           NonAdjacentWealthClass = W[9])

# %% [markdown]
# ## Tetrad Logit
# With $W$ appropriately constructed we can now fit a link formation model using *tetrad\_logit()*. We can get a sense of how the function works by viewing its help header.

# %%
help(netrics.tetrad_logit)
# Out:
# Help on function tetrad_logit in module netrics.tetrad_logit:
#
# tetrad_logit(D, W, dtcon=None, silent=False, W_names=None)
#     AUTHOR: Bryan S. Graham, bgraham@econ.berkeley.edu, June 2016
#             Revised/updated for Python 3.6 October, 2018
#
#     This function computes the Tetrad Logit estimator introduced in Graham (2017, Econometrica)
#     -- "An Econometric Model of Link Formation with Degree Heterogeneity". The implementation
#     is as described in the paper. Notation attempts to follow that used in the paper.
#
#     INPUTS
#     ------
#     D                 : N x N undirected adjacency matrix
#     W                 : List with elements consisting of N x N 2d numpy arrays of dyad-specific
#                         covariates such that W[k][i,j] gives the k-th covariate for dyad ij
#     dtcon             : Dyad and tetrad concordance (dtcon) List with elements [tetrad_to_dyads_indices,
#                         dyad_to_tetrads_dict]. If dtcon=None, then construct it using generate_tetrad_indices()
#                         function. See header to generate_tetrad_indices() for more information.
#     silent            : If True then suppress all optimization and estimation output, show output otherwise.
#     W_names           : List of K strings giving names of the columns of W_tilde. If silent=False then use
#                         these in presentation of estimation output.
#
#     OUTPUTS
#     -------
#     beta_TL          :  K x 1 vector of tetrad logit point estimates of beta
#     vcov_beta_TL     :  K x K asymptotic-variance matrix for beta_TL
#                         NOTE: vcov_beta_TL is already "divided by n" (just take square root
#                         of diagonal for std. errs.)
#     tetrad_frac_TL   :  Fraction of tetrads that contribute to Tetrad Logit criterion function
#     success          :  corresponds to success component of OptimizeResult associated with
#                         Scipy's minimize function; success = True if the tetrad logit
#                         optimizer exited successfully
#
#
#     CALLS:           : ...logit()...
#                        ...organize_data_tetrad_logit()...
#     ------

# %% [markdown]
# Finally we call *tetrad\_logit()*. Depending on the speed and memory of your computer, this next bit of code may take a few minutes to complete.

# %%
[beta_TL, vcov_beta_TL, tetrad_frac_TL, success] = \
    netrics.tetrad_logit(D, W, dtcon=None, silent=False, W_names=cov_names)
# Out:
# Fisher-Scoring Derivative check (2-norm): 83.97825828
# Value of -logL = 69158.185519,  2-norm of score = 5050101.000940
# Value of -logL = 67593.616893,  2-norm of score = 798126.605197
# Value of -logL = 67538.081576,  2-norm of score = 227764.211361
# Value of -logL = 67033.641902,  2-norm of score = 180510.666363
# Value of -logL = 66303.083394,  2-norm of score = 98018.170491
# Value of -logL = 66110.547910,  2-norm of score = 45862.868826
# Value of -logL = 59498.546153,  2-norm of score = 383793.425647
# Value of -logL = 59486.204464,  2-norm of score = 14890.282066
# Value of -logL = 57556.926540,  2-norm of score = 48275.681419
# Value of -logL = 57556.713128,  2-norm of score = 11335.705005
# Value of -logL = 55482.844366,  2-norm of score = 56718.092032
# Value of -logL = 55482.552130,  2-norm of score = 8825.014295
# Value of -logL = 52713.320941,  2-norm of score = 88089.023069
# Value of -logL = 52712.611516,  2-norm of score = 6841.114387
# Value of -logL = 51002.318076,  2-norm of score = 43317.145450
# Value of -logL = 51002.138980,  2-norm of score = 5468.068443
# Value of -logL = 49370.049745,  2-norm of score = 53249.152133
# Value of -logL = 49369.769408,  2-norm of score = 4019.173009
# Value of -logL = 48672.590390,  2-norm of score = 11247.660399
# Value of -logL = 48672.576423,  2-norm of score = 3468.331595
# Value of -logL = 48122.013390,  2-norm of score = 8455.907930
# Value of -logL = 47771.329668,  2-norm of score = 47829.201116
# Value of -logL = 47771.082825,  2-norm of score = 2592.771185
# Value of -logL = 47610.841750,  2-norm of score = 2660.110512
# Value of -logL = 47450.032102,  2-norm of score = 28257.521048
# Value of -logL = 47449.945960,  2-norm of score = 1485.404349
# Value of -logL = 47243.731016,  2-norm of score = 3705.727023
# Value of -logL = 47189.024597,  2-norm of score = 8475.809121
# Value of -logL = 47189.016513,  2-norm of score = 1126.448983
# Value of -logL = 47108.982259,  2-norm of score = 1281.294309
# Value of -logL = 46991.847840,  2-norm of score = 5055.560320
# Value of -logL = 46991.844911,  2-norm of score = 411.121014
# Value of -logL = 46984.260462,  2-norm of score = 360.493389
# Value of -logL = 46971.185893,  2-norm of score = 329.255083
# Value of -logL = 46957.615078,  2-norm of score = 1104.025022
# Value of -logL = 46957.614936,  2-norm of score = 13.375831
# Value of -logL = 46957.609369,  2-norm of score = 11.485992
# Value of -logL = 46957.600237,  2-norm of score = 7.539819
# Value of -logL = 46957.592318,  2-norm of score = 2.944535
# Value of -logL = 46957.591650,  2-norm of score = 0.682811
# Value of -logL = 46957.591557,  2-norm of score = 0.068719
# Value of -logL = 46957.591557,  2-norm of score = 0.016805
# Value of -logL = 46957.591557,  2-norm of score = 0.002933
# Value of -logL = 46957.591557,  2-norm of score = 0.000107
# Value of -logL = 46957.591557,  2-norm of score = 0.000001
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 46957.591557
#          Iterations: 45
#          Function evaluations: 110
#          Gradient evaluations: 154
#          Hessian evaluations: 46
#
# -------------------------------------------------------------------------------------------
# - TETRAD LOGIT ESTIMATION RESULTS                                                         -
# -------------------------------------------------------------------------------------------
#
# Number of agents,           N :             115
# Number of dyads,            n :           6,555
# Number of tetrads             :       6,913,340
# Number identifying tetrads    :         102,151
# Fraction identifying tetrads  :        0.014776
#
# -------------------------------------------------------------------------------------------
#
# Independent variable       Coef.    ( Std. Err.)     (0.95 Confid. Interval )
# -------------------------------------------------------------------------------------------
# Distance                  -0.002098 (  0.000321)     ( -0.002728 , -0.001468)
# Other blood relation       1.263222 (  0.295226)     (  0.684589 ,  1.841855)
# Cousin, etc.               2.045045 (  0.373156)     (  1.313671 ,  2.776418)
# Sibling, child, etc.       2.674647 (  0.415617)     (  1.860053 ,  3.489241)
# Age difference            -0.014230 (  0.005989)     ( -0.025968 , -0.002491)
# Same religion              0.234212 (  0.141803)     ( -0.043717 ,  0.512140)
# Same clan                  0.272891 (  0.215871)     ( -0.150207 ,  0.695990)
# Same education level       0.216351 (  0.148914)     ( -0.075515 ,  0.508217)
# Adjacent wealth class     -0.220430 (  0.160917)     ( -0.535821 ,  0.094961)
# Non-adjacent wealth class -0.228703 (  0.175977)     ( -0.573612 ,  0.116207)
#
# -------------------------------------------------------------------------------------------

# %% [markdown]
# The program spits out some useful information. In a network with $N = 115$ agents there are a total of $6,913,340$ different tetrads! Of these only $102,151$, or about 1.5 percent, actually contribute to the *tetrad\_logit()* criterion function. The effectiveness of the procedure in the context of sparse networks is one of its theoretical and practical attractions.
# <br>
# <br>
# The results suggest that ties are more frequent between households which are physically close, related by blood and where the household heads are close in age. There is little evidence for sorting by religion, clan or education. There is some evidence for heterophily in terms of wealth (perhaps consistent with some models of "mutual support"), but it is rather weak.
# <br>
# <br>
# The *tetrad\_logit()* estimation procedure is computationally intense. On a modern desktop machine it would be difficult to use the procedure on a network larger than a few hundred agents (fortunately there are many possible ways to apply the method at scale via various approximations and parallelizations; but these extensions are not yet part of the _netrics_ package).
# <br>
# <br>
# Part of the computational intensity is up front. Specifically, the function computes a detailed dictionary which maps dyads-to-tetrads and vice-versa. This bookkeeping overhead makes later calculations much quicker. A user who anticipates fitting several different models to the same adjacency matrix can save considerable time by computing this concordance first (once and for all) and then passing it to *tetrad\_logit()* via the _dtcon_ parameter. This can be done by calling the *generate\_tetrad\_indices()* function.
# <br>
# <br>
# To illustrate I create the concordance and then fit a model with only the distance and kinship variables included.

# %%
N = np.shape(D)[0]
concordance = netrics.generate_tetrad_indices(N, full_set=True)
[beta_TL, vcov_beta_TL, tetrad_frac_TL, success] = \
    netrics.tetrad_logit(D, W[0:4], dtcon=concordance, silent=False, W_names=cov_names[0:4])
# Out:
# Fisher-Scoring Derivative check (2-norm): 83.97815270
# Value of -logL = 69163.219760,  2-norm of score = 5045814.882187
# Value of -logL = 67604.839042,  2-norm of score = 772959.875424
# Value of -logL = 67557.021217,  2-norm of score = 30472.353371
# Value of -logL = 60570.400356,  2-norm of score = 312602.526238
# Value of -logL = 60562.289810,  2-norm of score = 9904.763502
# Value of -logL = 55914.238422,  2-norm of score = 204713.530248
# Value of -logL = 55910.626413,  2-norm of score = 6252.561686
# Value of -logL = 53745.636791,  2-norm of score = 62366.323282
# Value of -logL = 53745.286498,  2-norm of score = 4450.442313
# Value of -logL = 52853.898960,  2-norm of score = 13360.325113
# Value of -logL = 52853.881208,  2-norm of score = 3931.549248
# Value of -logL = 52132.404515,  2-norm of score = 9742.309208
# Value of -logL = 52132.394608,  2-norm of score = 3371.576692
# Value of -logL = 51720.031397,  2-norm of score = 4052.700812
# Value of -logL = 50991.842893,  2-norm of score = 17599.721535
# Value of -logL = 50991.812411,  2-norm of score = 2149.192227
# Value of -logL = 50682.101073,  2-norm of score = 3851.221553
# Value of -logL = 50172.487618,  2-norm of score = 16516.105463
# Value of -logL = 50172.459697,  2-norm of score = 1156.617786
# Value of -logL = 49922.476346,  2-norm of score = 6234.250147
# Value of -logL = 49922.472223,  2-norm of score = 734.826476
# Value of -logL = 49879.842850,  2-norm of score = 669.981301
# Value of -logL = 49806.495490,  2-norm of score = 1373.155590
# Value of -logL = 49806.495265,  2-norm of score = 478.409182
# Value of -logL = 49771.827415,  2-norm of score = 455.643624
# Value of -logL = 49728.736103,  2-norm of score = 2038.780078
# Value of -logL = 49728.735646,  2-norm of score = 82.412668
# Value of -logL = 49727.612693,  2-norm of score = 64.882457
# Value of -logL = 49726.049478,  2-norm of score = 50.312638
# Value of -logL = 49725.779417,  2-norm of score = 16.628135
# Value of -logL = 49725.779417,  2-norm of score = 2.008005
# Value of -logL = 49725.779115,  2-norm of score = 1.546773
# Value of -logL = 49725.778714,  2-norm of score = 0.489098
# Value of -logL = 49725.778667,  2-norm of score = 0.100898
# Value of -logL = 49725.778663,  2-norm of score = 0.039405
# Value of -logL = 49725.778663,  2-norm of score = 0.008846
# Value of -logL = 49725.778663,  2-norm of score = 0.000029
# Value of -logL = 49725.778663,  2-norm of score = 0.000025
# Value of -logL = 49725.778663,  2-norm of score = 0.000000
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 49725.778663
#          Iterations: 39
#          Function evaluations: 136
#          Gradient evaluations: 171
#          Hessian evaluations: 40
#
# -------------------------------------------------------------------------------------------
# - TETRAD LOGIT ESTIMATION RESULTS                                                         -
# -------------------------------------------------------------------------------------------
#
# Number of agents,           N :             115
# Number of dyads,            n :           6,555
# Number of tetrads             :       6,913,340
# Number identifying tetrads    :         102,151
# Fraction identifying tetrads  :        0.014776
#
# -------------------------------------------------------------------------------------------
#
# Independent variable       Coef.    ( Std. Err.)     (0.95 Confid. Interval )
# -------------------------------------------------------------------------------------------
# Distance                  -0.002067 (  0.000328)     ( -0.002710 , -0.001424)
# Other blood relation       1.307596 (  0.293372)     (  0.732597 ,  1.882595)
# Cousin, etc.               2.209613 (  0.393581)     (  1.438208 ,  2.981019)
# Sibling, child, etc.       2.895174 (  0.393442)     (  2.124043 ,  3.666305)
#
# -------------------------------------------------------------------------------------------

# %% [markdown]
# ## Joint Fixed Effects Logit
# Graham (2017) also introduces a joint fixed effects estimator for link formation. This procedure estimates the coefficients on $W_{k,ij}$ for $k=1,...,K$ as well as individual specific degree heterogeneity parameters $A_{i}$ for $i=1,...,N$. The *dyad\_jfe\_logit()* function implements this estimator. By default it reports the iterated bias-corrected estimates described in the paper (but the uncorrected estimates are also returned by the function).

# %%
[beta_JFE, beta_JFE_BC, vcov_beta_JFE, A_JFE, success] = \
    netrics.dyad_jfe_logit(D, W, T=None, silent=False, W_names=cov_names, beta_sv=None)
# Out:
# -------------------------------------------------------------------------------------------
# - COMPUTE JOINT FIXED EFFECT MLEs                                                         -
# -------------------------------------------------------------------------------------------
# Value of c_logl = 1573.908738,  2-norm of c_score = 62611.044224
# Value of c_logl = 1547.376177,  2-norm of c_score = 48351.975346
# Value of c_logl = 1529.569133,  2-norm of c_score = 37055.111351
# Value of c_logl = 1517.970298,  2-norm of c_score = 28245.611857
# Value of c_logl = 1510.616124,  2-norm of c_score = 21451.154557
# Value of c_logl = 1506.059542,  2-norm of c_score = 16250.785299
# Value of c_logl = 1503.289015,  2-norm of c_score = 12291.724887
# Value of c_logl = 1501.628916,  2-norm of c_score = 9289.087258
# Value of c_logl = 1500.644547,  2-norm of c_score = 7018.123943
# Value of c_logl = 1500.064460,  2-norm of c_score = 5304.215796
# Value of c_logl = 1499.723062,  2-norm of c_score = 4013.098329
# Value of c_logl = 1499.521112,  2-norm of c_score = 3042.322468
# Value of c_logl = 1499.399887,  2-norm of c_score = 2314.241468
# Value of c_logl = 1499.324853,  2-norm of c_score = 1770.525243
# Value of c_logl = 1498.606942,  2-norm of c_score = 2257.517124
# Value of c_logl = 1498.536576,  2-norm of c_score = 1724.198887
# Value of c_logl = 1497.866883,  2-norm of c_score = 2222.491160
# Value of c_logl = 1497.799814,  2-norm of c_score = 1694.206383
# Value of c_logl = 1497.757260,  2-norm of c_score = 1301.461429
# Value of c_logl = 1496.258750,  2-norm of c_score = 2731.275742
# Value of c_logl = 1496.164289,  2-norm of c_score = 2066.538171
# Value of c_logl = 1496.108257,  2-norm of c_score = 1568.431114
# Value of c_logl = 1496.074096,  2-norm of c_score = 1196.493358
# Value of c_logl = 1495.748416,  2-norm of c_score = 1536.654739
# Value of c_logl = 1495.716105,  2-norm of c_score = 1170.305710
# Value of c_logl = 1495.695683,  2-norm of c_score = 898.185033
# Value of c_logl = 1494.970061,  2-norm of c_score = 1855.434213
# Value of c_logl = 1494.925901,  2-norm of c_score = 1403.211445
# Value of c_logl = 1494.899748,  2-norm of c_score = 1064.698503
# Value of c_logl = 1494.883785,  2-norm of c_score = 812.235466
# Value of c_logl = 1494.730646,  2-norm of c_score = 1029.768392
# Value of c_logl = 1494.715870,  2-norm of c_score = 784.638654
# Value of c_logl = 1494.574599,  2-norm of c_score = 1002.110306
# Value of c_logl = 1494.560773,  2-norm of c_score = 762.525127
# Value of c_logl = 1494.429198,  2-norm of c_score = 983.152617
# Value of c_logl = 1494.416067,  2-norm of c_score = 746.957424
# Value of c_logl = 1494.407920,  2-norm of c_score = 571.273747
# Value of c_logl = 1494.119094,  2-norm of c_score = 1179.938243
# Value of c_logl = 1494.101159,  2-norm of c_score = 891.030646
# Value of c_logl = 1494.090632,  2-norm of c_score = 674.794653
# Value of c_logl = 1494.084286,  2-norm of c_score = 513.439555
# Value of c_logl = 1493.868376,  2-norm of c_score = 1112.276465
# Value of c_logl = 1493.852621,  2-norm of c_score = 837.952085
# Value of c_logl = 1493.843520,  2-norm of c_score = 632.383209
# Value of c_logl = 1493.838184,  2-norm of c_score = 478.581735
# Value of c_logl = 1493.834969,  2-norm of c_score = 363.867325
# Value of c_logl = 1493.718279,  2-norm of c_score = 726.240236
# Value of c_logl = 1493.711459,  2-norm of c_score = 547.336556
# Value of c_logl = 1493.707488,  2-norm of c_score = 413.430733
# Value of c_logl = 1493.705122,  2-norm of c_score = 313.455046
# Value of c_logl = 1470.159597,  2-norm of c_score = 2603.847691
# Value of c_logl = 1470.070915,  2-norm of c_score = 1947.657279
# Value of c_logl = 1470.021684,  2-norm of c_score = 1457.470781
# Value of c_logl = 1469.994248,  2-norm of c_score = 1091.224139
# Value of c_logl = 1469.978893,  2-norm of c_score = 817.568694
# Value of c_logl = 1469.970254,  2-norm of c_score = 613.127298
# Value of c_logl = 1469.965354,  2-norm of c_score = 460.464533
# Value of c_logl = 1469.962539,  2-norm of c_score = 346.583242
# Value of c_logl = 1469.960883,  2-norm of c_score = 261.816817
# Value of c_logl = 1453.285485,  2-norm of c_score = 2459.152827
# Value of c_logl = 1453.206831,  2-norm of c_score = 1837.869326
# Value of c_logl = 1453.163137,  2-norm of c_score = 1374.772483
# Value of c_logl = 1453.138705,  2-norm of c_score = 1029.606809
# Value of c_logl = 1453.124920,  2-norm of c_score = 772.440744
# Value of c_logl = 1453.117033,  2-norm of c_score = 581.025225
# Value of c_logl = 1453.112414,  2-norm of c_score = 438.854873
# Value of c_logl = 1453.068451,  2-norm of c_score = 570.510772
# Value of c_logl = 1453.064048,  2-norm of c_score = 430.357444
# Value of c_logl = 1453.061393,  2-norm of c_score = 326.593534
# Value of c_logl = 1452.966612,  2-norm of c_score = 676.772135
# Value of c_logl = 1452.960655,  2-norm of c_score = 507.905365
# Value of c_logl = 1452.957228,  2-norm of c_score = 382.242077
# Value of c_logl = 1452.955203,  2-norm of c_score = 288.977618
# Value of c_logl = 1452.883676,  2-norm of c_score = 610.249707
# Value of c_logl = 1452.878869,  2-norm of c_score = 457.286012
# Value of c_logl = 1452.876130,  2-norm of c_score = 343.353994
# Value of c_logl = 1452.874537,  2-norm of c_score = 258.643576
# Value of c_logl = 1437.110919,  2-norm of c_score = 2507.055192
# Value of c_logl = 1437.029535,  2-norm of c_score = 1870.408370
# Value of c_logl = 1436.984504,  2-norm of c_score = 1396.639821
# Value of c_logl = 1436.959429,  2-norm of c_score = 1044.098207
# Value of c_logl = 1436.945345,  2-norm of c_score = 781.859442
# Value of c_logl = 1436.937329,  2-norm of c_score = 586.969419
# Value of c_logl = 1436.932665,  2-norm of c_score = 442.420034
# Value of c_logl = 1436.929841,  2-norm of c_score = 335.687333
# Value of c_logl = 1436.829463,  2-norm of c_score = 699.461791
# Value of c_logl = 1436.823124,  2-norm of c_score = 524.283206
# Value of c_logl = 1436.819483,  2-norm of c_score = 394.172130
# Value of c_logl = 1436.817330,  2-norm of c_score = 297.813044
# Value of c_logl = 1436.743524,  2-norm of c_score = 650.432597
# Value of c_logl = 1436.738105,  2-norm of c_score = 486.598012
# Value of c_logl = 1436.735033,  2-norm of c_score = 364.752073
# Value of c_logl = 1436.733262,  2-norm of c_score = 274.272981
# Value of c_logl = 1436.732208,  2-norm of c_score = 207.309039
# Value of c_logl = 1436.693509,  2-norm of c_score = 415.815236
# Value of c_logl = 1436.691273,  2-norm of c_score = 311.412795
# Value of c_logl = 1436.689988,  2-norm of c_score = 233.854934
# Value of c_logl = 1436.689229,  2-norm of c_score = 176.407497
# Value of c_logl = 1428.816151,  2-norm of c_score = 1274.246136
# Value of c_logl = 1428.795467,  2-norm of c_score = 950.764856
# Value of c_logl = 1428.783948,  2-norm of c_score = 710.150088
# Value of c_logl = 1428.777484,  2-norm of c_score = 531.242521
# Value of c_logl = 1428.773814,  2-norm of c_score = 398.333176
# Value of c_logl = 1428.771686,  2-norm of c_score = 299.779210
# Value of c_logl = 1428.770408,  2-norm of c_score = 226.999307
# Value of c_logl = 1428.724319,  2-norm of c_score = 466.411734
# Value of c_logl = 1428.721512,  2-norm of c_score = 349.273375
# Value of c_logl = 1428.719900,  2-norm of c_score = 262.330197
# Value of c_logl = 1428.718947,  2-norm of c_score = 197.993346
# Value of c_logl = 1428.684486,  2-norm of c_score = 406.755041
# Value of c_logl = 1428.682362,  2-norm of c_score = 304.242848
# Value of c_logl = 1428.681149,  2-norm of c_score = 228.107981
# Value of c_logl = 1428.680441,  2-norm of c_score = 171.697768
# Value of c_logl = 1421.341261,  2-norm of c_score = 1175.274527
# Value of c_logl = 1421.323729,  2-norm of c_score = 876.386829
# Value of c_logl = 1421.313976,  2-norm of c_score = 654.182086
# Value of c_logl = 1421.308510,  2-norm of c_score = 489.049983
# Value of c_logl = 1421.305412,  2-norm of c_score = 366.436910
# Value of c_logl = 1421.303620,  2-norm of c_score = 275.559620
# Value of c_logl = 1421.302546,  2-norm of c_score = 208.470779
# Value of c_logl = 1421.264038,  2-norm of c_score = 431.600936
# Value of c_logl = 1421.261645,  2-norm of c_score = 322.951420
# Value of c_logl = 1421.260274,  2-norm of c_score = 242.341930
# Value of c_logl = 1421.259468,  2-norm of c_score = 182.705119
# Value of c_logl = 1421.230556,  2-norm of c_score = 380.290004
# Value of c_logl = 1421.228708,  2-norm of c_score = 284.189109
# Value of c_logl = 1421.227657,  2-norm of c_score = 212.839546
# Value of c_logl = 1421.227047,  2-norm of c_score = 159.978210
# Value of c_logl = 1414.878726,  2-norm of c_score = 976.156245
# Value of c_logl = 1414.866679,  2-norm of c_score = 727.688198
# Value of c_logl = 1414.859975,  2-norm of c_score = 543.038520
# Value of c_logl = 1414.856215,  2-norm of c_score = 405.877288
# Value of c_logl = 1414.854080,  2-norm of c_score = 304.089325
# Value of c_logl = 1414.852842,  2-norm of c_score = 228.703923
# Value of c_logl = 1414.852096,  2-norm of c_score = 173.120146
# Value of c_logl = 1414.824898,  2-norm of c_score = 350.161314
# Value of c_logl = 1414.823318,  2-norm of c_score = 262.074972
# Value of c_logl = 1414.822409,  2-norm of c_score = 196.789127
# Value of c_logl = 1414.821867,  2-norm of c_score = 148.575716
# Value of c_logl = 1414.801899,  2-norm of c_score = 296.156046
# Value of c_logl = 1414.800771,  2-norm of c_score = 221.483488
# Value of c_logl = 1414.800123,  2-norm of c_score = 166.122625
# Value of c_logl = 1414.799740,  2-norm of c_score = 125.214073
# Value of c_logl = 1400.451248,  2-norm of c_score = 1946.471753
# Value of c_logl = 1400.403051,  2-norm of c_score = 1448.825508
# Value of c_logl = 1400.376471,  2-norm of c_score = 1079.209050
# Value of c_logl = 1400.361736,  2-norm of c_score = 804.716978
# Value of c_logl = 1400.353507,  2-norm of c_score = 600.942575
# Value of c_logl = 1400.348859,  2-norm of c_score = 449.789523
# Value of c_logl = 1400.346183,  2-norm of c_score = 337.860442
# Value of c_logl = 1400.344590,  2-norm of c_score = 255.284059
# Value of c_logl = 1400.289754,  2-norm of c_score = 555.328725
# Value of c_logl = 1400.285840,  2-norm of c_score = 414.831361
# Value of c_logl = 1400.283621,  2-norm of c_score = 310.625717
# Value of c_logl = 1400.282338,  2-norm of c_score = 233.488291
# Value of c_logl = 1400.281567,  2-norm of c_score = 176.632327
# Value of c_logl = 1400.254147,  2-norm of c_score = 369.412869
# Value of c_logl = 1400.252407,  2-norm of c_score = 276.197769
# Value of c_logl = 1400.251411,  2-norm of c_score = 207.109824
# Value of c_logl = 1400.250827,  2-norm of c_score = 156.049588
# Value of c_logl = 1400.230641,  2-norm of c_score = 339.438593
# Value of c_logl = 1400.229186,  2-norm of c_score = 253.334545
# Value of c_logl = 1400.228364,  2-norm of c_score = 189.443007
# Value of c_logl = 1400.227891,  2-norm of c_score = 142.110973
# Value of c_logl = 1400.227611,  2-norm of c_score = 107.168585
# Value of c_logl = 1400.217173,  2-norm of c_score = 210.176568
# Value of c_logl = 1400.216607,  2-norm of c_score = 157.084480
# Value of c_logl = 1400.216282,  2-norm of c_score = 117.751865
# Value of c_logl = 1400.216089,  2-norm of c_score = 88.714708
# Value of c_logl = 1392.362599,  2-norm of c_score = 389.514284
# Value of c_logl = 1392.360697,  2-norm of c_score = 290.383317
# Value of c_logl = 1392.359631,  2-norm of c_score = 216.796713
# Value of c_logl = 1392.359027,  2-norm of c_score = 162.225803
# Value of c_logl = 1392.358678,  2-norm of c_score = 121.837979
# Value of c_logl = 1392.346735,  2-norm of c_score = 268.739917
# Value of c_logl = 1392.345828,  2-norm of c_score = 200.294718
# Value of c_logl = 1392.345319,  2-norm of c_score = 149.492775
# Value of c_logl = 1392.345030,  2-norm of c_score = 111.829996
# Value of c_logl = 1392.344861,  2-norm of c_score = 83.975144
# Value of c_logl = 1385.469432,  2-norm of c_score = 259.780645
# Value of c_logl = 1385.468585,  2-norm of c_score = 193.698029
# Value of c_logl = 1385.468109,  2-norm of c_score = 144.671887
# Value of c_logl = 1385.467837,  2-norm of c_score = 108.349129
# Value of c_logl = 1385.467678,  2-norm of c_score = 81.514368
# Value of c_logl = 1385.461790,  2-norm of c_score = 162.422906
# Value of c_logl = 1385.461455,  2-norm of c_score = 121.223515
# Value of c_logl = 1385.461265,  2-norm of c_score = 90.695040
# Value of c_logl = 1385.461153,  2-norm of c_score = 68.134735
# Value of c_logl = 1380.839130,  2-norm of c_score = 178.689236
# Value of c_logl = 1380.838728,  2-norm of c_score = 133.312337
# Value of c_logl = 1380.838499,  2-norm of c_score = 99.678862
# Value of c_logl = 1380.838367,  2-norm of c_score = 74.802601
# Value of c_logl = 1380.833532,  2-norm of c_score = 151.496252
# Value of c_logl = 1380.833243,  2-norm of c_score = 112.922379
# Value of c_logl = 1380.833080,  2-norm of c_score = 84.325720
# Value of c_logl = 1380.832985,  2-norm of c_score = 63.166818
# Value of c_logl = 1376.941011,  2-norm of c_score = 193.502626
# Value of c_logl = 1376.940543,  2-norm of c_score = 144.147325
# Value of c_logl = 1376.940281,  2-norm of c_score = 107.539133
# Value of c_logl = 1376.940132,  2-norm of c_score = 80.417545
# Value of c_logl = 1376.940046,  2-norm of c_score = 60.372469
# Value of c_logl = 1373.406628,  2-norm of c_score = 167.373096
# Value of c_logl = 1373.406278,  2-norm of c_score = 124.780324
# Value of c_logl = 1373.406080,  2-norm of c_score = 93.211953
# Value of c_logl = 1373.405966,  2-norm of c_score = 69.854085
# Value of c_logl = 1373.405899,  2-norm of c_score = 52.633651
# Value of c_logl = 1373.403390,  2-norm of c_score = 103.404639
# Value of c_logl = 1373.403254,  2-norm of c_score = 77.205943
# Value of c_logl = 1373.403176,  2-norm of c_score = 57.821125
# Value of c_logl = 1373.403130,  2-norm of c_score = 43.530100
# Value of c_logl = 1371.473937,  2-norm of c_score = 152.828603
# Value of c_logl = 1371.473645,  2-norm of c_score = 113.909336
# Value of c_logl = 1371.473480,  2-norm of c_score = 85.065788
# Value of c_logl = 1371.473386,  2-norm of c_score = 63.724077
# Value of c_logl = 1371.473330,  2-norm of c_score = 47.987301
# Value of c_logl = 1371.471263,  2-norm of c_score = 95.112428
# Value of c_logl = 1371.471148,  2-norm of c_score = 70.985079
# Value of c_logl = 1371.471082,  2-norm of c_score = 53.130963
# Value of c_logl = 1371.471044,  2-norm of c_score = 39.962941
# Value of c_logl = 1369.859683,  2-norm of c_score = 141.954920
# Value of c_logl = 1369.859431,  2-norm of c_score = 105.770170
# Value of c_logl = 1369.859289,  2-norm of c_score = 78.953156
# Value of c_logl = 1369.859208,  2-norm of c_score = 59.108052
# Value of c_logl = 1369.859161,  2-norm of c_score = 44.467832
# Value of c_logl = 1369.857417,  2-norm of c_score = 89.759581
# Value of c_logl = 1369.857315,  2-norm of c_score = 66.945615
# Value of c_logl = 1369.857257,  2-norm of c_score = 50.057690
# Value of c_logl = 1369.857224,  2-norm of c_score = 37.591095
# Value of c_logl = 1368.457219,  2-norm of c_score = 140.710996
# Value of c_logl = 1368.456972,  2-norm of c_score = 104.783342
# Value of c_logl = 1368.456834,  2-norm of c_score = 78.152148
# Value of c_logl = 1368.456756,  2-norm of c_score = 58.434890
# Value of c_logl = 1368.456710,  2-norm of c_score = 43.871425
# Value of c_logl = 1368.455098,  2-norm of c_score = 93.215965
# Value of c_logl = 1368.454989,  2-norm of c_score = 69.430332
# Value of c_logl = 1368.454928,  2-norm of c_score = 51.808169
# Value of c_logl = 1368.454893,  2-norm of c_score = 38.774439
# Value of c_logl = 1368.454872,  2-norm of c_score = 29.169220
# Value of c_logl = 1365.516313,  2-norm of c_score = 310.082706
# Value of c_logl = 1365.515123,  2-norm of c_score = 230.445436
# Value of c_logl = 1365.514465,  2-norm of c_score = 171.382304
# Value of c_logl = 1365.514100,  2-norm of c_score = 127.589725
# Value of c_logl = 1365.513896,  2-norm of c_score = 95.136383
# Value of c_logl = 1365.513780,  2-norm of c_score = 71.110533
# Value of c_logl = 1365.513713,  2-norm of c_score = 53.360169
# Value of c_logl = 1365.513673,  2-norm of c_score = 40.304740
# Value of c_logl = 1365.512244,  2-norm of c_score = 84.192222
# Value of c_logl = 1365.512154,  2-norm of c_score = 62.842042
# Value of c_logl = 1365.512103,  2-norm of c_score = 47.050290
# Value of c_logl = 1365.512073,  2-norm of c_score = 35.405802
# Value of c_logl = 1365.511031,  2-norm of c_score = 77.079603
# Value of c_logl = 1365.510957,  2-norm of c_score = 57.433166
# Value of c_logl = 1365.510915,  2-norm of c_score = 42.884531
# Value of c_logl = 1365.510891,  2-norm of c_score = 32.130246
# Value of c_logl = 1365.510877,  2-norm of c_score = 24.211281
# Value of c_logl = 1365.510349,  2-norm of c_score = 48.414285
# Value of c_logl = 1365.510319,  2-norm of c_score = 36.124957
# Value of c_logl = 1365.510302,  2-norm of c_score = 27.038253
# Value of c_logl = 1365.510292,  2-norm of c_score = 20.343245
# Value of c_logl = 1365.509910,  2-norm of c_score = 38.707751
# Value of c_logl = 1365.509891,  2-norm of c_score = 28.881851
# Value of c_logl = 1365.509880,  2-norm of c_score = 21.620712
# Value of c_logl = 1365.057869,  2-norm of c_score = 74.674665
# Value of c_logl = 1365.057799,  2-norm of c_score = 55.560973
# Value of c_logl = 1365.057761,  2-norm of c_score = 41.396679
# Value of c_logl = 1365.057739,  2-norm of c_score = 30.910495
# Value of c_logl = 1365.057726,  2-norm of c_score = 23.162722
# Value of c_logl = 1365.057283,  2-norm of c_score = 49.764720
# Value of c_logl = 1365.057252,  2-norm of c_score = 37.026817
# Value of c_logl = 1365.057235,  2-norm of c_score = 27.591062
# Value of c_logl = 1365.057225,  2-norm of c_score = 20.611092
# Value of c_logl = 1365.057219,  2-norm of c_score = 15.462675
# Value of c_logl = 1364.238131,  2-norm of c_score = 160.279934
# Value of c_logl = 1364.237814,  2-norm of c_score = 119.065481
# Value of c_logl = 1364.237638,  2-norm of c_score = 88.505808
# Value of c_logl = 1364.237541,  2-norm of c_score = 65.851851
# Value of c_logl = 1364.237487,  2-norm of c_score = 49.066073
# Value of c_logl = 1364.237456,  2-norm of c_score = 36.639346
# Value of c_logl = 1364.237439,  2-norm of c_score = 27.455848
# Value of c_logl = 1364.237428,  2-norm of c_score = 20.694619
# Value of c_logl = 1364.237062,  2-norm of c_score = 44.205942
# Value of c_logl = 1364.237037,  2-norm of c_score = 32.956980
# Value of c_logl = 1364.237023,  2-norm of c_score = 24.633794
# Value of c_logl = 1364.237015,  2-norm of c_score = 18.489924
# Value of c_logl = 1364.236744,  2-norm of c_score = 41.669209
# Value of c_logl = 1364.236722,  2-norm of c_score = 31.006169
# Value of c_logl = 1364.236710,  2-norm of c_score = 23.107626
# Value of c_logl = 1364.236703,  2-norm of c_score = 17.263829
# Value of c_logl = 1364.236699,  2-norm of c_score = 12.950815
# Value of c_logl = 1364.236555,  2-norm of c_score = 26.679408
# Value of c_logl = 1364.236546,  2-norm of c_score = 19.862845
# Value of c_logl = 1364.236541,  2-norm of c_score = 14.817719
# Value of c_logl = 1364.236538,  2-norm of c_score = 11.091349
# Value of c_logl = 1364.116587,  2-norm of c_score = 23.292173
# Value of c_logl = 1364.116580,  2-norm of c_score = 17.353734
# Value of c_logl = 1364.116576,  2-norm of c_score = 12.960685
# Value of c_logl = 1364.116574,  2-norm of c_score = 9.719105
# Value of c_logl = 1364.023716,  2-norm of c_score = 29.999381
# Value of c_logl = 1364.023705,  2-norm of c_score = 22.331778
# Value of c_logl = 1364.023699,  2-norm of c_score = 16.654267
# Value of c_logl = 1364.023695,  2-norm of c_score = 12.456593
# Value of c_logl = 1364.023693,  2-norm of c_score = 9.362741
# Value of c_logl = 1364.023615,  2-norm of c_score = 18.824352
# Value of c_logl = 1364.023611,  2-norm of c_score = 14.028040
# Value of c_logl = 1364.023608,  2-norm of c_score = 10.481117
# Value of c_logl = 1364.023607,  2-norm of c_score = 7.865695
# Value of c_logl = 1363.961724,  2-norm of c_score = 22.988326
# Value of c_logl = 1363.961717,  2-norm of c_score = 17.118823
# Value of c_logl = 1363.961714,  2-norm of c_score = 12.774403
# Value of c_logl = 1363.961712,  2-norm of c_score = 9.564778
# Value of c_logl = 1363.961710,  2-norm of c_score = 7.203034
# Value of c_logl = 1363.961662,  2-norm of c_score = 13.710565
# Value of c_logl = 1363.961659,  2-norm of c_score = 10.231692
# Value of c_logl = 1363.961658,  2-norm of c_score = 7.663084
# Value of c_logl = 1363.904576,  2-norm of c_score = 24.758810
# Value of c_logl = 1363.904569,  2-norm of c_score = 18.421372
# Value of c_logl = 1363.904565,  2-norm of c_score = 13.727715
# Value of c_logl = 1363.904562,  2-norm of c_score = 10.255645
# Value of c_logl = 1363.904561,  2-norm of c_score = 7.693534
# Value of c_logl = 1363.904510,  2-norm of c_score = 16.058652
# Value of c_logl = 1363.904507,  2-norm of c_score = 11.953286
# Value of c_logl = 1363.904505,  2-norm of c_score = 8.914914
# Value of c_logl = 1363.904504,  2-norm of c_score = 6.670565
# Value of c_logl = 1363.861531,  2-norm of c_score = 21.751512
# Value of c_logl = 1363.861525,  2-norm of c_score = 16.179237
# Value of c_logl = 1363.861522,  2-norm of c_score = 12.051814
# Value of c_logl = 1363.861520,  2-norm of c_score = 8.997844
# Value of c_logl = 1363.861519,  2-norm of c_score = 6.743001
# Value of c_logl = 1363.861481,  2-norm of c_score = 14.265329
# Value of c_logl = 1363.861478,  2-norm of c_score = 10.612890
# Value of c_logl = 1363.861477,  2-norm of c_score = 7.908984
# Value of c_logl = 1363.861476,  2-norm of c_score = 5.910505
# Value of c_logl = 1363.861476,  2-norm of c_score = 4.438467
# Value of c_logl = 1363.791699,  2-norm of c_score = 38.857226
# Value of c_logl = 1363.791680,  2-norm of c_score = 28.861257
# Value of c_logl = 1363.791670,  2-norm of c_score = 21.451413
# Value of c_logl = 1363.791664,  2-norm of c_score = 15.960182
# Value of c_logl = 1363.791661,  2-norm of c_score = 11.892966
# Value of c_logl = 1363.791659,  2-norm of c_score = 8.883608
# Value of c_logl = 1363.791658,  2-norm of c_score = 6.661637
# Value of c_logl = 1363.791658,  2-norm of c_score = 5.028561
# Value of c_logl = 1363.791635,  2-norm of c_score = 10.224253
# Value of c_logl = 1363.791633,  2-norm of c_score = 7.629835
# Value of c_logl = 1363.791633,  2-norm of c_score = 5.712941
# Value of c_logl = 1363.791632,  2-norm of c_score = 4.301937
# Value of c_logl = 1363.791616,  2-norm of c_score = 8.731580
# Value of c_logl = 1363.791615,  2-norm of c_score = 6.510177
# Value of c_logl = 1363.791614,  2-norm of c_score = 4.868133
# Value of c_logl = 1363.791614,  2-norm of c_score = 3.658227
# Value of c_logl = 1363.791602,  2-norm of c_score = 7.172473
# Value of c_logl = 1363.791601,  2-norm of c_score = 5.345456
# Value of c_logl = 1363.791601,  2-norm of c_score = 3.995110
# Value of c_logl = 1363.791600,  2-norm of c_score = 3.000420
# Value of c_logl = 1363.760460,  2-norm of c_score = 16.197816
# Value of c_logl = 1363.760457,  2-norm of c_score = 12.033540
# Value of c_logl = 1363.760455,  2-norm of c_score = 8.947182
# Value of c_logl = 1363.760454,  2-norm of c_score = 6.660652
# Value of c_logl = 1363.760454,  2-norm of c_score = 4.967987
# Value of c_logl = 1363.760453,  2-norm of c_score = 3.716860
# Value of c_logl = 1363.760453,  2-norm of c_score = 2.795068
# Value of c_logl = 1363.760446,  2-norm of c_score = 5.832409
# Value of c_logl = 1363.760446,  2-norm of c_score = 4.344984
# Value of c_logl = 1363.760446,  2-norm of c_score = 3.244794
# Value of c_logl = 1363.760446,  2-norm of c_score = 2.432998
# Value of c_logl = 1363.760440,  2-norm of c_score = 4.967961
# Value of c_logl = 1363.760440,  2-norm of c_score = 3.697643
# Value of c_logl = 1363.760440,  2-norm of c_score = 2.757800
# Value of c_logl = 1363.760440,  2-norm of c_score = 2.063952
# Value of c_logl = 1363.756258,  2-norm of c_score = 11.332731
# Value of c_logl = 1363.756257,  2-norm of c_score = 8.421759
# Value of c_logl = 1363.756256,  2-norm of c_score = 6.264670
# Value of c_logl = 1363.756255,  2-norm of c_score = 4.667115
# Value of c_logl = 1363.756255,  2-norm of c_score = 3.485233
# Value of c_logl = 1363.756255,  2-norm of c_score = 2.612783
# Value of c_logl = 1363.756249,  2-norm of c_score = 5.729226
# Value of c_logl = 1363.756249,  2-norm of c_score = 4.261418
# Value of c_logl = 1363.756249,  2-norm of c_score = 3.174640
# Value of c_logl = 1363.756248,  2-norm of c_score = 2.371062
# Value of c_logl = 1363.756248,  2-norm of c_score = 1.778545
# Value of c_logl = 1363.753090,  2-norm of c_score = 4.434234
# Value of c_logl = 1363.753090,  2-norm of c_score = 3.303236
# Value of c_logl = 1363.753090,  2-norm of c_score = 2.466702
# Value of c_logl = 1363.753090,  2-norm of c_score = 1.849469
# Value of c_logl = 1363.753087,  2-norm of c_score = 3.746551
# Value of c_logl = 1363.753087,  2-norm of c_score = 2.788647
# Value of c_logl = 1363.753087,  2-norm of c_score = 2.080012
# Value of c_logl = 1363.753087,  2-norm of c_score = 1.556955
# Value of c_logl = 1363.750688,  2-norm of c_score = 5.235355
# Value of c_logl = 1363.750688,  2-norm of c_score = 3.893802
# Value of c_logl = 1363.750688,  2-norm of c_score = 2.900333
# Value of c_logl = 1363.750687,  2-norm of c_score = 2.165485
# Value of c_logl = 1363.750687,  2-norm of c_score = 1.623222
# Value of c_logl = 1363.750685,  2-norm of c_score = 3.276864
# Value of c_logl = 1363.750685,  2-norm of c_score = 2.438866
# Value of c_logl = 1363.750685,  2-norm of c_score = 1.818933
# Value of c_logl = 1363.750685,  2-norm of c_score = 1.361340
# Value of c_logl = 1363.748848,  2-norm of c_score = 3.945177
# Value of c_logl = 1363.748848,  2-norm of c_score = 2.935217
# Value of c_logl = 1363.748848,  2-norm of c_score = 2.187555
# Value of c_logl = 1363.748848,  2-norm of c_score = 1.634894
# Value of c_logl = 1363.748848,  2-norm of c_score = 1.227653
# Value of c_logl = 1363.747333,  2-norm of c_score = 3.153742
# Value of c_logl = 1363.747333,  2-norm of c_score = 2.349834
# Value of c_logl = 1363.747333,  2-norm of c_score = 1.755302
# Value of c_logl = 1363.747333,  2-norm of c_score = 1.316733
# Value of c_logl = 1363.747331,  2-norm of c_score = 2.697932
# Value of c_logl = 1363.747331,  2-norm of c_score = 2.008306
# Value of c_logl = 1363.747331,  2-norm of c_score = 1.498129
# Value of c_logl = 1363.747331,  2-norm of c_score = 1.121536
# Value of c_logl = 1363.746095,  2-norm of c_score = 3.568082
# Value of c_logl = 1363.746095,  2-norm of c_score = 2.654198
# Value of c_logl = 1363.746095,  2-norm of c_score = 1.977504
# Value of c_logl = 1363.746095,  2-norm of c_score = 1.477062
# Value of c_logl = 1363.746095,  2-norm of c_score = 1.107916
# Value of c_logl = 1363.746094,  2-norm of c_score = 2.235826
# Value of c_logl = 1363.746094,  2-norm of c_score = 1.664489
# Value of c_logl = 1363.746094,  2-norm of c_score = 1.241895
# Value of c_logl = 1363.746094,  2-norm of c_score = 0.930068
# Value of c_logl = 1363.745234,  2-norm of c_score = 2.757989
# Value of c_logl = 1363.745234,  2-norm of c_score = 2.052181
# Value of c_logl = 1363.745234,  2-norm of c_score = 1.529706
# Value of c_logl = 1363.745234,  2-norm of c_score = 1.143535
# Value of c_logl = 1363.745234,  2-norm of c_score = 0.859027
# Value of c_logl = 1363.744494,  2-norm of c_score = 2.216351
# Value of c_logl = 1363.744494,  2-norm of c_score = 1.651514
# Value of c_logl = 1363.744494,  2-norm of c_score = 1.233797
# Value of c_logl = 1363.744494,  2-norm of c_score = 0.925670
# Value of c_logl = 1363.744493,  2-norm of c_score = 1.921038
# Value of c_logl = 1363.744493,  2-norm of c_score = 1.429908
# Value of c_logl = 1363.744493,  2-norm of c_score = 1.066535
# Value of c_logl = 1363.744493,  2-norm of c_score = 0.798243
# Value of c_logl = 1363.743873,  2-norm of c_score = 2.679782
# Value of c_logl = 1363.743873,  2-norm of c_score = 1.993026
# Value of c_logl = 1363.743873,  2-norm of c_score = 1.484426
# Value of c_logl = 1363.743873,  2-norm of c_score = 1.108167
# Value of c_logl = 1363.743873,  2-norm of c_score = 0.830420
# Value of c_logl = 1363.743873,  2-norm of c_score = 1.760444
# Value of c_logl = 1363.743873,  2-norm of c_score = 1.309537
# Value of c_logl = 1363.743873,  2-norm of c_score = 0.975782
# Value of c_logl = 1363.743873,  2-norm of c_score = 0.729141
# Value of c_logl = 1363.743873,  2-norm of c_score = 0.547500
# Value of c_logl = 1363.742814,  2-norm of c_score = 4.714349
# Value of c_logl = 1363.742813,  2-norm of c_score = 3.501178
# Value of c_logl = 1363.742813,  2-norm of c_score = 2.601954
# Value of c_logl = 1363.742813,  2-norm of c_score = 1.935619
# Value of c_logl = 1363.742813,  2-norm of c_score = 1.442118
# Value of c_logl = 1363.742813,  2-norm of c_score = 1.076994
# Value of c_logl = 1363.742813,  2-norm of c_score = 0.807406
# Value of c_logl = 1363.742813,  2-norm of c_score = 0.609247
# Value of c_logl = 1363.742813,  2-norm of c_score = 1.242190
# Value of c_logl = 1363.742813,  2-norm of c_score = 0.926768
# Value of c_logl = 1363.742813,  2-norm of c_score = 0.693717
# Value of c_logl = 1363.742813,  2-norm of c_score = 0.522147
# Value of c_logl = 1363.742812,  2-norm of c_score = 1.063363
# Value of c_logl = 1363.742812,  2-norm of c_score = 0.792622
# Value of c_logl = 1363.742812,  2-norm of c_score = 0.592487
# Value of c_logl = 1363.742812,  2-norm of c_score = 0.444997
# Value of c_logl = 1363.742812,  2-norm of c_score = 0.874430
# Value of c_logl = 1363.742812,  2-norm of c_score = 0.651495
# Value of c_logl = 1363.742812,  2-norm of c_score = 0.486717
# Value of c_logl = 1363.742812,  2-norm of c_score = 0.365314
# Value of c_logl = 1363.742352,  2-norm of c_score = 2.410812
# Value of c_logl = 1363.742352,  2-norm of c_score = 1.790572
# Value of c_logl = 1363.742352,  2-norm of c_score = 1.330862
# Value of c_logl = 1363.742352,  2-norm of c_score = 0.990243
# Value of c_logl = 1363.742352,  2-norm of c_score = 0.738018
# Value of c_logl = 1363.742352,  2-norm of c_score = 0.551467
# Value of c_logl = 1363.742352,  2-norm of c_score = 0.413823
# Value of c_logl = 1363.742352,  2-norm of c_score = 0.924678
# Value of c_logl = 1363.742352,  2-norm of c_score = 0.687891
# Value of c_logl = 1363.742352,  2-norm of c_score = 0.512571
# Value of c_logl = 1363.742352,  2-norm of c_score = 0.382931
# Value of c_logl = 1363.742352,  2-norm of c_score = 0.287323
# Value of c_logl = 1363.742352,  2-norm of c_score = 0.580164
# Value of c_logl = 1363.742352,  2-norm of c_score = 0.431960
# Value of c_logl = 1363.742352,  2-norm of c_score = 0.322350
# Value of c_logl = 1363.742352,  2-norm of c_score = 0.241484
# Value of c_logl = 1363.742294,  2-norm of c_score = 0.916581
# Value of c_logl = 1363.742294,  2-norm of c_score = 0.681615
# Value of c_logl = 1363.742294,  2-norm of c_score = 0.507598
# Value of c_logl = 1363.742294,  2-norm of c_score = 0.378853
# Value of c_logl = 1363.742294,  2-norm of c_score = 0.283801
# Value of c_logl = 1363.742294,  2-norm of c_score = 0.601878
# Value of c_logl = 1363.742294,  2-norm of c_score = 0.447655
# Value of c_logl = 1363.742294,  2-norm of c_score = 0.333496
# Value of c_logl = 1363.742294,  2-norm of c_score = 0.249126
# Value of c_logl = 1363.742294,  2-norm of c_score = 0.186976
# Value of c_logl = 1363.742170,  2-norm of c_score = 1.799884
# Value of c_logl = 1363.742170,  2-norm of c_score = 1.336610
# Value of c_logl = 1363.742170,  2-norm of c_score = 0.993215
# Value of c_logl = 1363.742170,  2-norm of c_score = 0.738744
# Value of c_logl = 1363.742170,  2-norm of c_score = 0.550261
# Value of c_logl = 1363.742170,  2-norm of c_score = 0.410781
# Value of c_logl = 1363.742170,  2-norm of c_score = 0.307756
# Value of c_logl = 1363.742170,  2-norm of c_score = 0.231957
# Value of c_logl = 1363.742170,  2-norm of c_score = 0.485113
# Value of c_logl = 1363.742170,  2-norm of c_score = 0.361668
# Value of c_logl = 1363.742170,  2-norm of c_score = 0.270398
# Value of c_logl = 1363.742170,  2-norm of c_score = 0.203108
# Value of c_logl = 1363.742170,  2-norm of c_score = 0.434047
# Value of c_logl = 1363.742170,  2-norm of c_score = 0.323130
# Value of c_logl = 1363.742170,  2-norm of c_score = 0.241054
# Value of c_logl = 1363.742170,  2-norm of c_score = 0.180435
# Value of c_logl = 1363.742170,  2-norm of c_score = 0.135847
# Value of c_logl = 1363.742151,  2-norm of c_score = 0.132711
# Value of c_logl = 1363.742118,  2-norm of c_score = 0.690470
# Value of c_logl = 1363.742118,  2-norm of c_score = 0.513135
# Value of c_logl = 1363.742118,  2-norm of c_score = 0.381733
# Value of c_logl = 1363.742118,  2-norm of c_score = 0.284419
# Value of c_logl = 1363.742118,  2-norm of c_score = 0.212427
# Value of c_logl = 1363.742118,  2-norm of c_score = 0.159283
# Value of c_logl = 1363.742118,  2-norm of c_score = 0.120236
# Value of c_logl = 1363.742118,  2-norm of c_score = 0.240776
# Value of c_logl = 1363.742118,  2-norm of c_score = 0.179704
# Value of c_logl = 1363.742118,  2-norm of c_score = 0.134602
# Value of c_logl = 1363.742118,  2-norm of c_score = 0.301438
# Value of c_logl = 1363.742118,  2-norm of c_score = 0.224100
# Value of c_logl = 1363.742118,  2-norm of c_score = 0.166827
# Value of c_logl = 1363.742118,  2-norm of c_score = 0.124458
# Value of c_logl = 1363.742118,  2-norm of c_score = 0.093185
# Value of c_logl = 1363.742110,  2-norm of c_score = 0.298262
# Value of c_logl = 1363.742110,  2-norm of c_score = 0.221864
# Value of c_logl = 1363.742110,  2-norm of c_score = 0.165294
# Value of c_logl = 1363.742110,  2-norm of c_score = 0.123458
# Value of c_logl = 1363.742110,  2-norm of c_score = 0.092596
# Value of c_logl = 1363.742102,  2-norm of c_score = 0.309660
# Value of c_logl = 1363.742102,  2-norm of c_score = 0.230402
# Value of c_logl = 1363.742102,  2-norm of c_score = 0.171715
# Value of c_logl = 1363.742102,  2-norm of c_score = 0.128312
# Value of c_logl = 1363.742102,  2-norm of c_score = 0.096294
# Value of c_logl = 1363.742102,  2-norm of c_score = 0.210082
# Value of c_logl = 1363.742102,  2-norm of c_score = 0.156319
# Value of c_logl = 1363.742102,  2-norm of c_score = 0.116522
# Value of c_logl = 1363.742102,  2-norm of c_score = 0.087109
# Value of c_logl = 1363.742095,  2-norm of c_score = 0.321830
# Value of c_logl = 1363.742095,  2-norm of c_score = 0.239225
# Value of c_logl = 1363.742095,  2-norm of c_score = 0.178025
# Value of c_logl = 1363.742095,  2-norm of c_score = 0.132713
# Value of c_logl = 1363.742095,  2-norm of c_score = 0.099208
# Value of c_logl = 1363.742095,  2-norm of c_score = 0.133447
# Value of c_logl = 1363.742095,  2-norm of c_score = 0.099615
# Value of c_logl = 1363.742095,  2-norm of c_score = 0.074633
# Value of c_logl = 1363.742095,  2-norm of c_score = 0.165671
# Value of c_logl = 1363.742095,  2-norm of c_score = 0.123185
# Value of c_logl = 1363.742095,  2-norm of c_score = 0.091725
# Value of c_logl = 1363.742095,  2-norm of c_score = 0.068457
# Value of c_logl = 1363.742090,  2-norm of c_score = 0.327207
# Value of c_logl = 1363.742090,  2-norm of c_score = 0.243083
# Value of c_logl = 1363.742090,  2-norm of c_score = 0.180739
# Value of c_logl = 1363.742090,  2-norm of c_score = 0.134555
# Value of c_logl = 1363.742090,  2-norm of c_score = 0.100370
# Value of c_logl = 1363.742090,  2-norm of c_score = 0.075106
# Value of c_logl = 1363.742090,  2-norm of c_score = 0.099573
# Value of c_logl = 1363.742090,  2-norm of c_score = 0.074414
# Value of c_logl = 1363.742090,  2-norm of c_score = 0.099822
# Value of c_logl = 1363.742090,  2-norm of c_score = 0.074499
# Value of c_logl = 1363.742090,  2-norm of c_score = 0.101087
# Value of c_logl = 1363.742090,  2-norm of c_score = 0.075341
# Value of c_logl = 1363.742089,  2-norm of c_score = 0.087587
# Value of c_logl = 1363.742089,  2-norm of c_score = 0.065306
# Value of c_logl = 1363.742086,  2-norm of c_score = 0.313947
# Value of c_logl = 1363.742086,  2-norm of c_score = 0.233164
# Value of c_logl = 1363.742086,  2-norm of c_score = 0.173287
# Value of c_logl = 1363.742086,  2-norm of c_score = 0.128917
# Value of c_logl = 1363.742086,  2-norm of c_score = 0.096056
# Value of c_logl = 1363.742086,  2-norm of c_score = 0.071742
# Value of c_logl = 1363.742086,  2-norm of c_score = 0.101808
# Value of c_logl = 1363.742086,  2-norm of c_score = 0.075881
# Value of c_logl = 1363.742086,  2-norm of c_score = 0.056705
# Value of c_logl = 1363.742086,  2-norm of c_score = 0.078688
# Value of c_logl = 1363.742086,  2-norm of c_score = 0.058692
# Value of c_logl = 1363.742086,  2-norm of c_score = 0.084340
# Value of c_logl = 1363.742086,  2-norm of c_score = 0.062786
# Value of c_logl = 1363.742086,  2-norm of c_score = 0.046834
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.066468
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.049530
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.072264
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.053749
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.040039
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.116269
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.086418
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.064299
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.047921
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.070699
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.052585
# Value of c_logl = 1363.742085,  2-norm of c_score = 0.039170
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.071692
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.053323
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.039719
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.059533
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.044256
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.032939
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.098494
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.073180
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.054421
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.040525
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.062613
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.046524
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.034603
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.057613
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.042810
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.031842
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.035715
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.026572
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.141617
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.105164
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.078143
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.058118
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.043284
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.032305
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.047413
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.035304
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.039488
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.029420
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.045439
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.033774
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.025132
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.028105
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.033753
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.025086
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.058453
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.043420
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.032279
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.024024
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.026963
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.032513
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.024167
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.027386
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.020357
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.039844
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.029604
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.022015
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.024935
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.018545
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.032035
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.023812
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.017720
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.019901
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.023941
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.017793
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.026112
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.019403
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.014431
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.016367
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.019807
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.014711
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.016477
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.012239
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.009736
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.000147
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.001742
# Value of c_logl = 1363.742084,  2-norm of c_score = 0.001294
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1363.742084
#          Iterations: 652
#          Function evaluations: 1181
#          Gradient evaluations: 1832
#          Hessian evaluations: 653
#
# -------------------------------------------------------------------------------------------
# - BIAS CORRECTED JOINT FIXED EFFECTS LOGIT ESTIMATION RESULTS                             -
# -------------------------------------------------------------------------------------------
#
# Number of agents,           N :             115
# Number of dyads,            n :           6,555
#
# -------------------------------------------------------------------------------------------
#
# Independent variable       Coef.    ( Std. Err.)     (0.95 Confid. Interval )
# -------------------------------------------------------------------------------------------
# Distance                  -0.002001 (  0.000184)     ( -0.002361 , -0.001640)
# Other blood relation       1.362710 (  0.189174)     (  0.991936 ,  1.733485)
# Cousin, etc.               1.856894 (  0.244763)     (  1.377168 ,  2.336620)
# Sibling, child, etc.       2.875527 (  0.273332)     (  2.339806 ,  3.411247)
# Age difference            -0.004631 (  0.003642)     ( -0.011770 ,  0.002508)
# Same religion              0.466867 (  0.083760)     (  0.302700 ,  0.631033)
# Same clan                  0.294968 (  0.138685)     (  0.023151 ,  0.566784)
# Same education level       0.417187 (  0.117280)     (  0.187322 ,  0.647052)
# Adjacent wealth class      0.038704 (  0.100513)     ( -0.158297 ,  0.235705)
# Non-adjacent wealth class -0.030166 (  0.113675)     ( -0.252964 ,  0.192632)
#
# -------------------------------------------------------------------------------------------

# %% [markdown]
# It takes some time for *dyad\_jfe\_logit()* to converge. This reflects the sparsity of the Nyakatoke network and the consequent difficulty of estimating the household degree heterogeneity effects.
# <br>
# <br>
# Relative to the *tetrad\_logit()* results, the joint estimator suggests sorting by religion and clan. In Monte Carlo experiments I have found that the joint estimator -- particularly the bias correction step -- can work very poorly in networks like the Nyakatoke one (i.e., in networks that are sparse such that many agents have only a few links). In such settings the $A_{i}$ for $i=1,...,N$ may be _very_ imprecisely estimated and this can effect the quality of the common parameter estimates as well.
# <br>
# <br>
# For reference we can look at the joint coefficient estimates prior to bias correction using the *print\_coef()* utility included in the **netrics** package. These point estimates are closer to the *tetrad\_logit()* ones than their bias-corrected counterparts. This suggests, that in this particular example, bias-correction may be doing more harm that good.
# <br>
# <br>
# Monte Carlo evidence suggests that in denser networks, the size distortion causes by bias in the limit distribution of the joint fixed effects estimator is very real and, furthermore, that bias correction can be effective in such contexts. So not too much should be made of this example.

# %%
netrics.print_coef(beta_JFE, vcov_beta_JFE, var_names=cov_names)
# Out:
# Independent variable       Coef.    ( Std. Err.)     (0.95 Confid. Interval )
# -------------------------------------------------------------------------------------------
# Distance                  -0.002531 (  0.000184)     ( -0.002891 , -0.002170)
# Other blood relation       1.305248 (  0.189174)     (  0.934474 ,  1.676022)
# Cousin, etc.               1.924261 (  0.244763)     (  1.444534 ,  2.403987)
# Sibling, child, etc.       2.880070 (  0.273332)     (  2.344350 ,  3.415791)
# Age difference            -0.013243 (  0.003642)     ( -0.020382 , -0.006103)
# Same religion              0.375953 (  0.083760)     (  0.211786 ,  0.540119)
# Same clan                  0.259152 (  0.138685)     ( -0.012665 ,  0.530969)
# Same education level       0.073594 (  0.117280)     ( -0.156270 ,  0.303459)
# Adjacent wealth class     -0.175216 (  0.100513)     ( -0.372218 ,  0.021785)
# Non-adjacent wealth class -0.282325 (  0.113675)     ( -0.505123 , -0.059527)
#
# -------------------------------------------------------------------------------------------

# %%
# This imports an attractive notebook style from Github
from IPython.display import HTML
from urllib.request import urlopen
html = urlopen('http://bit.ly/1Bf5Hft')
HTML(html.read().decode('utf-8'))
# Out:
# <style>
#
# html {
#   font-size: 62.5% !important; }
# body {
#   font-size: 1.5em !important; /* currently ems cause chrome bug misinterpreting rems on body element */
#   line-height: 1.6 !important;
#   font-weight: 400 !important;
#   font-family: "Raleway", "HelveticaNeue", "Helvetica Neue", Helvetica, Arial, sans-serif !important;
#   color: #222 !important; }
#
# div{ border-radius: 0px !important;  }
# div.CodeMirror-sizer{ background: rgb(244, 244, 248) !important; }
# div.input_area{ background: rgb(244, 244, 248) !important; }
#
# div.out_prompt_overlay:hover{ background: rgb(244, 244, 248) !important; }
# div.input_prompt:hover{ background: rgb(244, 244, 248) !important; }
#
# h1, h2, h3, h4, h5, h6 {
#   color: #333 !important;
#   margin-top: 0 !important;
#   margin-bottom: 2rem !important;
#   font-weight: 300 !important; }
# h1 { font-size: 4.0rem !important; line-height: 1.2 !important;  letter-spacing: -.1rem !important;}
# h2 { font-size: 3.6rem !important; line-height: 1.25 !important; letter-spacing: -.1rem !important; }
# h3 { font-size: 3.0rem !important; line-height: 1.3 !important;  letter-spacing: -.1rem !important; }
# h4 { font-size: 2.4rem !important; line-height: 1.35 !important; letter-spacing: -.08rem !important; }
# h5 { font-size: 1.8rem !important; line-height: 1.5 !important;  letter-spacing: -.05rem !important; }
# h6 { font-size: 1.5rem !important; line-height: 1.6 !important;  letter-spacing: 0 !important; }
#
# @media (min-width: 550px) {
#   h1 { font-size: 5.0rem !important; }
#   h2 { font-size: 4.2rem !important; }
#   h3 { font-size: 3.6rem !important; }
#   h4 { font-size: 3.0rem !important; }
#   h5 { font-size: 2.4rem !important; }
#   h6 { font-size: 1.5rem !important; }
# }
#
# p {
#   margin-top: 0 !important; }
#
# a {
#   color: #1EAEDB !important; }
# a:hover {
#   color: #0FA0CE !important; }
#
# code {
#   padding: .2rem .5rem !important;
#   margin: 0 .2rem !important;
#   font-size: 90% !important;
#   white-space: nowrap !important;
#   background: #F1F1F1 !important;
#   border: 1px solid #E1E1E1 !important;
#   border-radius: 4px !important; }
# pre > code {
#   display: block !important;
#   padding: 1rem 1.5rem !important;
#   white-space: pre !important; }
#
# button{ border-radius: 0px !important; }
# .navbar-inner{ background-image: none !important;  }
# select, textarea{ border-radius: 0px !important; }
#
# </style>
