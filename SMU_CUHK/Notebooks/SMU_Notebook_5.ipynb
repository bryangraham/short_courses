# %% [markdown]
# # Notebook 5: Estimating models of exogenous network formation
# #### Econometric Methods for Networks
# #### _Singapore Management University (SMU) May 29th to June 1st, 2017_
# ##### _Bryan S. Graham, UC - Berkeley, bgraham@econ.berkeley.edu_
# <br>
# <br>
# This is the fifth in a series of iPython Jupyter notebooks designed to accompany a series of instructional lectures given at the Singapore Management University (SMU) from May 29th to June 1st, 2017. The scripts below were written for Python 2.7.12. The Anaconda distribution of Python, available at https://www.continuum.io/downloads, comes bundled with most the scientific computing packages used in these notebooks.
# <br>
# <br>
# For more information about the course please visit my webpage at http://bryangraham.github.io/econometrics/. This notebook also provides a basic illustration of the recently introduced _netrics_ Python package for the econometric analysis of network data.
# <br>
# <br>
# I begin by importing several key packages. The _numpy_ and _scipy_ libraries include a core set of scientific computing tools. The _pandas_ package is useful for data organization and analysis, while _matplotlib_ is Python's basic plotting add-on. Finally the _networkx_ package includes functionality for the analysis, and also visualizing, network data.

# %%
# Direct Python to plot all figures inline (i.e., not in a separate window)
# %matplotlib inline

# Main scientific computing modules
import numpy as np
import scipy as sp
import pandas as pd

# Import matplotlib
import matplotlib.pyplot as plt

# networkx module for the analysis of network data
import networkx as nx

# Division of two integers in Python 2.7 does not return a floating point result. The default is to round down 
# to the nearest integer. The following piece of code changes the default.
from __future__ import division

# %% [markdown]
# Load **netrics** package. This package is registered on [PyPi](https://pypi.python.org/pypi/netrics/), with a GitHub repository at https://github.com/bryangraham/netrics. For an informal introduction to the package see [this](http://bryangraham.github.io/econometrics/networks/2016/09/15/netrics-module.html) blog post. The blog post also includes links to additional resources.

# %%
# Append location of netrics module base directory to system path
# NOTE: only required if permanent install not made (see discussion in blog post referenced above)
import sys
sys.path.append('/Users/bgraham/Dropbox/Sites/software/netrics/')

# Load netrics module
import netrics as netrics
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-2d85ad0d4152> in <module>()
#       5
#       6 # Load netrics module
# ----> 7 import netrics as netrics
#
# /Users/bgraham/Dropbox/Sites/software/netrics/netrics/__init__.py in <module>()
#       9 # Import the different functions into the package
#      10 #from print_coef import print_coef
# ---> 11 from helpers import generate_dyad_to_tetrads_dict, generate_tetrad_indices, \
#      12                     organize_data_tetrad_logit, tetrad_logit_score_proj, \
#      13                     dyad_jfe_select_matrix
#
# ModuleNotFoundError: No module named 'helpers'

# %% [markdown]
# The following code snippet should be edited to point to wherever you have saved the instructional datasets for the course

# %%
# Directory where datasets of located
data =  '/Users/bgraham/Dropbox/Teaching/Short_Courses/St_Gallen/Data/'

# %% [markdown]
# A basic dyadic dataset for Nyakatoke was constructed in the Lecture 1 notebook. I begin by loading this dataset into a pandas dataframe.

# %%
# Read in estimation sample created in the notebook for Lecture 1
es = pd.read_csv(data+"Created/Nyakatoke_Estimation_Sample.csv")
es = es.set_index(['hh1', 'hh2'], drop = False)           # Set dataframe multi-index
del es['Unnamed: 0']                                      # Delete first column which is an unneeded single index

# Print out the first few rows of the dyadic data
es.head()
# Out:
#          hh1  hh2            links               kinship    distance  clan1  \
# hh1 hh2
# 1   2      1    2          no link  other blood relation   91.199997   21.0
#     3      1    3          no link     no blood relation   69.599998   21.0
#     4      1    4  unilateral link     no blood relation  199.199997   21.0
#     5      1    5          no link     no blood relation  252.000000   21.0
#     6      1    6          no link     no blood relation  213.600006   21.0
#
#          clan2    wealth1   wealth2 religion1 religion2       education1  \
# hh1 hh2
# 1   2      6.0  17.657388  6.639588  Catholic  Catholic  started primary
#     3     21.0  17.657388  1.538235  Catholic  Catholic  started primary
#     4     23.0  17.657388  2.743059  Catholic  Catholic  started primary
#     5     23.0  17.657388  1.976098  Catholic  Catholic  started primary
#     6     23.0  17.657388  1.394941  Catholic  Catholic  started primary
#
#                education2  head_age1  head_age2 head_sex1 head_sex2
# hh1 hh2
# 1   2    finished primary       75.0       30.0      male      male
#     3           secondary       75.0       48.0      male    female
#     4    finished primary       75.0       80.0      male      male
#     5    finished primary       75.0       35.0      male      male
#     6    finished primary       75.0       28.0      male      male

# %% [markdown]
# Below we fit a dyadic link formation model using the two estimators introduced by Graham (2014, _NBER_). The link formation model studied in that paper is
#
#
# <div> $$\Pr\left(\left.D_{ij}=1\right|\mathbf{X},\mathbf{A}\right) = \frac{\exp\left(\sum_{k=1}^{K}W_{k,ij}\beta_{k}+A_{i}+A_{j}\right)}   {1+\exp\left(\sum_{k=1}^{K}W_{k,ij}\beta_{k}+A_{i}+A_{j}\right)}$$ </div>
#
# Here $\mathbf{X}$ denotes all the household-specific observed covariates in the network, $W_{k,ij} = W_{k,ji}$ are dyad-specific covariates constructed from $\mathbf{X}$, and the $A_i$ for $i=1,...,N$ are _degree heterogeneity_ parameters which are household specific. These are treated as co-called "fixed effects".
# <br>
# <br>
# Graham (2014) introduces a "tetrad logit" procedure which forms a criterion function, based on conditioning arguments, which is invariant to the fixed effects and also a "joint fixed effects" procedure which estimates the individual effects along with the common parameters.
# <br>
# <br>
# In the _netrics_ package these two procedures are operationalized by the *tetrad\_logit()* and *dyad\_jfe\_logit()* functions. These two functions require the user to input data in a very particular way. The outcome is $D$, the $N \times N$ adjacency matrix. The regressors are included in a length $K$ list where each element is an $N \times N $ numpy 2d array $W_{k}$ with $(i,j)$ element equal to the dyadic covariate $W_{k,ij}$. It takes a bit of work to get our Nyakatoke dataset into this form. This is what the next few snippets of code do.

# %%
hh_set = set(es['hh1'].unique()) | set(es['hh2'].unique()) # Set of all households
N = len(hh_set)                                            # Number of households
n = N * (N - 1) //2                                        # Number of dyads

# %%
# Get multi-indices for lower triangle of N x N matrix
ij_LowTri = np.tril_indices(N, -1)

# %%
# Form adjacency matrix as a dense 2d numpy array
D = np.zeros((N,N), dtype = np.bool)
D[ij_LowTri] = (es['links'] != 'no link')
D = (D + D.T)*1

# %%
# Form four categorical bins for wealth (same as used in plot of Network from Lecture 1)
wealth_bkts = [1000000, 6, 3, 1.5, 0]
wealth_bin_labels = ['+600K','(600K,300K]','(300K,150K]','(150K, 0K]']
es['wealth_cat1'] = np.digitize(es.wealth1, wealth_bkts)
es['wealth_cat2'] = np.digitize(es.wealth2, wealth_bkts)

# %% [markdown]
# Construct $K$ list of $N \times N$ dyad-specific covariate matrices.

# %%
cov_names = ['Distance','Other blood relation', 'Cousin, etc.', 'Sibling, child, etc.', 'Age difference', \
             'Same religion', 'Same clan', 'Same education level', 'Adjacent wealth class', \
             'Non-adjacent wealth class']

# Initialize K-list of dyadic covariate matrices
W = [np.zeros((N,N), dtype = np.float)]*len(cov_names)

# Distance between households
W[0][ij_LowTri] = es['distance']
W[0] = W[0] + W[0].T

# Whether two households are other blood related
W[1][ij_LowTri] = (es['kinship']=='other blood relation')*1
W[1] = W[1] + W[1].T

# Whether two households have a nephew etc. level blood relation
W[2][ij_LowTri] = (es['kinship']=='Nephew/niece/uncle/aunt,cousin,grandparent/grandchild')*1
W[2] = W[2] + W[2].T    

# Whether two households have a child etc. level blood relation
W[3][ij_LowTri] = (es['kinship']=='sibling, child, parent')*1
W[3] = W[3] + W[3].T  

# Absolute difference in age between two household heads
W[4][ij_LowTri] = np.abs(es['head_age1']-es['head_age2'])
W[4] = W[4] + W[4].T

# Whether two households are of the same religion
W[5][ij_LowTri] = (es['religion1'] == es['religion2'])*1
W[5] = W[5] + W[5].T

# Whether two households belong to the same clan
W[6][ij_LowTri] = (es['clan1'] == es['clan2'])*1
W[6] = W[6] + W[6].T

# Whether two households are of the same education level
W[7][ij_LowTri] = (es['education1'] == es['education2'])*1
W[7] = W[7] + W[7].T

# Whether two households are of in adjacent wealth class
W[8][ij_LowTri] = (np.abs(es['wealth_cat1'] - es['wealth_cat2']) == 1)*1
W[8] = W[8] + W[8].T

# Whether two households are of in distance wealth classes
W[9][ij_LowTri] = (np.abs(es['wealth_cat1'] - es['wealth_cat2']) > 1)*1
W[9] = W[9] + W[9].T

# %% [markdown]
# Save the adjacency matrix and the covariate matrices to an uncompressed file (this serves as a test dataset for the *tetrad\_logit()* and *dyad\_jfe\_logit()* functions). This file can be download from GitHub at https://github.com/bryangraham/netrics/blob/master/Notebooks/Nyakatoke_Example.npz.

# %%
np.savez(data+"Created/Nyakatoke_Example", D = D, Distance = W[0], OtherBlood = W[1], Cousin = W[2], \
                                           Sibling = W[3], AgeDiff = W[4], SameReligion = W[5], \
                                           SameClan = W[6], SameEdLvl = W[7], AdjacentWealthClass = W[8], \
                                           NonAdjacentWealthClass = W[9])

# %% [markdown]
# ## Tetrad Logit
# With $W$ appropriately constructed we can now fit a link formation model using *tetrad\_logit()*. We can get a sense of how the function works by viewing its help header.

# %%
help(netrics.tetrad_logit)
# Out:
# Help on function tetrad_logit in module netrics.tetrad_logit:
#
# tetrad_logit(D, W, dtcon=None, silent=False, W_names=None)
#     AUTHOR: Bryan S. Graham, bgraham@econ.berkeley.edu, June 2016
#
#     This function computes the Tetrad Logit estimator introduced in Graham (2014, NBER No. 20341) -- "An Econometric
#     Model of Link Formation with Degree Heterogeneity". The implementation is as described in the paper. Notation
#     attempts to follow that used in the paper.
#
#     INPUTS
#     ------
#     D                 : N x N undirected adjacency matrix
#     W                 : List with elements consisting of N x N 2d numpy arrays of dyad-specific
#                         covariates such that W[k][i,j] gives the k-th covariate for dyad ij
#     dtcon             : Dyad and tetrad concordance (dtcon) List with elements [tetrad_to_dyads_indices,
#                         dyad_to_tetrads_dict]. If dtcon=None, then construct it using generate_tetrad_indices()
#                         function. See header to generate_tetrad_indices() for more information.
#     silent            : If True then suppress all optimization and estimation output, show output otherwise.
#     W_names           : List of K strings giving names of the columns of W_tilde. If silent=False then use
#                         these in presentation of estimation output.
#
#     OUTPUTS
#     -------
#     beta_TL          :  K x 1 vector of tetrad logit point estimates of beta
#     vcov_beta_TL     :  K x K asymptotic-variance matrix for beta_TL
#                         NOTE: vcov_beta_TL is already "divided by n" (just take square root of diagonal for std. errs.)
#     tetrad_frac_TL   :  Fraction of tetrads that contribute to Tetrad Logit criterion function
#     success          :  corresponds to success component of OptimizeResult associated with Scipy's minimize function;
#                         success = True if the tetrad logit optimizer exited successfully
#
#
#     CALLS:           : ...logit()...
#                        ...organize_data_tetrad_logit()...
#     ------

# %% [markdown]
# Finally we call *tetrad\_logit()*. Depending on the speed and memory of your computer, this next bit of code may take a few minutes to complete.

# %%
[beta_TL, vcov_beta_TL, tetrad_frac_TL, success] = \
    netrics.tetrad_logit(D, W, dtcon=None, silent=False, W_names=cov_names)
# Out:
# Fisher-Scoring Derivative check (2-norm): 1.05880494
# Value of -logL = 69158.188469,  2-norm of score = 5050098.146665
# Value of -logL = 67593.624111,  2-norm of score = 798109.125689
# Value of -logL = 67538.094518,  2-norm of score = 227678.840354
# Value of -logL = 67033.773228,  2-norm of score = 180386.454584
# Value of -logL = 66303.957241,  2-norm of score = 97861.543728
# Value of -logL = 66113.734802,  2-norm of score = 45086.126082
# Value of -logL = 59607.729590,  2-norm of score = 387085.401838
# Value of -logL = 59595.163177,  2-norm of score = 14576.033822
# Value of -logL = 57635.344150,  2-norm of score = 50080.210276
# Value of -logL = 57635.115803,  2-norm of score = 10900.994775
# Value of -logL = 55435.049721,  2-norm of score = 64548.389938
# Value of -logL = 55434.672762,  2-norm of score = 8406.106366
# Value of -logL = 54462.006475,  2-norm of score = 14238.250795
# Value of -logL = 52751.424449,  2-norm of score = 55380.340383
# Value of -logL = 52751.136088,  2-norm of score = 5782.197257
# Value of -logL = 52005.455344,  2-norm of score = 9561.070961
# Value of -logL = 50687.061404,  2-norm of score = 36485.717021
# Value of -logL = 50686.930201,  2-norm of score = 4090.321811
# Value of -logL = 49440.579254,  2-norm of score = 30016.068000
# Value of -logL = 49440.487560,  2-norm of score = 3211.496347
# Value of -logL = 48566.525963,  2-norm of score = 19810.312676
# Value of -logL = 48566.484748,  2-norm of score = 2527.837498
# Value of -logL = 48157.299769,  2-norm of score = 6426.315328
# Value of -logL = 48157.294930,  2-norm of score = 2184.253932
# Value of -logL = 47958.204016,  2-norm of score = 2217.248957
# Value of -logL = 47619.748302,  2-norm of score = 8830.246280
# Value of -logL = 47619.739666,  2-norm of score = 1324.064824
# Value of -logL = 47531.538191,  2-norm of score = 1305.416800
# Value of -logL = 47384.157497,  2-norm of score = 3769.249861
# Value of -logL = 47384.155852,  2-norm of score = 779.626862
# Value of -logL = 47322.427277,  2-norm of score = 1062.737747
# Value of -logL = 47257.938350,  2-norm of score = 5035.548787
# Value of -logL = 47257.935426,  2-norm of score = 68.129900
# Value of -logL = 47257.907883,  2-norm of score = 59.100913
# Value of -logL = 47257.696659,  2-norm of score = 32.498108
# Value of -logL = 47257.572869,  2-norm of score = 8.986163
# Value of -logL = 47257.572869,  2-norm of score = 3.303643
# Value of -logL = 47257.572436,  2-norm of score = 2.802843
# Value of -logL = 47257.571732,  2-norm of score = 1.759384
# Value of -logL = 47257.571238,  2-norm of score = 0.457471
# Value of -logL = 47257.571203,  2-norm of score = 0.028014
# Value of -logL = 47257.571203,  2-norm of score = 0.005494
# Value of -logL = 47257.571203,  2-norm of score = 0.000550
# Value of -logL = 47257.571203,  2-norm of score = 0.000007
# Value of -logL = 47257.571203,  2-norm of score = 0.000003
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 47257.571203
#          Iterations: 45
#          Function evaluations: 118
#          Gradient evaluations: 162
#          Hessian evaluations: 46
#
# -------------------------------------------------------------------------------------------
# - TETRAD LOGIT ESTIMATION RESULTS                                                         -
# -------------------------------------------------------------------------------------------
#
# Number of agents,           N :             115
# Number of dyads,            n :           6,555
# Number of tetrads             :       6,913,340
# Number identifying tetrads    :         102,151
# Fraction identifying tetrads  :        0.014776
#
# -------------------------------------------------------------------------------------------
#
# Independent variable       Coef.    ( Std. Err.)
# -------------------------------------------------------------------------------------------
# Distance                  -0.002083 (  0.000319)
# Other blood relation       1.252720 (  0.293468)
# Cousin, etc.               2.038704 (  0.378834)
# Sibling, child, etc.       2.714449 (  0.417002)
# Age difference            -0.014838 (  0.006137)
# Same religion              0.236759 (  0.141679)
# Same clan                  0.277682 (  0.217226)
# Same education level      -0.012042 (  0.151148)
# Adjacent wealth class     -0.226542 (  0.160744)
# Non-adjacent wealth class -0.262694 (  0.175229)
#
# -------------------------------------------------------------------------------------------

# %% [markdown]
# The program spits out some useful information. In a network with $N = 115$ agents there are a total of $6,913,340$ different tetrads! Of these only $102,151$, or about 1.5 percent, actually contribute to the *tetrad\_logit()* criterion function. The effectiveness of the procedure in the context of sparse networks is one of its theoretical and practical attractions.
# <br>
# <br>
# The results suggest that ties are more frequent between households which are physically close, related by blood and where the household heads are close in age. There is little evidence for sorting by religion, clan or education. There is some evidence for heterophily in terms of wealth (perhaps consistent with some models of "mutual support"), but it is rather weak.
# <br>
# <br>
# The *tetrad\_logit()* estimation procedure is computationally intense. On a modern desktop machine it would be difficult to use the procedure on a network larger than a few hundred agents (fortunately there are many possible ways to apply the method at scale via various approximations and parallelizations; but these extensions are not yet part of the _netrics_ package).
# <br>
# <br>
# Part of the computational intensity is up front. Specifically, the function computes a detailed dictionary which maps dyads-to-tetrads and vice-versa. This bookkeeping overhead makes later calculations much quicker. A user who anticipates fitting several different models to the same adjacency matrix can save considerable time by computing this concordance first (once and for all) and then passing it to *tetrad\_logit()* via the _dtcon_ parameter. This can be done by calling the *generate\_tetrad\_indices()* function.
# <br>
# <br>
# To illustrate I create the concordance and then fit a model with only the distance and kinship variables included.

# %%
N = np.shape(D)[0]
concordance = netrics.generate_tetrad_indices(N, full_set=True)
[beta_TL, vcov_beta_TL, tetrad_frac_TL, success] = \
    netrics.tetrad_logit(D, W[0:4], dtcon=concordance, silent=False, W_names=cov_names[0:4])
# Out:
# Fisher-Scoring Derivative check (2-norm): 1.02942103
# Value of -logL = 69163.219831,  2-norm of score = 5045814.866051
# Value of -logL = 67604.839126,  2-norm of score = 772959.869305
# Value of -logL = 67557.021302,  2-norm of score = 30472.352890
# Value of -logL = 60570.400551,  2-norm of score = 312602.514426
# Value of -logL = 60562.290006,  2-norm of score = 9904.763394
# Value of -logL = 55914.238906,  2-norm of score = 204713.498450
# Value of -logL = 55910.626898,  2-norm of score = 6252.561744
# Value of -logL = 53745.637844,  2-norm of score = 62366.284082
# Value of -logL = 53745.287551,  2-norm of score = 4450.443068
# Value of -logL = 52853.901035,  2-norm of score = 13360.292597
# Value of -logL = 52853.883284,  2-norm of score = 3931.551890
# Value of -logL = 52132.409478,  2-norm of score = 9742.220437
# Value of -logL = 52132.399571,  2-norm of score = 3371.585318
# Value of -logL = 51720.042469,  2-norm of score = 4052.606975
# Value of -logL = 50991.862745,  2-norm of score = 17599.149968
# Value of -logL = 50991.832265,  2-norm of score = 2149.214175
# Value of -logL = 50682.138866,  2-norm of score = 3850.792333
# Value of -logL = 50172.544435,  2-norm of score = 16513.986055
# Value of -logL = 50172.516521,  2-norm of score = 1156.703198
# Value of -logL = 49922.576825,  2-norm of score = 6230.673557
# Value of -logL = 49922.572707,  2-norm of score = 735.041327
# Value of -logL = 49879.987204,  2-norm of score = 670.043618
# Value of -logL = 49806.691167,  2-norm of score = 1369.967641
# Value of -logL = 49806.690942,  2-norm of score = 479.235695
# Value of -logL = 49772.123874,  2-norm of score = 453.236335
# Value of -logL = 49728.917910,  2-norm of score = 2019.382002
# Value of -logL = 49728.917462,  2-norm of score = 84.932620
# Value of -logL = 49727.805761,  2-norm of score = 68.144642
# Value of -logL = 49726.185940,  2-norm of score = 49.589035
# Value of -logL = 49725.779131,  2-norm of score = 24.416378
# Value of -logL = 49725.779131,  2-norm of score = 1.468816
# Value of -logL = 49725.778969,  2-norm of score = 1.141102
# Value of -logL = 49725.778750,  2-norm of score = 0.401675
# Value of -logL = 49725.778715,  2-norm of score = 0.108367
# Value of -logL = 49725.778711,  2-norm of score = 0.003925
# Value of -logL = 49725.778711,  2-norm of score = 0.000140
# Value of -logL = 49725.778711,  2-norm of score = 0.000000
# Value of -logL = 49725.778711,  2-norm of score = 0.000000
# Optimization terminated successfully.
#          Current function value: 49725.778711
#          Iterations: 38
#          Function evaluations: 108
#          Gradient evaluations: 145
#          Hessian evaluations: 38
#
# -------------------------------------------------------------------------------------------
# - TETRAD LOGIT ESTIMATION RESULTS                                                         -
# -------------------------------------------------------------------------------------------
#
# Number of agents,           N :             115
# Number of dyads,            n :           6,555
# Number of tetrads             :       6,913,340
# Number identifying tetrads    :         102,151
# Fraction identifying tetrads  :        0.014776
#
# -------------------------------------------------------------------------------------------
#
# Independent variable       Coef.    ( Std. Err.)
# -------------------------------------------------------------------------------------------
# Distance                  -0.002067 (  0.000328)
# Other blood relation       1.307596 (  0.293372)
# Cousin, etc.               2.209613 (  0.393581)
# Sibling, child, etc.       2.895174 (  0.393442)
#
# -------------------------------------------------------------------------------------------

# %% [markdown]
# ## Joint Fixed Effects Logit
# Graham (2014) also introduces a joint fixed effects estimator for link formation. This procedure estimates the coefficients on $W_{k,ij}$ for $k=1,...,K$ as well as individual specific degree heterogeneity parameters $A_{i}$ for $i=1,...,N$. The *dyad\_jfe\_logit()* function implements this estimator. By default it reports the iterated bias-corrected estimates described in the paper (but the uncorrected estimates are also returned by the function).

# %%
[beta_JFE, beta_JFE_BC, vcov_beta_JFE, A_JFE, success] = \
    netrics.dyad_jfe_logit(D, W, T=None, silent=False, W_names=cov_names, beta_sv=None)
# Out:
# -------------------------------------------------------------------------------------------
# - COMPUTE JOINT FIXED EFFECT MLEs                                                         -
# -------------------------------------------------------------------------------------------
# Value of c_logl = 1573.908746,  2-norm of c_score = 62611.046459
# Value of c_logl = 1547.376191,  2-norm of c_score = 48351.980722
# Value of c_logl = 1529.569153,  2-norm of c_score = 37055.119814
# Value of c_logl = 1517.970321,  2-norm of c_score = 28245.623208
# Value of c_logl = 1510.616150,  2-norm of c_score = 21451.168506
# Value of c_logl = 1506.059569,  2-norm of c_score = 16250.801500
# Value of c_logl = 1503.289044,  2-norm of c_score = 12291.742962
# Value of c_logl = 1501.628945,  2-norm of c_score = 9289.106809
# Value of c_logl = 1500.644577,  2-norm of c_score = 7018.144552
# Value of c_logl = 1500.064492,  2-norm of c_score = 5304.237016
# Value of c_logl = 1499.723095,  2-norm of c_score = 4013.119659
# Value of c_logl = 1499.521148,  2-norm of c_score = 3042.343307
# Value of c_logl = 1499.399925,  2-norm of c_score = 2314.261004
# Value of c_logl = 1499.324894,  2-norm of c_score = 1770.542197
# Value of c_logl = 1498.607050,  2-norm of c_score = 2258.018679
# Value of c_logl = 1498.536662,  2-norm of c_score = 1724.573882
# Value of c_logl = 1497.866818,  2-norm of c_score = 2223.637539
# Value of c_logl = 1497.799693,  2-norm of c_score = 1695.060497
# Value of c_logl = 1497.757111,  2-norm of c_score = 1302.087806
# Value of c_logl = 1496.258277,  2-norm of c_score = 2734.965482
# Value of c_logl = 1496.163581,  2-norm of c_score = 2069.298596
# Value of c_logl = 1496.107418,  2-norm of c_score = 1570.486054
# Value of c_logl = 1496.073187,  2-norm of c_score = 1198.007724
# Value of c_logl = 1495.746945,  2-norm of c_score = 1539.794850
# Value of c_logl = 1495.714527,  2-norm of c_score = 1172.624209
# Value of c_logl = 1495.694052,  2-norm of c_score = 899.864079
# Value of c_logl = 1494.967496,  2-norm of c_score = 1862.966115
# Value of c_logl = 1494.923005,  2-norm of c_score = 1408.821272
# Value of c_logl = 1494.896671,  2-norm of c_score = 1068.848810
# Value of c_logl = 1494.880615,  2-norm of c_score = 815.264686
# Value of c_logl = 1494.726696,  2-norm of c_score = 1035.546577
# Value of c_logl = 1494.711790,  2-norm of c_score = 788.870116
# Value of c_logl = 1494.569435,  2-norm of c_score = 1010.064609
# Value of c_logl = 1494.555431,  2-norm of c_score = 768.366748
# Value of c_logl = 1494.422380,  2-norm of c_score = 994.116728
# Value of c_logl = 1494.409002,  2-norm of c_score = 755.030661
# Value of c_logl = 1494.400732,  2-norm of c_score = 577.112229
# Value of c_logl = 1494.109504,  2-norm of c_score = 1203.381540
# Value of c_logl = 1494.090899,  2-norm of c_score = 908.455124
# Value of c_logl = 1494.080006,  2-norm of c_score = 687.657953
# Value of c_logl = 1494.073470,  2-norm of c_score = 522.812072
# Value of c_logl = 1494.010779,  2-norm of c_score = 664.485318
# Value of c_logl = 1494.004725,  2-norm of c_score = 504.673114
# Value of c_logl = 1493.946751,  2-norm of c_score = 643.876412
# Value of c_logl = 1493.941113,  2-norm of c_score = 488.497667
# Value of c_logl = 1493.887199,  2-norm of c_score = 625.425013
# Value of c_logl = 1493.881922,  2-norm of c_score = 473.983541
# Value of c_logl = 1493.831503,  2-norm of c_score = 608.372676
# Value of c_logl = 1493.826547,  2-norm of c_score = 460.566634
# Value of c_logl = 1493.823549,  2-norm of c_score = 350.371861
# Value of c_logl = 1493.713926,  2-norm of c_score = 692.195543
# Value of c_logl = 1493.707710,  2-norm of c_score = 521.856849
# Value of c_logl = 1493.704081,  2-norm of c_score = 394.400210
# Value of c_logl = 1493.701908,  2-norm of c_score = 299.297882
# Value of c_logl = 1471.781195,  2-norm of c_score = 1960.485958
# Value of c_logl = 1471.731271,  2-norm of c_score = 1466.815609
# Value of c_logl = 1471.703468,  2-norm of c_score = 1097.836186
# Value of c_logl = 1471.687932,  2-norm of c_score = 822.026406
# Value of c_logl = 1471.679215,  2-norm of c_score = 615.870988
# Value of c_logl = 1471.674295,  2-norm of c_score = 461.821212
# Value of c_logl = 1471.671493,  2-norm of c_score = 346.782507
# Value of c_logl = 1471.669872,  2-norm of c_score = 260.994723
# Value of c_logl = 1455.220765,  2-norm of c_score = 2060.780255
# Value of c_logl = 1455.165796,  2-norm of c_score = 1540.454554
# Value of c_logl = 1455.135222,  2-norm of c_score = 1152.371645
# Value of c_logl = 1455.118123,  2-norm of c_score = 862.932814
# Value of c_logl = 1455.108489,  2-norm of c_score = 647.131211
# Value of c_logl = 1455.102998,  2-norm of c_score = 486.357165
# Value of c_logl = 1455.099807,  2-norm of c_score = 366.780768
# Value of c_logl = 1455.097889,  2-norm of c_score = 278.174182
# Value of c_logl = 1455.028264,  2-norm of c_score = 564.106216
# Value of c_logl = 1455.024118,  2-norm of c_score = 423.470415
# Value of c_logl = 1455.021726,  2-norm of c_score = 318.791393
# Value of c_logl = 1455.020307,  2-norm of c_score = 241.101035
# Value of c_logl = 1440.695773,  2-norm of c_score = 1908.841340
# Value of c_logl = 1440.648835,  2-norm of c_score = 1425.708419
# Value of c_logl = 1440.622712,  2-norm of c_score = 1065.961516
# Value of c_logl = 1440.608065,  2-norm of c_score = 798.157039
# Value of c_logl = 1440.599759,  2-norm of c_score = 598.934961
# Value of c_logl = 1440.594962,  2-norm of c_score = 450.959975
# Value of c_logl = 1440.592101,  2-norm of c_score = 341.421313
# Value of c_logl = 1440.493115,  2-norm of c_score = 735.841308
# Value of c_logl = 1440.486145,  2-norm of c_score = 551.126921
# Value of c_logl = 1440.482176,  2-norm of c_score = 413.728445
# Value of c_logl = 1440.479870,  2-norm of c_score = 311.714581
# Value of c_logl = 1440.457873,  2-norm of c_score = 404.740210
# Value of c_logl = 1440.455685,  2-norm of c_score = 304.603267
# Value of c_logl = 1440.454381,  2-norm of c_score = 230.465951
# Value of c_logl = 1440.407004,  2-norm of c_score = 468.851569
# Value of c_logl = 1440.404160,  2-norm of c_score = 351.321294
# Value of c_logl = 1440.402528,  2-norm of c_score = 263.951103
# Value of c_logl = 1440.401565,  2-norm of c_score = 199.177876
# Value of c_logl = 1430.515615,  2-norm of c_score = 1347.917577
# Value of c_logl = 1430.492429,  2-norm of c_score = 1006.162086
# Value of c_logl = 1430.479506,  2-norm of c_score = 751.873276
# Value of c_logl = 1430.472247,  2-norm of c_score = 562.740132
# Value of c_logl = 1430.468118,  2-norm of c_score = 422.195223
# Value of c_logl = 1430.465720,  2-norm of c_score = 317.957972
# Value of c_logl = 1430.464274,  2-norm of c_score = 240.979195
# Value of c_logl = 1430.412181,  2-norm of c_score = 494.717255
# Value of c_logl = 1430.409018,  2-norm of c_score = 370.674374
# Value of c_logl = 1430.407198,  2-norm of c_score = 278.581058
# Value of c_logl = 1430.406120,  2-norm of c_score = 210.420424
# Value of c_logl = 1430.367405,  2-norm of c_score = 435.587761
# Value of c_logl = 1430.364967,  2-norm of c_score = 325.947975
# Value of c_logl = 1430.363576,  2-norm of c_score = 244.485289
# Value of c_logl = 1430.362763,  2-norm of c_score = 184.097863
# Value of c_logl = 1421.985250,  2-norm of c_score = 1123.483749
# Value of c_logl = 1421.969224,  2-norm of c_score = 838.173565
# Value of c_logl = 1421.960293,  2-norm of c_score = 626.005223
# Value of c_logl = 1421.955276,  2-norm of c_score = 468.299100
# Value of c_logl = 1421.952422,  2-norm of c_score = 351.190269
# Value of c_logl = 1421.950762,  2-norm of c_score = 264.408434
# Value of c_logl = 1421.934941,  2-norm of c_score = 343.713162
# Value of c_logl = 1421.933367,  2-norm of c_score = 258.472747
# Value of c_logl = 1421.932425,  2-norm of c_score = 195.507287
# Value of c_logl = 1421.898450,  2-norm of c_score = 401.591928
# Value of c_logl = 1421.896376,  2-norm of c_score = 300.566537
# Value of c_logl = 1421.895188,  2-norm of c_score = 225.590395
# Value of c_logl = 1421.894487,  2-norm of c_score = 170.106319
# Value of c_logl = 1421.868928,  2-norm of c_score = 344.925147
# Value of c_logl = 1421.867403,  2-norm of c_score = 257.896217
# Value of c_logl = 1421.866532,  2-norm of c_score = 193.280195
# Value of c_logl = 1421.866024,  2-norm of c_score = 145.422606
# Value of c_logl = 1403.498575,  2-norm of c_score = 2271.102601
# Value of c_logl = 1403.432614,  2-norm of c_score = 1690.991433
# Value of c_logl = 1403.396265,  2-norm of c_score = 1259.945376
# Value of c_logl = 1403.376129,  2-norm of c_score = 939.682606
# Value of c_logl = 1403.364898,  2-norm of c_score = 701.799618
# Value of c_logl = 1403.358569,  2-norm of c_score = 525.226523
# Value of c_logl = 1403.354941,  2-norm of c_score = 394.351074
# Value of c_logl = 1403.352799,  2-norm of c_score = 297.647854
# Value of c_logl = 1403.332252,  2-norm of c_score = 381.059587
# Value of c_logl = 1403.330270,  2-norm of c_score = 287.329013
# Value of c_logl = 1403.311340,  2-norm of c_score = 370.918453
# Value of c_logl = 1403.309483,  2-norm of c_score = 279.351951
# Value of c_logl = 1403.308351,  2-norm of c_score = 211.958731
# Value of c_logl = 1403.267490,  2-norm of c_score = 433.557738
# Value of c_logl = 1403.265070,  2-norm of c_score = 324.677151
# Value of c_logl = 1403.263673,  2-norm of c_score = 244.012063
# Value of c_logl = 1403.262839,  2-norm of c_score = 184.480102
# Value of c_logl = 1403.233461,  2-norm of c_score = 390.826856
# Value of c_logl = 1403.231516,  2-norm of c_score = 292.192413
# Value of c_logl = 1403.230408,  2-norm of c_score = 219.023376
# Value of c_logl = 1403.229761,  2-norm of c_score = 164.874681
# Value of c_logl = 1403.207853,  2-norm of c_score = 365.916246
# Value of c_logl = 1403.206164,  2-norm of c_score = 273.047240
# Value of c_logl = 1403.205213,  2-norm of c_score = 204.076747
# Value of c_logl = 1403.204670,  2-norm of c_score = 152.918771
# Value of c_logl = 1403.204353,  2-norm of c_score = 115.071706
# Value of c_logl = 1403.192595,  2-norm of c_score = 228.174604
# Value of c_logl = 1403.191931,  2-norm of c_score = 170.414344
# Value of c_logl = 1403.191552,  2-norm of c_score = 127.567252
# Value of c_logl = 1403.191331,  2-norm of c_score = 95.863544
# Value of c_logl = 1394.251916,  2-norm of c_score = 258.675313
# Value of c_logl = 1394.251072,  2-norm of c_score = 193.060001
# Value of c_logl = 1394.250594,  2-norm of c_score = 144.362562
# Value of c_logl = 1394.250320,  2-norm of c_score = 108.282340
# Value of c_logl = 1394.250156,  2-norm of c_score = 81.647486
# Value of c_logl = 1387.539374,  2-norm of c_score = 202.960395
# Value of c_logl = 1387.538850,  2-norm of c_score = 151.686077
# Value of c_logl = 1387.538550,  2-norm of c_score = 113.684668
# Value of c_logl = 1387.538374,  2-norm of c_score = 85.603748
# Value of c_logl = 1387.531861,  2-norm of c_score = 170.404584
# Value of c_logl = 1387.531492,  2-norm of c_score = 127.261278
# Value of c_logl = 1387.531281,  2-norm of c_score = 95.280811
# Value of c_logl = 1387.531157,  2-norm of c_score = 71.641468
# Value of c_logl = 1382.417919,  2-norm of c_score = 215.601866
# Value of c_logl = 1382.417335,  2-norm of c_score = 160.852808
# Value of c_logl = 1382.417005,  2-norm of c_score = 120.237040
# Value of c_logl = 1382.416815,  2-norm of c_score = 90.156134
# Value of c_logl = 1382.416703,  2-norm of c_score = 67.956264
# Value of c_logl = 1377.803705,  2-norm of c_score = 203.215319
# Value of c_logl = 1377.803185,  2-norm of c_score = 151.682640
# Value of c_logl = 1377.802891,  2-norm of c_score = 113.476032
# Value of c_logl = 1377.802720,  2-norm of c_score = 85.206736
# Value of c_logl = 1377.796920,  2-norm of c_score = 188.920010
# Value of c_logl = 1377.796474,  2-norm of c_score = 140.767900
# Value of c_logl = 1377.796224,  2-norm of c_score = 105.036028
# Value of c_logl = 1377.796082,  2-norm of c_score = 78.551078
# Value of c_logl = 1377.795999,  2-norm of c_score = 58.966134
# Value of c_logl = 1374.398016,  2-norm of c_score = 234.381558
# Value of c_logl = 1374.397332,  2-norm of c_score = 174.615057
# Value of c_logl = 1374.396949,  2-norm of c_score = 130.264444
# Value of c_logl = 1374.396733,  2-norm of c_score = 97.383255
# Value of c_logl = 1374.396608,  2-norm of c_score = 73.049889
# Value of c_logl = 1374.396534,  2-norm of c_score = 55.112956
# Value of c_logl = 1374.393759,  2-norm of c_score = 107.676696
# Value of c_logl = 1374.393611,  2-norm of c_score = 80.463292
# Value of c_logl = 1374.393526,  2-norm of c_score = 60.325182
# Value of c_logl = 1374.390423,  2-norm of c_score = 123.453170
# Value of c_logl = 1374.390231,  2-norm of c_score = 91.976768
# Value of c_logl = 1374.390124,  2-norm of c_score = 68.635481
# Value of c_logl = 1374.390062,  2-norm of c_score = 51.355270
# Value of c_logl = 1374.390025,  2-norm of c_score = 38.607167
# Value of c_logl = 1368.956778,  2-norm of c_score = 397.205209
# Value of c_logl = 1368.954823,  2-norm of c_score = 295.413196
# Value of c_logl = 1368.953741,  2-norm of c_score = 219.858203
# Value of c_logl = 1368.953139,  2-norm of c_score = 163.792229
# Value of c_logl = 1368.952803,  2-norm of c_score = 122.209381
# Value of c_logl = 1368.952612,  2-norm of c_score = 91.399074
# Value of c_logl = 1368.952502,  2-norm of c_score = 68.616615
# Value of c_logl = 1368.952436,  2-norm of c_score = 51.844278
# Value of c_logl = 1368.950036,  2-norm of c_score = 105.926345
# Value of c_logl = 1368.949894,  2-norm of c_score = 79.135001
# Value of c_logl = 1368.949812,  2-norm of c_score = 59.308557
# Value of c_logl = 1368.949764,  2-norm of c_score = 44.686716
# Value of c_logl = 1368.948012,  2-norm of c_score = 91.542995
# Value of c_logl = 1368.947906,  2-norm of c_score = 68.317537
# Value of c_logl = 1368.947846,  2-norm of c_score = 51.119883
# Value of c_logl = 1368.947811,  2-norm of c_score = 38.420842
# Value of c_logl = 1368.946500,  2-norm of c_score = 76.061738
# Value of c_logl = 1368.946427,  2-norm of c_score = 56.728812
# Value of c_logl = 1368.946385,  2-norm of c_score = 42.413130
# Value of c_logl = 1368.946361,  2-norm of c_score = 31.841887
# Value of c_logl = 1367.929328,  2-norm of c_score = 93.837044
# Value of c_logl = 1367.929217,  2-norm of c_score = 69.938051
# Value of c_logl = 1367.929155,  2-norm of c_score = 52.227312
# Value of c_logl = 1367.929119,  2-norm of c_score = 39.125553
# Value of c_logl = 1367.929098,  2-norm of c_score = 29.469844
# Value of c_logl = 1367.046116,  2-norm of c_score = 98.884107
# Value of c_logl = 1367.045993,  2-norm of c_score = 73.718848
# Value of c_logl = 1367.045924,  2-norm of c_score = 55.072544
# Value of c_logl = 1367.045885,  2-norm of c_score = 41.281267
# Value of c_logl = 1367.045861,  2-norm of c_score = 31.120128
# Value of c_logl = 1367.044981,  2-norm of c_score = 61.302112
# Value of c_logl = 1367.044933,  2-norm of c_score = 45.773283
# Value of c_logl = 1367.044906,  2-norm of c_score = 34.287170
# Value of c_logl = 1367.044890,  2-norm of c_score = 25.823601
# Value of c_logl = 1366.365137,  2-norm of c_score = 94.770543
# Value of c_logl = 1366.365025,  2-norm of c_score = 70.623714
# Value of c_logl = 1366.364962,  2-norm of c_score = 52.729403
# Value of c_logl = 1366.364926,  2-norm of c_score = 39.489118
# Value of c_logl = 1366.364904,  2-norm of c_score = 29.724361
# Value of c_logl = 1366.364125,  2-norm of c_score = 60.306390
# Value of c_logl = 1366.364079,  2-norm of c_score = 44.985689
# Value of c_logl = 1366.364053,  2-norm of c_score = 33.645158
# Value of c_logl = 1366.364038,  2-norm of c_score = 25.274423
# Value of c_logl = 1365.733113,  2-norm of c_score = 96.872772
# Value of c_logl = 1365.732996,  2-norm of c_score = 72.140259
# Value of c_logl = 1365.732931,  2-norm of c_score = 53.805980
# Value of c_logl = 1365.732894,  2-norm of c_score = 40.230040
# Value of c_logl = 1365.732872,  2-norm of c_score = 30.200596
# Value of c_logl = 1365.732123,  2-norm of c_score = 65.560706
# Value of c_logl = 1365.732069,  2-norm of c_score = 48.822753
# Value of c_logl = 1365.732039,  2-norm of c_score = 36.418787
# Value of c_logl = 1365.732022,  2-norm of c_score = 27.239980
# Value of c_logl = 1365.732012,  2-norm of c_score = 20.468469
# Value of c_logl = 1365.311751,  2-norm of c_score = 75.349295
# Value of c_logl = 1365.311681,  2-norm of c_score = 56.117508
# Value of c_logl = 1365.311641,  2-norm of c_score = 41.864343
# Value of c_logl = 1365.311618,  2-norm of c_score = 31.314637
# Value of c_logl = 1365.311605,  2-norm of c_score = 23.527003
# Value of c_logl = 1365.311129,  2-norm of c_score = 48.716661
# Value of c_logl = 1365.311099,  2-norm of c_score = 36.303080
# Value of c_logl = 1365.311082,  2-norm of c_score = 27.110433
# Value of c_logl = 1365.311072,  2-norm of c_score = 20.317563
# Value of c_logl = 1364.910986,  2-norm of c_score = 76.228545
# Value of c_logl = 1364.910914,  2-norm of c_score = 56.735978
# Value of c_logl = 1364.910874,  2-norm of c_score = 42.285316
# Value of c_logl = 1364.910851,  2-norm of c_score = 31.582410
# Value of c_logl = 1364.910838,  2-norm of c_score = 23.670100
# Value of c_logl = 1364.910830,  2-norm of c_score = 17.844346
# Value of c_logl = 1364.910538,  2-norm of c_score = 34.808475
# Value of c_logl = 1364.910522,  2-norm of c_score = 25.989251
# Value of c_logl = 1364.910513,  2-norm of c_score = 19.470268
# Value of c_logl = 1364.910189,  2-norm of c_score = 39.891750
# Value of c_logl = 1364.910169,  2-norm of c_score = 29.694750
# Value of c_logl = 1364.910158,  2-norm of c_score = 22.141108
# Value of c_logl = 1364.910151,  2-norm of c_score = 16.555197
# Value of c_logl = 1364.910148,  2-norm of c_score = 12.439619
# Value of c_logl = 1364.338427,  2-norm of c_score = 121.214121
# Value of c_logl = 1364.338245,  2-norm of c_score = 90.087699
# Value of c_logl = 1364.338145,  2-norm of c_score = 66.999484
# Value of c_logl = 1364.338089,  2-norm of c_score = 49.878438
# Value of c_logl = 1364.338058,  2-norm of c_score = 37.189077
# Value of c_logl = 1364.338040,  2-norm of c_score = 27.793946
# Value of c_logl = 1364.338030,  2-norm of c_score = 20.852291
# Value of c_logl = 1364.338024,  2-norm of c_score = 15.746652
# Value of c_logl = 1364.337799,  2-norm of c_score = 31.735451
# Value of c_logl = 1364.337786,  2-norm of c_score = 23.698116
# Value of c_logl = 1364.337779,  2-norm of c_score = 17.756474
# Value of c_logl = 1364.337775,  2-norm of c_score = 13.381061
# Value of c_logl = 1364.337612,  2-norm of c_score = 26.579771
# Value of c_logl = 1364.337603,  2-norm of c_score = 19.836162
# Value of c_logl = 1364.337598,  2-norm of c_score = 14.850067
# Value of c_logl = 1364.337595,  2-norm of c_score = 11.176970
# Value of c_logl = 1364.211003,  2-norm of c_score = 20.388455
# Value of c_logl = 1364.210998,  2-norm of c_score = 15.246720
# Value of c_logl = 1364.210994,  2-norm of c_score = 11.453164
# Value of c_logl = 1364.210878,  2-norm of c_score = 22.939849
# Value of c_logl = 1364.210872,  2-norm of c_score = 17.096124
# Value of c_logl = 1364.210868,  2-norm of c_score = 12.771888
# Value of c_logl = 1364.210866,  2-norm of c_score = 9.580586
# Value of c_logl = 1364.119127,  2-norm of c_score = 31.016066
# Value of c_logl = 1364.119115,  2-norm of c_score = 23.093759
# Value of c_logl = 1364.119108,  2-norm of c_score = 17.224971
# Value of c_logl = 1364.119105,  2-norm of c_score = 12.883699
# Value of c_logl = 1364.119102,  2-norm of c_score = 9.682069
# Value of c_logl = 1364.119018,  2-norm of c_score = 18.988249
# Value of c_logl = 1364.119013,  2-norm of c_score = 14.156312
# Value of c_logl = 1364.119011,  2-norm of c_score = 10.582426
# Value of c_logl = 1364.119009,  2-norm of c_score = 7.947411
# Value of c_logl = 1363.901506,  2-norm of c_score = 66.100729
# Value of c_logl = 1363.901452,  2-norm of c_score = 49.118568
# Value of c_logl = 1363.901422,  2-norm of c_score = 36.524181
# Value of c_logl = 1363.901405,  2-norm of c_score = 27.186460
# Value of c_logl = 1363.901396,  2-norm of c_score = 20.266916
# Value of c_logl = 1363.901391,  2-norm of c_score = 15.144500
# Value of c_logl = 1363.901388,  2-norm of c_score = 11.360193
# Value of c_logl = 1363.901386,  2-norm of c_score = 8.576847
# Value of c_logl = 1363.901320,  2-norm of c_score = 17.596778
# Value of c_logl = 1363.901316,  2-norm of c_score = 13.134686
# Value of c_logl = 1363.901314,  2-norm of c_score = 9.835508
# Value of c_logl = 1363.901312,  2-norm of c_score = 7.404531
# Value of c_logl = 1363.901264,  2-norm of c_score = 15.330551
# Value of c_logl = 1363.901261,  2-norm of c_score = 11.429983
# Value of c_logl = 1363.901260,  2-norm of c_score = 8.544019
# Value of c_logl = 1363.901259,  2-norm of c_score = 6.414384
# Value of c_logl = 1363.901223,  2-norm of c_score = 13.029744
# Value of c_logl = 1363.901221,  2-norm of c_score = 9.706085
# Value of c_logl = 1363.901219,  2-norm of c_score = 7.246319
# Value of c_logl = 1363.901219,  2-norm of c_score = 5.430189
# Value of c_logl = 1363.872084,  2-norm of c_score = 15.332520
# Value of c_logl = 1363.872082,  2-norm of c_score = 11.416800
# Value of c_logl = 1363.872080,  2-norm of c_score = 8.516985
# Value of c_logl = 1363.872079,  2-norm of c_score = 6.373020
# Value of c_logl = 1363.872078,  2-norm of c_score = 4.793390
# Value of c_logl = 1363.848920,  2-norm of c_score = 12.255814
# Value of c_logl = 1363.848918,  2-norm of c_score = 9.139408
# Value of c_logl = 1363.848917,  2-norm of c_score = 6.833999
# Value of c_logl = 1363.848916,  2-norm of c_score = 5.133273
# Value of c_logl = 1363.848893,  2-norm of c_score = 10.542102
# Value of c_logl = 1363.848892,  2-norm of c_score = 7.853609
# Value of c_logl = 1363.848891,  2-norm of c_score = 5.863939
# Value of c_logl = 1363.848891,  2-norm of c_score = 4.394867
# Value of c_logl = 1363.829963,  2-norm of c_score = 14.088431
# Value of c_logl = 1363.829961,  2-norm of c_score = 10.486562
# Value of c_logl = 1363.829959,  2-norm of c_score = 7.818336
# Value of c_logl = 1363.829959,  2-norm of c_score = 5.844273
# Value of c_logl = 1363.829958,  2-norm of c_score = 4.387639
# Value of c_logl = 1363.829941,  2-norm of c_score = 8.988987
# Value of c_logl = 1363.829940,  2-norm of c_score = 6.695340
# Value of c_logl = 1363.829940,  2-norm of c_score = 4.997808
# Value of c_logl = 1363.829939,  2-norm of c_score = 3.744296
# Value of c_logl = 1363.816176,  2-norm of c_score = 11.098228
# Value of c_logl = 1363.816175,  2-norm of c_score = 8.261708
# Value of c_logl = 1363.816174,  2-norm of c_score = 6.160788
# Value of c_logl = 1363.816173,  2-norm of c_score = 4.606929
# Value of c_logl = 1363.816173,  2-norm of c_score = 3.461109
# Value of c_logl = 1363.816162,  2-norm of c_score = 6.807740
# Value of c_logl = 1363.816162,  2-norm of c_score = 5.074084
# Value of c_logl = 1363.816161,  2-norm of c_score = 3.791964
# Value of c_logl = 1363.816161,  2-norm of c_score = 2.846708
# Value of c_logl = 1363.788372,  2-norm of c_score = 23.353544
# Value of c_logl = 1363.788365,  2-norm of c_score = 17.351079
# Value of c_logl = 1363.788361,  2-norm of c_score = 12.899922
# Value of c_logl = 1363.788359,  2-norm of c_score = 9.600029
# Value of c_logl = 1363.788358,  2-norm of c_score = 7.154865
# Value of c_logl = 1363.788357,  2-norm of c_score = 5.344795
# Value of c_logl = 1363.788357,  2-norm of c_score = 4.007472
# Value of c_logl = 1363.788357,  2-norm of c_score = 3.023582
# Value of c_logl = 1363.788349,  2-norm of c_score = 6.244662
# Value of c_logl = 1363.788348,  2-norm of c_score = 4.659345
# Value of c_logl = 1363.788348,  2-norm of c_score = 3.487067
# Value of c_logl = 1363.788348,  2-norm of c_score = 2.622958
# Value of c_logl = 1363.788342,  2-norm of c_score = 5.481811
# Value of c_logl = 1363.788341,  2-norm of c_score = 4.085099
# Value of c_logl = 1363.788341,  2-norm of c_score = 3.051543
# Value of c_logl = 1363.788341,  2-norm of c_score = 2.288519
# Value of c_logl = 1363.788336,  2-norm of c_score = 4.688429
# Value of c_logl = 1363.788336,  2-norm of c_score = 3.490528
# Value of c_logl = 1363.788336,  2-norm of c_score = 2.603836
# Value of c_logl = 1363.788336,  2-norm of c_score = 1.948844
# Value of c_logl = 1363.784614,  2-norm of c_score = 4.822195
# Value of c_logl = 1363.784614,  2-norm of c_score = 3.590497
# Value of c_logl = 1363.784614,  2-norm of c_score = 2.678598
# Value of c_logl = 1363.784613,  2-norm of c_score = 2.004686
# Value of c_logl = 1363.784613,  2-norm of c_score = 1.508589
# Value of c_logl = 1363.782267,  2-norm of c_score = 3.789822
# Value of c_logl = 1363.782267,  2-norm of c_score = 2.826838
# Value of c_logl = 1363.782267,  2-norm of c_score = 2.114849
# Value of c_logl = 1363.782267,  2-norm of c_score = 1.590186
# Value of c_logl = 1363.782264,  2-norm of c_score = 3.083881
# Value of c_logl = 1363.782264,  2-norm of c_score = 2.299630
# Value of c_logl = 1363.782264,  2-norm of c_score = 1.719948
# Value of c_logl = 1363.782264,  2-norm of c_score = 1.293043
# Value of c_logl = 1363.776356,  2-norm of c_score = 10.044288
# Value of c_logl = 1363.776355,  2-norm of c_score = 7.463245
# Value of c_logl = 1363.776354,  2-norm of c_score = 5.549409
# Value of c_logl = 1363.776354,  2-norm of c_score = 4.130746
# Value of c_logl = 1363.776354,  2-norm of c_score = 3.079755
# Value of c_logl = 1363.776354,  2-norm of c_score = 2.302031
# Value of c_logl = 1363.776353,  2-norm of c_score = 1.727855
# Value of c_logl = 1363.776353,  2-norm of c_score = 1.306127
# Value of c_logl = 1363.776352,  2-norm of c_score = 2.596714
# Value of c_logl = 1363.776352,  2-norm of c_score = 1.939775
# Value of c_logl = 1363.776352,  2-norm of c_score = 1.454599
# Value of c_logl = 1363.776352,  2-norm of c_score = 1.097949
# Value of c_logl = 1363.776351,  2-norm of c_score = 2.143239
# Value of c_logl = 1363.776350,  2-norm of c_score = 1.600539
# Value of c_logl = 1363.776350,  2-norm of c_score = 1.199766
# Value of c_logl = 1363.776349,  2-norm of c_score = 2.516224
# Value of c_logl = 1363.776349,  2-norm of c_score = 1.872583
# Value of c_logl = 1363.776349,  2-norm of c_score = 1.396016
# Value of c_logl = 1363.776349,  2-norm of c_score = 1.043754
# Value of c_logl = 1363.776349,  2-norm of c_score = 0.784316
# Value of c_logl = 1363.774135,  2-norm of c_score = 5.188363
# Value of c_logl = 1363.774135,  2-norm of c_score = 3.855379
# Value of c_logl = 1363.774135,  2-norm of c_score = 2.867042
# Value of c_logl = 1363.774135,  2-norm of c_score = 2.134509
# Value of c_logl = 1363.774135,  2-norm of c_score = 1.591945
# Value of c_logl = 1363.774135,  2-norm of c_score = 1.190625
# Value of c_logl = 1363.774134,  2-norm of c_score = 0.894607
# Value of c_logl = 1363.774134,  2-norm of c_score = 1.908830
# Value of c_logl = 1363.774134,  2-norm of c_score = 1.421596
# Value of c_logl = 1363.774134,  2-norm of c_score = 1.060907
# Value of c_logl = 1363.774134,  2-norm of c_score = 0.794401
# Value of c_logl = 1363.774134,  2-norm of c_score = 0.598288
# Value of c_logl = 1363.773766,  2-norm of c_score = 1.732283
# Value of c_logl = 1363.773766,  2-norm of c_score = 1.291365
# Value of c_logl = 1363.773766,  2-norm of c_score = 0.965154
# Value of c_logl = 1363.773766,  2-norm of c_score = 0.724419
# Value of c_logl = 1363.773766,  2-norm of c_score = 1.524600
# Value of c_logl = 1363.773766,  2-norm of c_score = 1.135131
# Value of c_logl = 1363.773766,  2-norm of c_score = 0.846814
# Value of c_logl = 1363.773766,  2-norm of c_score = 0.633781
# Value of c_logl = 1363.773381,  2-norm of c_score = 1.999611
# Value of c_logl = 1363.773381,  2-norm of c_score = 1.487775
# Value of c_logl = 1363.773380,  2-norm of c_score = 1.108568
# Value of c_logl = 1363.773380,  2-norm of c_score = 0.827923
# Value of c_logl = 1363.773380,  2-norm of c_score = 0.620671
# Value of c_logl = 1363.773380,  2-norm of c_score = 1.323927
# Value of c_logl = 1363.773380,  2-norm of c_score = 0.985168
# Value of c_logl = 1363.773380,  2-norm of c_score = 0.734310
# Value of c_logl = 1363.773380,  2-norm of c_score = 0.548832
# Value of c_logl = 1363.773380,  2-norm of c_score = 0.412142
# Value of c_logl = 1363.772789,  2-norm of c_score = 3.397163
# Value of c_logl = 1363.772789,  2-norm of c_score = 2.523901
# Value of c_logl = 1363.772789,  2-norm of c_score = 1.876365
# Value of c_logl = 1363.772789,  2-norm of c_score = 1.396341
# Value of c_logl = 1363.772789,  2-norm of c_score = 1.040678
# Value of c_logl = 1363.772789,  2-norm of c_score = 0.777419
# Value of c_logl = 1363.772789,  2-norm of c_score = 0.582947
# Value of c_logl = 1363.772789,  2-norm of c_score = 0.439912
# Value of c_logl = 1363.772788,  2-norm of c_score = 0.900738
# Value of c_logl = 1363.772788,  2-norm of c_score = 0.672167
# Value of c_logl = 1363.772788,  2-norm of c_score = 0.503193
# Value of c_logl = 1363.772788,  2-norm of c_score = 0.378703
# Value of c_logl = 1363.772788,  2-norm of c_score = 0.777304
# Value of c_logl = 1363.772788,  2-norm of c_score = 0.579461
# Value of c_logl = 1363.772788,  2-norm of c_score = 0.433121
# Value of c_logl = 1363.772788,  2-norm of c_score = 0.325178
# Value of c_logl = 1363.772788,  2-norm of c_score = 0.645960
# Value of c_logl = 1363.772788,  2-norm of c_score = 0.481252
# Value of c_logl = 1363.772788,  2-norm of c_score = 0.359418
# Value of c_logl = 1363.772788,  2-norm of c_score = 0.269548
# Value of c_logl = 1363.772715,  2-norm of c_score = 0.579796
# Value of c_logl = 1363.772715,  2-norm of c_score = 0.432300
# Value of c_logl = 1363.772715,  2-norm of c_score = 0.323253
# Value of c_logl = 1363.772715,  2-norm of c_score = 0.242901
# Value of c_logl = 1363.772655,  2-norm of c_score = 0.614720
# Value of c_logl = 1363.772655,  2-norm of c_score = 0.458273
# Value of c_logl = 1363.772655,  2-norm of c_score = 0.342557
# Value of c_logl = 1363.772655,  2-norm of c_score = 0.257210
# Value of c_logl = 1363.772655,  2-norm of c_score = 0.508695
# Value of c_logl = 1363.772655,  2-norm of c_score = 0.379019
# Value of c_logl = 1363.772655,  2-norm of c_score = 0.283108
# Value of c_logl = 1363.772655,  2-norm of c_score = 0.212373
# Value of c_logl = 1363.772609,  2-norm of c_score = 0.585656
# Value of c_logl = 1363.772609,  2-norm of c_score = 0.436204
# Value of c_logl = 1363.772609,  2-norm of c_score = 0.325588
# Value of c_logl = 1363.772609,  2-norm of c_score = 0.243885
# Value of c_logl = 1363.772609,  2-norm of c_score = 0.492902
# Value of c_logl = 1363.772609,  2-norm of c_score = 0.366818
# Value of c_logl = 1363.772609,  2-norm of c_score = 0.273488
# Value of c_logl = 1363.772609,  2-norm of c_score = 0.204539
# Value of c_logl = 1363.772568,  2-norm of c_score = 0.592435
# Value of c_logl = 1363.772568,  2-norm of c_score = 0.440781
# Value of c_logl = 1363.772568,  2-norm of c_score = 0.328453
# Value of c_logl = 1363.772568,  2-norm of c_score = 0.245362
# Value of c_logl = 1363.772568,  2-norm of c_score = 0.184064
# Value of c_logl = 1363.772534,  2-norm of c_score = 0.464302
# Value of c_logl = 1363.772534,  2-norm of c_score = 0.345947
# Value of c_logl = 1363.772534,  2-norm of c_score = 0.258365
# Value of c_logl = 1363.772534,  2-norm of c_score = 0.193704
# Value of c_logl = 1363.772534,  2-norm of c_score = 0.396154
# Value of c_logl = 1363.772534,  2-norm of c_score = 0.294895
# Value of c_logl = 1363.772534,  2-norm of c_score = 0.219946
# Value of c_logl = 1363.772534,  2-norm of c_score = 0.164582
# Value of c_logl = 1363.772508,  2-norm of c_score = 0.492197
# Value of c_logl = 1363.772508,  2-norm of c_score = 0.366237
# Value of c_logl = 1363.772508,  2-norm of c_score = 0.272936
# Value of c_logl = 1363.772508,  2-norm of c_score = 0.203915
# Value of c_logl = 1363.772508,  2-norm of c_score = 0.152989
# Value of c_logl = 1363.772508,  2-norm of c_score = 0.298097
# Value of c_logl = 1363.772508,  2-norm of c_score = 0.222065
# Value of c_logl = 1363.772508,  2-norm of c_score = 0.165831
# Value of c_logl = 1363.772508,  2-norm of c_score = 0.124360
# Value of c_logl = 1363.772454,  2-norm of c_score = 0.953268
# Value of c_logl = 1363.772454,  2-norm of c_score = 0.708183
# Value of c_logl = 1363.772454,  2-norm of c_score = 0.526449
# Value of c_logl = 1363.772454,  2-norm of c_score = 0.391727
# Value of c_logl = 1363.772454,  2-norm of c_score = 0.291906
# Value of c_logl = 1363.772454,  2-norm of c_score = 0.218016
# Value of c_logl = 1363.772454,  2-norm of c_score = 0.163428
# Value of c_logl = 1363.772454,  2-norm of c_score = 0.123269
# Value of c_logl = 1363.772454,  2-norm of c_score = 0.250189
# Value of c_logl = 1363.772454,  2-norm of c_score = 0.186688
# Value of c_logl = 1363.772454,  2-norm of c_score = 0.139748
# Value of c_logl = 1363.772454,  2-norm of c_score = 0.105171
# Value of c_logl = 1363.772454,  2-norm of c_score = 0.210324
# Value of c_logl = 1363.772454,  2-norm of c_score = 0.156835
# Value of c_logl = 1363.772454,  2-norm of c_score = 0.117287
# Value of c_logl = 1363.772441,  2-norm of c_score = 0.297205
# Value of c_logl = 1363.772441,  2-norm of c_score = 0.221175
# Value of c_logl = 1363.772441,  2-norm of c_score = 0.164854
# Value of c_logl = 1363.772441,  2-norm of c_score = 0.123183
# Value of c_logl = 1363.772441,  2-norm of c_score = 0.092425
# Value of c_logl = 1363.772441,  2-norm of c_score = 0.194546
# Value of c_logl = 1363.772441,  2-norm of c_score = 0.144827
# Value of c_logl = 1363.772441,  2-norm of c_score = 0.108020
# Value of c_logl = 1363.772441,  2-norm of c_score = 0.080821
# Value of c_logl = 1363.772435,  2-norm of c_score = 0.300358
# Value of c_logl = 1363.772435,  2-norm of c_score = 0.223385
# Value of c_logl = 1363.772435,  2-norm of c_score = 0.166344
# Value of c_logl = 1363.772435,  2-norm of c_score = 0.124107
# Value of c_logl = 1363.772435,  2-norm of c_score = 0.092883
# Value of c_logl = 1363.772435,  2-norm of c_score = 0.120294
# Value of c_logl = 1363.772435,  2-norm of c_score = 0.089955
# Value of c_logl = 1363.772435,  2-norm of c_score = 0.203778
# Value of c_logl = 1363.772435,  2-norm of c_score = 0.151436
# Value of c_logl = 1363.772435,  2-norm of c_score = 0.112648
# Value of c_logl = 1363.772435,  2-norm of c_score = 0.083926
# Value of c_logl = 1363.772428,  2-norm of c_score = 0.299561
# Value of c_logl = 1363.772428,  2-norm of c_score = 0.222581
# Value of c_logl = 1363.772428,  2-norm of c_score = 0.165507
# Value of c_logl = 1363.772428,  2-norm of c_score = 0.123210
# Value of c_logl = 1363.772428,  2-norm of c_score = 0.091887
# Value of c_logl = 1363.772428,  2-norm of c_score = 0.068726
# Value of c_logl = 1363.772424,  2-norm of c_score = 0.176212
# Value of c_logl = 1363.772424,  2-norm of c_score = 0.131116
# Value of c_logl = 1363.772424,  2-norm of c_score = 0.097704
# Value of c_logl = 1363.772424,  2-norm of c_score = 0.072975
# Value of c_logl = 1363.772424,  2-norm of c_score = 0.100159
# Value of c_logl = 1363.772424,  2-norm of c_score = 0.074692
# Value of c_logl = 1363.772424,  2-norm of c_score = 0.104334
# Value of c_logl = 1363.772424,  2-norm of c_score = 0.077687
# Value of c_logl = 1363.772424,  2-norm of c_score = 0.057961
# Value of c_logl = 1363.772421,  2-norm of c_score = 0.341304
# Value of c_logl = 1363.772421,  2-norm of c_score = 0.253580
# Value of c_logl = 1363.772421,  2-norm of c_score = 0.188532
# Value of c_logl = 1363.772421,  2-norm of c_score = 0.140312
# Value of c_logl = 1363.772421,  2-norm of c_score = 0.104585
# Value of c_logl = 1363.772421,  2-norm of c_score = 0.078141
# Value of c_logl = 1363.772421,  2-norm of c_score = 0.110817
# Value of c_logl = 1363.772421,  2-norm of c_score = 0.082627
# Value of c_logl = 1363.772421,  2-norm of c_score = 0.061767
# Value of c_logl = 1363.772421,  2-norm of c_score = 0.085477
# Value of c_logl = 1363.772421,  2-norm of c_score = 0.063782
# Value of c_logl = 1363.772421,  2-norm of c_score = 0.091383
# Value of c_logl = 1363.772421,  2-norm of c_score = 0.068059
# Value of c_logl = 1363.772421,  2-norm of c_score = 0.050790
# Value of c_logl = 1363.772421,  2-norm of c_score = 0.020870
# Value of c_logl = 1363.772420,  2-norm of c_score = 0.191092
# Value of c_logl = 1363.772420,  2-norm of c_score = 0.142010
# Value of c_logl = 1363.772420,  2-norm of c_score = 0.105618
# Value of c_logl = 1363.772420,  2-norm of c_score = 0.078646
# Value of c_logl = 1363.772420,  2-norm of c_score = 0.058667
# Value of c_logl = 1363.772420,  2-norm of c_score = 0.087465
# Value of c_logl = 1363.772420,  2-norm of c_score = 0.065099
# Value of c_logl = 1363.772420,  2-norm of c_score = 0.048529
# Value of c_logl = 1363.772420,  2-norm of c_score = 0.072877
# Value of c_logl = 1363.772420,  2-norm of c_score = 0.054212
# Value of c_logl = 1363.772420,  2-norm of c_score = 0.040380
# Value of c_logl = 1363.772420,  2-norm of c_score = 0.060145
# Value of c_logl = 1363.772420,  2-norm of c_score = 0.044717
# Value of c_logl = 1363.772420,  2-norm of c_score = 0.033284
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.015310
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.046210
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.034335
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.025531
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.073827
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.054860
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.040797
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.030373
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.033982
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.025311
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.039573
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.029410
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.021876
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.097130
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.072153
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.053632
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.039900
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.029723
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.033263
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.024794
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.038752
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.028814
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.021448
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.024070
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.029018
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.021572
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.024503
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.018215
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.010479
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.033422
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.024831
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.018460
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.013737
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.015427
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.018546
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.013784
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.014921
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.011093
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.018088
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.013446
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.015412
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.011455
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.017333
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.012880
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.009579
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.011068
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.013459
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.009994
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.007424
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.016573
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.012311
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.009150
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.010435
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.007754
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.007117
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.010724
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.007962
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.005914
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.004395
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.004945
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.003673
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.003791
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.002815
# Value of c_logl = 1363.772419,  2-norm of c_score = 0.002845
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1363.772419
#          Iterations: 642
#          Function evaluations: 1165
#          Gradient evaluations: 1806
#          Hessian evaluations: 643
#
# -------------------------------------------------------------------------------------------
# - BIAS CORRECTED JOINT FIXED EFFECTS LOGIT ESTIMATION RESULTS                             -
# -------------------------------------------------------------------------------------------
#
# Number of agents,           N :             115
# Number of dyads,            n :           6,555
#
# -------------------------------------------------------------------------------------------
#
# Independent variable       Coef.    ( Std. Err.)
# -------------------------------------------------------------------------------------------
# Distance                  -0.001949 (  0.000190)
# Other blood relation       1.361086 (  0.190788)
# Cousin, etc.               1.849790 (  0.245518)
# Sibling, child, etc.       2.898098 (  0.270260)
# Age difference            -0.004347 (  0.003730)
# Same religion              0.475105 (  0.086042)
# Same clan                  0.298617 (  0.141581)
# Same education level       0.143418 (  0.110033)
# Adjacent wealth class      0.052694 (  0.103700)
# Non-adjacent wealth class -0.043660 (  0.116544)
#
# -------------------------------------------------------------------------------------------

# %% [markdown]
# It takes some time for *dyad\_jfe\_logit()* to converge. This reflects the sparsity of the Nyakatoke network and the consequent difficulty of estimating the household degree heterogeneity effects.
# <br>
# <br>
# Relative to the *tetrad\_logit()* results, the joint estimator suggests sorting by religion and clan. In Monte Carlo experiments I have found that the joint estimator -- particularly the bias correction step -- can work very poorly in networks like the Nyakatoke one (i.e., in networks that are sparse such that many agents have only a few links). In such settings the $A_{i}$ for $i=1,...,N$ may be _very_ imprecisely estimated and this can effect the quality of the common parameter estimates as well.
# <br>
# <br>
# For reference we can look at the joint coefficient estimates prior to bias correction using the *print\_coef()* utility included in the **netrics** package. These point estimates are closer to the *tetrad\_logit()* ones than their bias-corrected counterparts. This suggests, that in this particular example, bias-correction may be doing more harm that good.
# <br>
# <br>
# Monte Carlo evidence suggests that in denser networks, the size distortion causes by bias in the limit distribution of the joint fixed effects estimator is very real and, furthermore, that bias correction can be effective in such contexts. So not too much should be made of this example.

# %%
netrics.print_coef(beta_JFE, vcov_beta_JFE, var_names=cov_names)
# Out:
# Independent variable       Coef.    ( Std. Err.)
# -------------------------------------------------------------------------------------------
# Distance                  -0.002531 (  0.000190)
# Other blood relation       1.308501 (  0.190788)
# Cousin, etc.               1.925634 (  0.245518)
# Sibling, child, etc.       2.893077 (  0.270260)
# Age difference            -0.013740 (  0.003730)
# Same religion              0.375629 (  0.086042)
# Same clan                  0.264691 (  0.141581)
# Same education level      -0.062930 (  0.110033)
# Adjacent wealth class     -0.176241 (  0.103700)
# Non-adjacent wealth class -0.298087 (  0.116544)
#
# -------------------------------------------------------------------------------------------

# %%
# This imports an attractive notebook style from Github
from IPython.core.display import HTML
import urllib2
HTML(urllib2.urlopen('http://bit.ly/1Bf5Hft').read())
# Out:
# <style>
#
# html {
#   font-size: 62.5% !important; }
# body {
#   font-size: 1.5em !important; /* currently ems cause chrome bug misinterpreting rems on body element */
#   line-height: 1.6 !important;
#   font-weight: 400 !important;
#   font-family: "Raleway", "HelveticaNeue", "Helvetica Neue", Helvetica, Arial, sans-serif !important;
#   color: #222 !important; }
#
# div{ border-radius: 0px !important;  }
# div.CodeMirror-sizer{ background: rgb(244, 244, 248) !important; }
# div.input_area{ background: rgb(244, 244, 248) !important; }
#
# div.out_prompt_overlay:hover{ background: rgb(244, 244, 248) !important; }
# div.input_prompt:hover{ background: rgb(244, 244, 248) !important; }
#
# h1, h2, h3, h4, h5, h6 {
#   color: #333 !important;
#   margin-top: 0 !important;
#   margin-bottom: 2rem !important;
#   font-weight: 300 !important; }
# h1 { font-size: 4.0rem !important; line-height: 1.2 !important;  letter-spacing: -.1rem !important;}
# h2 { font-size: 3.6rem !important; line-height: 1.25 !important; letter-spacing: -.1rem !important; }
# h3 { font-size: 3.0rem !important; line-height: 1.3 !important;  letter-spacing: -.1rem !important; }
# h4 { font-size: 2.4rem !important; line-height: 1.35 !important; letter-spacing: -.08rem !important; }
# h5 { font-size: 1.8rem !important; line-height: 1.5 !important;  letter-spacing: -.05rem !important; }
# h6 { font-size: 1.5rem !important; line-height: 1.6 !important;  letter-spacing: 0 !important; }
#
# @media (min-width: 550px) {
#   h1 { font-size: 5.0rem !important; }
#   h2 { font-size: 4.2rem !important; }
#   h3 { font-size: 3.6rem !important; }
#   h4 { font-size: 3.0rem !important; }
#   h5 { font-size: 2.4rem !important; }
#   h6 { font-size: 1.5rem !important; }
# }
#
# p {
#   margin-top: 0 !important; }
#
# a {
#   color: #1EAEDB !important; }
# a:hover {
#   color: #0FA0CE !important; }
#
# code {
#   padding: .2rem .5rem !important;
#   margin: 0 .2rem !important;
#   font-size: 90% !important;
#   white-space: nowrap !important;
#   background: #F1F1F1 !important;
#   border: 1px solid #E1E1E1 !important;
#   border-radius: 4px !important; }
# pre > code {
#   display: block !important;
#   padding: 1rem 1.5rem !important;
#   white-space: pre !important; }
#
# button{ border-radius: 0px !important; }
# .navbar-inner{ background-image: none !important;  }
# select, textarea{ border-radius: 0px !important; }
#
# </style>
